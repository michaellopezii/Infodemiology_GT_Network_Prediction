# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime
from math import comb

# %%
main_dirs = [
    "../gt_corr_adj_matrix/gt_adj_matrices_msv_15day",
    "../gt_corr_adj_matrix/gt_adj_matrices_msv_30day",
    "../gt_corr_adj_matrix/gt_adj_matrices_rsv_normal_15day",
    "../gt_corr_adj_matrix/gt_adj_matrices_rsv_normal_30day"
]

# %%
thresholds = [0.4, 0.5, 0.6, 0.8]

# %%
def calculate_clustering_coefficient(adj_matrix, debug=False):
    """
    Calculate global clustering coefficient with fixed denominator.
    Uses total possible triplets in 15-node network as denominator.
    """
    n = 15
    # Total possible triplets in a 15-node network: C(15,3)
    total_possible_triplets = comb(n, 3)  # This equals 455
    total_triangles = 0
    
    if debug:
        print("\nDebugging Clustering Coefficient Calculation:")
        print(f"Total possible triplets (denominator): {total_possible_triplets}")
        print("============================================")
    
    # Store triangle information for debugging
    triangle_details = []
    
    # Look at each possible triplet of nodes
    for i in range(1, n):
        for j in range(i):
            for k in range(j):
                # Get the three relevant edges
                edge_ij = adj_matrix.iloc[i, j]
                edge_ik = adj_matrix.iloc[i, k]
                edge_jk = adj_matrix.iloc[j, k]
                
                # If all three edges exist, it's a triangle
                if edge_ij == 1 and edge_ik == 1 and edge_jk == 1:
                    total_triangles += 1
                    
                    if debug:
                        triangle_info = {
                            'nodes': (i, j, k),
                            'node_names': (adj_matrix.index[i], adj_matrix.index[j], adj_matrix.index[k]),
                            'edges': {
                                f'{adj_matrix.index[i]}-{adj_matrix.index[j]}': edge_ij,
                                f'{adj_matrix.index[i]}-{adj_matrix.index[k]}': edge_ik,
                                f'{adj_matrix.index[j]}-{adj_matrix.index[k]}': edge_jk
                            }
                        }
                        triangle_details.append(triangle_info)
    
    # Calculate coefficient using fixed denominator
    coef = total_triangles / total_possible_triplets
    
    if debug:
        print(f"\nTotal triangles found: {total_triangles}")
        print(f"Clustering coefficient: {coef}")
        if triangle_details:
            print("\nTriangles found:")
            for idx, triangle in enumerate(triangle_details, 1):
                print(f"\nTriangle {idx}:")
                print(f"Nodes: {triangle['node_names']}")
                print("Edges:")
                for edge, value in triangle['edges'].items():
                    print(f"  {edge}: {value}")
        print("\n============================================")
    
    return coef, {'triangles': total_triangles, 'possible_triplets': total_possible_triplets, 'details': triangle_details} if debug else None

# %%
def process_adjacency_matrices(main_dir, threshold):
    """Process all adjacency matrices with debugging."""
    threshold_dir = os.path.join(main_dir, f"{threshold}_threshold")
    
    if not os.path.exists(threshold_dir):
        print(f"Directory not found: {threshold_dir}")
        return pd.DataFrame()
    
    dates = []
    coefficients = []
    
    adj_files = sorted([f for f in os.listdir(threshold_dir) if f.endswith('.csv')])
    
    for adj_file in adj_files:
        date_parts = adj_file.split('_')[-3:]
        formatted_date = f"{date_parts[0]}-{date_parts[1]}-{date_parts[2].replace('.csv', '')}"
        
        print(f"\nProcessing {adj_file}")
        
        try:
            file_path = os.path.join(threshold_dir, adj_file)
            adj_matrix = pd.read_csv(file_path, index_col=0)
            
            if adj_matrix.shape != (15, 15):
                print(f"Warning: Matrix size is {adj_matrix.shape}, expected (15, 15)")
                continue
            
            # Calculate coefficient with debugging for high values
            coef, debug_info = calculate_clustering_coefficient(adj_matrix, debug=(coef > 0.5 if 'coef' in locals() else False))
            
            dates.append(formatted_date)
            coefficients.append(coef)
            print(f"Processed successfully: coefficient = {coef}")
            
        except Exception as e:
            print(f"Error processing {adj_file}: {str(e)}")
            continue
    
    return pd.DataFrame({
        'date': dates,
        'clustering_coefficient': coefficients
    })

# %%
def process_adjacency_matrices(main_dir, threshold):
    """Process all adjacency matrices with debugging"""
    threshold_dir = os.path.join(main_dir, f"{threshold}_threshold")
    
    if not os.path.exists(threshold_dir):
        print(f"Directory not found: {threshold_dir}")
        return pd.DataFrame()
    
    dates = []
    coefficients = []
    
    adj_files = sorted([f for f in os.listdir(threshold_dir) if f.endswith('.csv')])
    
    for adj_file in adj_files:
        date_parts = adj_file.split('_')[-3:]
        formatted_date = f"{date_parts[0]}-{date_parts[1]}-{date_parts[2].replace('.csv', '')}"
        
        print(f"\nProcessing {adj_file}")
        
        try:
            file_path = os.path.join(threshold_dir, adj_file)
            adj_matrix = pd.read_csv(file_path, index_col=0)
            
            if adj_matrix.shape != (15, 15):
                print(f"Warning: Matrix size is {adj_matrix.shape}, expected (15, 15)")
                continue
            
            # Calculate coefficient with debugging for high values
            coef, debug_info = calculate_clustering_coefficient(adj_matrix, debug=(coef > 0.5 if 'coef' in locals() else False))
            
            dates.append(formatted_date)
            coefficients.append(coef)
            print(f"Processed successfully: coefficient = {coef}")
            
        except Exception as e:
            print(f"Error processing {adj_file}: {str(e)}")
            continue
    
    return pd.DataFrame({
        'date': dates,
        'clustering_coefficient': coefficients
    })

# %%
# Process each directory and threshold
for main_dir in main_dirs:
    matrix_type = 'msv' if 'msv' in main_dir else 'rsv'
    window_size = '15' if '15day' in main_dir else '30'
    
    print(f"\nProcessing {main_dir}")
    
    for threshold in thresholds:
        print(f"\nProcessing threshold {threshold}")
        
        try:
            results_df = process_adjacency_matrices(main_dir, threshold)
            
            if not results_df.empty:
                results_df = results_df.sort_values('date')
                output_filename = f"cluscoeff_{matrix_type}_{threshold}_{window_size}day.csv"
                results_df.to_csv(output_filename, index=False)
                print(f"Created {output_filename} with {len(results_df)} entries")
            else:
                print(f"No results generated for {main_dir} threshold {threshold}")
            
        except Exception as e:
            print(f"Error processing {main_dir} with threshold {threshold}: {str(e)}")

print("\nClustering coefficient calculation completed")
# Out:
# Processing ../gt_corr_adj_matrix/gt_adj_matrices_msv_15day
#
# Processing threshold 0.4
#
# Processing msv_0.4_2020_03_30.csv
# Processed successfully: coefficient = 0.45494505494505494
#
# Processing msv_0.4_2020_03_31.csv
# Processed successfully: coefficient = 0.5714285714285714
#
# Processing msv_0.4_2020_04_01.csv
#
# Debugging Clustering Coefficient Calculation:
# Total possible triplets (denominator): 455
# ============================================
#
# Total triangles found: 224
# Clustering coefficient: 0.49230769230769234
#
# Triangles found:
#
# Triangle 1:
# Nodes: ('fever', 'cough', 'flu')
# Edges:
#   fever-cough: 1.0
#   fever-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 2:
# Nodes: ('headache', 'fever', 'flu')
# Edges:
#   headache-fever: 1.0
#   headache-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 3:
# Nodes: ('lagnat', 'cough', 'flu')
# Edges:
#   lagnat-cough: 1.0
#   lagnat-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 4:
# Nodes: ('lagnat', 'fever', 'flu')
# Edges:
#   lagnat-fever: 1.0
#   lagnat-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 5:
# Nodes: ('lagnat', 'fever', 'cough')
# Edges:
#   lagnat-fever: 1.0
#   lagnat-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 6:
# Nodes: ('rashes', 'fever', 'flu')
# Edges:
#   rashes-fever: 1.0
#   rashes-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 7:
# Nodes: ('rashes', 'headache', 'flu')
# Edges:
#   rashes-headache: 1.0
#   rashes-flu: 1.0
#   headache-flu: 1.0
#
# Triangle 8:
# Nodes: ('rashes', 'headache', 'fever')
# Edges:
#   rashes-headache: 1.0
#   rashes-fever: 1.0
#   headache-fever: 1.0
#
# Triangle 9:
# Nodes: ('rashes', 'lagnat', 'flu')
# Edges:
#   rashes-lagnat: 1.0
#   rashes-flu: 1.0
#   lagnat-flu: 1.0
#
# Triangle 10:
# Nodes: ('rashes', 'lagnat', 'fever')
# Edges:
#   rashes-lagnat: 1.0
#   rashes-fever: 1.0
#   lagnat-fever: 1.0
#
# Triangle 11:
# Nodes: ('sipon', 'cough', 'flu')
# Edges:
#   sipon-cough: 1.0
#   sipon-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 12:
# Nodes: ('sipon', 'fever', 'flu')
# Edges:
#   sipon-fever: 1.0
#   sipon-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 13:
# Nodes: ('sipon', 'fever', 'cough')
# Edges:
#   sipon-fever: 1.0
#   sipon-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 14:
# Nodes: ('sipon', 'lagnat', 'flu')
# Edges:
#   sipon-lagnat: 1.0
#   sipon-flu: 1.0
#   lagnat-flu: 1.0
#
# Triangle 15:
# Nodes: ('sipon', 'lagnat', 'cough')
# Edges:
#   sipon-lagnat: 1.0
#   sipon-cough: 1.0
#   lagnat-cough: 1.0
#
# Triangle 16:
# Nodes: ('sipon', 'lagnat', 'fever')
# Edges:
#   sipon-lagnat: 1.0
#   sipon-fever: 1.0
#   lagnat-fever: 1.0
#
# Triangle 17:
# Nodes: ('ubo', 'cough', 'flu')
# Edges:
#   ubo-cough: 1.0
#   ubo-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 18:
# Nodes: ('ubo', 'fever', 'flu')
# Edges:
#   ubo-fever: 1.0
#   ubo-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 19:
# Nodes: ('ubo', 'fever', 'cough')
# Edges:
#   ubo-fever: 1.0
#   ubo-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 20:
# Nodes: ('ubo', 'lagnat', 'flu')
# Edges:
#   ubo-lagnat: 1.0
#   ubo-flu: 1.0
#   lagnat-flu: 1.0
#
# Triangle 21:
# Nodes: ('ubo', 'lagnat', 'cough')
# Edges:
#   ubo-lagnat: 1.0
#   ubo-cough: 1.0
#   lagnat-cough: 1.0
#
# Triangle 22:
# Nodes: ('ubo', 'lagnat', 'fever')
# Edges:
#   ubo-lagnat: 1.0
#   ubo-fever: 1.0
#   lagnat-fever: 1.0
#
# Triangle 23:
# Nodes: ('ubo', 'sipon', 'flu')
# Edges:
#   ubo-sipon: 1.0
#   ubo-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 24:
# Nodes: ('ubo', 'sipon', 'cough')
# Edges:
#   ubo-sipon: 1.0
#   ubo-cough: 1.0
#   sipon-cough: 1.0
#
# Triangle 25:
# Nodes: ('ubo', 'sipon', 'fever')
# Edges:
#   ubo-sipon: 1.0
#   ubo-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 26:
# Nodes: ('ubo', 'sipon', 'lagnat')
# Edges:
#   ubo-sipon: 1.0
#   ubo-lagnat: 1.0
#   sipon-lagnat: 1.0
#
# Triangle 27:
# Nodes: ('ecq', 'cough', 'flu')
# Edges:
#   ecq-cough: 1.0
#   ecq-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 28:
# Nodes: ('ecq', 'fever', 'flu')
# Edges:
#   ecq-fever: 1.0
#   ecq-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 29:
# Nodes: ('ecq', 'fever', 'cough')
# Edges:
#   ecq-fever: 1.0
#   ecq-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 30:
# Nodes: ('ecq', 'lagnat', 'flu')
# Edges:
#   ecq-lagnat: 1.0
#   ecq-flu: 1.0
#   lagnat-flu: 1.0
#
# Triangle 31:
# Nodes: ('ecq', 'lagnat', 'cough')
# Edges:
#   ecq-lagnat: 1.0
#   ecq-cough: 1.0
#   lagnat-cough: 1.0
#
# Triangle 32:
# Nodes: ('ecq', 'lagnat', 'fever')
# Edges:
#   ecq-lagnat: 1.0
#   ecq-fever: 1.0
#   lagnat-fever: 1.0
#
# Triangle 33:
# Nodes: ('ecq', 'rashes', 'flu')
# Edges:
#   ecq-rashes: 1.0
#   ecq-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 34:
# Nodes: ('ecq', 'rashes', 'fever')
# Edges:
#   ecq-rashes: 1.0
#   ecq-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 35:
# Nodes: ('ecq', 'rashes', 'lagnat')
# Edges:
#   ecq-rashes: 1.0
#   ecq-lagnat: 1.0
#   rashes-lagnat: 1.0
#
# Triangle 36:
# Nodes: ('ecq', 'sipon', 'flu')
# Edges:
#   ecq-sipon: 1.0
#   ecq-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 37:
# Nodes: ('ecq', 'sipon', 'cough')
# Edges:
#   ecq-sipon: 1.0
#   ecq-cough: 1.0
#   sipon-cough: 1.0
#
# Triangle 38:
# Nodes: ('ecq', 'sipon', 'fever')
# Edges:
#   ecq-sipon: 1.0
#   ecq-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 39:
# Nodes: ('ecq', 'sipon', 'lagnat')
# Edges:
#   ecq-sipon: 1.0
#   ecq-lagnat: 1.0
#   sipon-lagnat: 1.0
#
# Triangle 40:
# Nodes: ('ecq', 'ubo', 'flu')
# Edges:
#   ecq-ubo: 1.0
#   ecq-flu: 1.0
#   ubo-flu: 1.0
#
# Triangle 41:
# Nodes: ('ecq', 'ubo', 'cough')
# Edges:
#   ecq-ubo: 1.0
#   ecq-cough: 1.0
#   ubo-cough: 1.0
#
# Triangle 42:
# Nodes: ('ecq', 'ubo', 'fever')
# Edges:
#   ecq-ubo: 1.0
#   ecq-fever: 1.0
#   ubo-fever: 1.0
#
# Triangle 43:
# Nodes: ('ecq', 'ubo', 'lagnat')
# Edges:
#   ecq-ubo: 1.0
#   ecq-lagnat: 1.0
#   ubo-lagnat: 1.0
#
# Triangle 44:
# Nodes: ('ecq', 'ubo', 'sipon')
# Edges:
#   ecq-ubo: 1.0
#   ecq-sipon: 1.0
#   ubo-sipon: 1.0
#
# Triangle 45:
# Nodes: ('face shield', 'fever', 'flu')
# Edges:
#   face shield-fever: 1.0
#   face shield-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 46:
# Nodes: ('face shield', 'headache', 'flu')
# Edges:
#   face shield-headache: 1.0
#   face shield-flu: 1.0
#   headache-flu: 1.0
#
# Triangle 47:
# Nodes: ('face shield', 'headache', 'fever')
# Edges:
#   face shield-headache: 1.0
#   face shield-fever: 1.0
#   headache-fever: 1.0
#
# Triangle 48:
# Nodes: ('face shield', 'lagnat', 'flu')
# Edges:
#   face shield-lagnat: 1.0
#   face shield-flu: 1.0
#   lagnat-flu: 1.0
#
# Triangle 49:
# Nodes: ('face shield', 'lagnat', 'fever')
# Edges:
#   face shield-lagnat: 1.0
#   face shield-fever: 1.0
#   lagnat-fever: 1.0
#
# Triangle 50:
# Nodes: ('face shield', 'rashes', 'flu')
# Edges:
#   face shield-rashes: 1.0
#   face shield-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 51:
# Nodes: ('face shield', 'rashes', 'fever')
# Edges:
#   face shield-rashes: 1.0
#   face shield-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 52:
# Nodes: ('face shield', 'rashes', 'headache')
# Edges:
#   face shield-rashes: 1.0
#   face shield-headache: 1.0
#   rashes-headache: 1.0
#
# Triangle 53:
# Nodes: ('face shield', 'rashes', 'lagnat')
# Edges:
#   face shield-rashes: 1.0
#   face shield-lagnat: 1.0
#   rashes-lagnat: 1.0
#
# Triangle 54:
# Nodes: ('face shield', 'sipon', 'flu')
# Edges:
#   face shield-sipon: 1.0
#   face shield-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 55:
# Nodes: ('face shield', 'sipon', 'fever')
# Edges:
#   face shield-sipon: 1.0
#   face shield-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 56:
# Nodes: ('face shield', 'sipon', 'lagnat')
# Edges:
#   face shield-sipon: 1.0
#   face shield-lagnat: 1.0
#   sipon-lagnat: 1.0
#
# Triangle 57:
# Nodes: ('Frontliners', 'cough', 'flu')
# Edges:
#   Frontliners-cough: 1.0
#   Frontliners-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 58:
# Nodes: ('Frontliners', 'fever', 'flu')
# Edges:
#   Frontliners-fever: 1.0
#   Frontliners-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 59:
# Nodes: ('Frontliners', 'fever', 'cough')
# Edges:
#   Frontliners-fever: 1.0
#   Frontliners-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 60:
# Nodes: ('Frontliners', 'headache', 'flu')
# Edges:
#   Frontliners-headache: 1.0
#   Frontliners-flu: 1.0
#   headache-flu: 1.0
#
# Triangle 61:
# Nodes: ('Frontliners', 'headache', 'fever')
# Edges:
#   Frontliners-headache: 1.0
#   Frontliners-fever: 1.0
#   headache-fever: 1.0
#
# Triangle 62:
# Nodes: ('Frontliners', 'lagnat', 'flu')
# Edges:
#   Frontliners-lagnat: 1.0
#   Frontliners-flu: 1.0
#   lagnat-flu: 1.0
#
# Triangle 63:
# Nodes: ('Frontliners', 'lagnat', 'cough')
# Edges:
#   Frontliners-lagnat: 1.0
#   Frontliners-cough: 1.0
#   lagnat-cough: 1.0
#
# Triangle 64:
# Nodes: ('Frontliners', 'lagnat', 'fever')
# Edges:
#   Frontliners-lagnat: 1.0
#   Frontliners-fever: 1.0
#   lagnat-fever: 1.0
#
# Triangle 65:
# Nodes: ('Frontliners', 'rashes', 'flu')
# Edges:
#   Frontliners-rashes: 1.0
#   Frontliners-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 66:
# Nodes: ('Frontliners', 'rashes', 'fever')
# Edges:
#   Frontliners-rashes: 1.0
#   Frontliners-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 67:
# Nodes: ('Frontliners', 'rashes', 'headache')
# Edges:
#   Frontliners-rashes: 1.0
#   Frontliners-headache: 1.0
#   rashes-headache: 1.0
#
# Triangle 68:
# Nodes: ('Frontliners', 'rashes', 'lagnat')
# Edges:
#   Frontliners-rashes: 1.0
#   Frontliners-lagnat: 1.0
#   rashes-lagnat: 1.0
#
# Triangle 69:
# Nodes: ('Frontliners', 'ubo', 'flu')
# Edges:
#   Frontliners-ubo: 1.0
#   Frontliners-flu: 1.0
#   ubo-flu: 1.0
#
# Triangle 70:
# Nodes: ('Frontliners', 'ubo', 'cough')
# Edges:
#   Frontliners-ubo: 1.0
#   Frontliners-cough: 1.0
#   ubo-cough: 1.0
#
# Triangle 71:
# Nodes: ('Frontliners', 'ubo', 'fever')
# Edges:
#   Frontliners-ubo: 1.0
#   Frontliners-fever: 1.0
#   ubo-fever: 1.0
#
# Triangle 72:
# Nodes: ('Frontliners', 'ubo', 'lagnat')
# Edges:
#   Frontliners-ubo: 1.0
#   Frontliners-lagnat: 1.0
#   ubo-lagnat: 1.0
#
# Triangle 73:
# Nodes: ('Frontliners', 'ecq', 'flu')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-flu: 1.0
#   ecq-flu: 1.0
#
# Triangle 74:
# Nodes: ('Frontliners', 'ecq', 'cough')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-cough: 1.0
#   ecq-cough: 1.0
#
# Triangle 75:
# Nodes: ('Frontliners', 'ecq', 'fever')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-fever: 1.0
#   ecq-fever: 1.0
#
# Triangle 76:
# Nodes: ('Frontliners', 'ecq', 'lagnat')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-lagnat: 1.0
#   ecq-lagnat: 1.0
#
# Triangle 77:
# Nodes: ('Frontliners', 'ecq', 'rashes')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-rashes: 1.0
#   ecq-rashes: 1.0
#
# Triangle 78:
# Nodes: ('Frontliners', 'ecq', 'ubo')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-ubo: 1.0
#   ecq-ubo: 1.0
#
# Triangle 79:
# Nodes: ('Frontliners', 'face shield', 'flu')
# Edges:
#   Frontliners-face shield: 1.0
#   Frontliners-flu: 1.0
#   face shield-flu: 1.0
#
# Triangle 80:
# Nodes: ('Frontliners', 'face shield', 'fever')
# Edges:
#   Frontliners-face shield: 1.0
#   Frontliners-fever: 1.0
#   face shield-fever: 1.0
#
# Triangle 81:
# Nodes: ('Frontliners', 'face shield', 'headache')
# Edges:
#   Frontliners-face shield: 1.0
#   Frontliners-headache: 1.0
#   face shield-headache: 1.0
#
# Triangle 82:
# Nodes: ('Frontliners', 'face shield', 'lagnat')
# Edges:
#   Frontliners-face shield: 1.0
#   Frontliners-lagnat: 1.0
#   face shield-lagnat: 1.0
#
# Triangle 83:
# Nodes: ('Frontliners', 'face shield', 'rashes')
# Edges:
#   Frontliners-face shield: 1.0
#   Frontliners-rashes: 1.0
#   face shield-rashes: 1.0
#
# Triangle 84:
# Nodes: ('masks', 'face shield', 'fever')
# Edges:
#   masks-face shield: 1.0
#   masks-fever: 1.0
#   face shield-fever: 1.0
#
# Triangle 85:
# Nodes: ('Quarantine', 'cough', 'flu')
# Edges:
#   Quarantine-cough: 1.0
#   Quarantine-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 86:
# Nodes: ('Quarantine', 'fever', 'flu')
# Edges:
#   Quarantine-fever: 1.0
#   Quarantine-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 87:
# Nodes: ('Quarantine', 'fever', 'cough')
# Edges:
#   Quarantine-fever: 1.0
#   Quarantine-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 88:
# Nodes: ('Quarantine', 'lagnat', 'flu')
# Edges:
#   Quarantine-lagnat: 1.0
#   Quarantine-flu: 1.0
#   lagnat-flu: 1.0
#
# Triangle 89:
# Nodes: ('Quarantine', 'lagnat', 'cough')
# Edges:
#   Quarantine-lagnat: 1.0
#   Quarantine-cough: 1.0
#   lagnat-cough: 1.0
#
# Triangle 90:
# Nodes: ('Quarantine', 'lagnat', 'fever')
# Edges:
#   Quarantine-lagnat: 1.0
#   Quarantine-fever: 1.0
#   lagnat-fever: 1.0
#
# Triangle 91:
# Nodes: ('Quarantine', 'rashes', 'flu')
# Edges:
#   Quarantine-rashes: 1.0
#   Quarantine-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 92:
# Nodes: ('Quarantine', 'rashes', 'fever')
# Edges:
#   Quarantine-rashes: 1.0
#   Quarantine-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 93:
# Nodes: ('Quarantine', 'rashes', 'lagnat')
# Edges:
#   Quarantine-rashes: 1.0
#   Quarantine-lagnat: 1.0
#   rashes-lagnat: 1.0
#
# Triangle 94:
# Nodes: ('Quarantine', 'sipon', 'flu')
# Edges:
#   Quarantine-sipon: 1.0
#   Quarantine-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 95:
# Nodes: ('Quarantine', 'sipon', 'cough')
# Edges:
#   Quarantine-sipon: 1.0
#   Quarantine-cough: 1.0
#   sipon-cough: 1.0
#
# Triangle 96:
# Nodes: ('Quarantine', 'sipon', 'fever')
# Edges:
#   Quarantine-sipon: 1.0
#   Quarantine-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 97:
# Nodes: ('Quarantine', 'sipon', 'lagnat')
# Edges:
#   Quarantine-sipon: 1.0
#   Quarantine-lagnat: 1.0
#   sipon-lagnat: 1.0
#
# Triangle 98:
# Nodes: ('Quarantine', 'ubo', 'flu')
# Edges:
#   Quarantine-ubo: 1.0
#   Quarantine-flu: 1.0
#   ubo-flu: 1.0
#
# Triangle 99:
# Nodes: ('Quarantine', 'ubo', 'cough')
# Edges:
#   Quarantine-ubo: 1.0
#   Quarantine-cough: 1.0
#   ubo-cough: 1.0
#
# Triangle 100:
# Nodes: ('Quarantine', 'ubo', 'fever')
# Edges:
#   Quarantine-ubo: 1.0
#   Quarantine-fever: 1.0
#   ubo-fever: 1.0
#
# Triangle 101:
# Nodes: ('Quarantine', 'ubo', 'lagnat')
# Edges:
#   Quarantine-ubo: 1.0
#   Quarantine-lagnat: 1.0
#   ubo-lagnat: 1.0
#
# Triangle 102:
# Nodes: ('Quarantine', 'ubo', 'sipon')
# Edges:
#   Quarantine-ubo: 1.0
#   Quarantine-sipon: 1.0
#   ubo-sipon: 1.0
#
# Triangle 103:
# Nodes: ('Quarantine', 'ecq', 'flu')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-flu: 1.0
#   ecq-flu: 1.0
#
# Triangle 104:
# Nodes: ('Quarantine', 'ecq', 'cough')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-cough: 1.0
#   ecq-cough: 1.0
#
# Triangle 105:
# Nodes: ('Quarantine', 'ecq', 'fever')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-fever: 1.0
#   ecq-fever: 1.0
#
# Triangle 106:
# Nodes: ('Quarantine', 'ecq', 'lagnat')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-lagnat: 1.0
#   ecq-lagnat: 1.0
#
# Triangle 107:
# Nodes: ('Quarantine', 'ecq', 'rashes')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-rashes: 1.0
#   ecq-rashes: 1.0
#
# Triangle 108:
# Nodes: ('Quarantine', 'ecq', 'sipon')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-sipon: 1.0
#   ecq-sipon: 1.0
#
# Triangle 109:
# Nodes: ('Quarantine', 'ecq', 'ubo')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-ubo: 1.0
#   ecq-ubo: 1.0
#
# Triangle 110:
# Nodes: ('Quarantine', 'face shield', 'flu')
# Edges:
#   Quarantine-face shield: 1.0
#   Quarantine-flu: 1.0
#   face shield-flu: 1.0
#
# Triangle 111:
# Nodes: ('Quarantine', 'face shield', 'fever')
# Edges:
#   Quarantine-face shield: 1.0
#   Quarantine-fever: 1.0
#   face shield-fever: 1.0
#
# Triangle 112:
# Nodes: ('Quarantine', 'face shield', 'lagnat')
# Edges:
#   Quarantine-face shield: 1.0
#   Quarantine-lagnat: 1.0
#   face shield-lagnat: 1.0
#
# Triangle 113:
# Nodes: ('Quarantine', 'face shield', 'rashes')
# Edges:
#   Quarantine-face shield: 1.0
#   Quarantine-rashes: 1.0
#   face shield-rashes: 1.0
#
# Triangle 114:
# Nodes: ('Quarantine', 'face shield', 'sipon')
# Edges:
#   Quarantine-face shield: 1.0
#   Quarantine-sipon: 1.0
#   face shield-sipon: 1.0
#
# Triangle 115:
# Nodes: ('Quarantine', 'Frontliners', 'flu')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-flu: 1.0
#   Frontliners-flu: 1.0
#
# Triangle 116:
# Nodes: ('Quarantine', 'Frontliners', 'cough')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-cough: 1.0
#   Frontliners-cough: 1.0
#
# Triangle 117:
# Nodes: ('Quarantine', 'Frontliners', 'fever')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-fever: 1.0
#   Frontliners-fever: 1.0
#
# Triangle 118:
# Nodes: ('Quarantine', 'Frontliners', 'lagnat')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-lagnat: 1.0
#   Frontliners-lagnat: 1.0
#
# Triangle 119:
# Nodes: ('Quarantine', 'Frontliners', 'rashes')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-rashes: 1.0
#   Frontliners-rashes: 1.0
#
# Triangle 120:
# Nodes: ('Quarantine', 'Frontliners', 'ubo')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-ubo: 1.0
#   Frontliners-ubo: 1.0
#
# Triangle 121:
# Nodes: ('Quarantine', 'Frontliners', 'ecq')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-ecq: 1.0
#   Frontliners-ecq: 1.0
#
# Triangle 122:
# Nodes: ('Quarantine', 'Frontliners', 'face shield')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-face shield: 1.0
#   Frontliners-face shield: 1.0
#
# Triangle 123:
# Nodes: ('social distancing', 'cough', 'flu')
# Edges:
#   social distancing-cough: 1.0
#   social distancing-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 124:
# Nodes: ('social distancing', 'fever', 'flu')
# Edges:
#   social distancing-fever: 1.0
#   social distancing-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 125:
# Nodes: ('social distancing', 'fever', 'cough')
# Edges:
#   social distancing-fever: 1.0
#   social distancing-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 126:
# Nodes: ('social distancing', 'headache', 'flu')
# Edges:
#   social distancing-headache: 1.0
#   social distancing-flu: 1.0
#   headache-flu: 1.0
#
# Triangle 127:
# Nodes: ('social distancing', 'headache', 'fever')
# Edges:
#   social distancing-headache: 1.0
#   social distancing-fever: 1.0
#   headache-fever: 1.0
#
# Triangle 128:
# Nodes: ('social distancing', 'lagnat', 'flu')
# Edges:
#   social distancing-lagnat: 1.0
#   social distancing-flu: 1.0
#   lagnat-flu: 1.0
#
# Triangle 129:
# Nodes: ('social distancing', 'lagnat', 'cough')
# Edges:
#   social distancing-lagnat: 1.0
#   social distancing-cough: 1.0
#   lagnat-cough: 1.0
#
# Triangle 130:
# Nodes: ('social distancing', 'lagnat', 'fever')
# Edges:
#   social distancing-lagnat: 1.0
#   social distancing-fever: 1.0
#   lagnat-fever: 1.0
#
# Triangle 131:
# Nodes: ('social distancing', 'rashes', 'flu')
# Edges:
#   social distancing-rashes: 1.0
#   social distancing-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 132:
# Nodes: ('social distancing', 'rashes', 'fever')
# Edges:
#   social distancing-rashes: 1.0
#   social distancing-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 133:
# Nodes: ('social distancing', 'rashes', 'headache')
# Edges:
#   social distancing-rashes: 1.0
#   social distancing-headache: 1.0
#   rashes-headache: 1.0
#
# Triangle 134:
# Nodes: ('social distancing', 'rashes', 'lagnat')
# Edges:
#   social distancing-rashes: 1.0
#   social distancing-lagnat: 1.0
#   rashes-lagnat: 1.0
#
# Triangle 135:
# Nodes: ('social distancing', 'sipon', 'flu')
# Edges:
#   social distancing-sipon: 1.0
#   social distancing-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 136:
# Nodes: ('social distancing', 'sipon', 'cough')
# Edges:
#   social distancing-sipon: 1.0
#   social distancing-cough: 1.0
#   sipon-cough: 1.0
#
# Triangle 137:
# Nodes: ('social distancing', 'sipon', 'fever')
# Edges:
#   social distancing-sipon: 1.0
#   social distancing-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 138:
# Nodes: ('social distancing', 'sipon', 'lagnat')
# Edges:
#   social distancing-sipon: 1.0
#   social distancing-lagnat: 1.0
#   sipon-lagnat: 1.0
#
# Triangle 139:
# Nodes: ('social distancing', 'ubo', 'flu')
# Edges:
#   social distancing-ubo: 1.0
#   social distancing-flu: 1.0
#   ubo-flu: 1.0
#
# Triangle 140:
# Nodes: ('social distancing', 'ubo', 'cough')
# Edges:
#   social distancing-ubo: 1.0
#   social distancing-cough: 1.0
#   ubo-cough: 1.0
#
# Triangle 141:
# Nodes: ('social distancing', 'ubo', 'fever')
# Edges:
#   social distancing-ubo: 1.0
#   social distancing-fever: 1.0
#   ubo-fever: 1.0
#
# Triangle 142:
# Nodes: ('social distancing', 'ubo', 'lagnat')
# Edges:
#   social distancing-ubo: 1.0
#   social distancing-lagnat: 1.0
#   ubo-lagnat: 1.0
#
# Triangle 143:
# Nodes: ('social distancing', 'ubo', 'sipon')
# Edges:
#   social distancing-ubo: 1.0
#   social distancing-sipon: 1.0
#   ubo-sipon: 1.0
#
# Triangle 144:
# Nodes: ('social distancing', 'ecq', 'flu')
# Edges:
#   social distancing-ecq: 1.0
#   social distancing-flu: 1.0
#   ecq-flu: 1.0
#
# Triangle 145:
# Nodes: ('social distancing', 'ecq', 'cough')
# Edges:
#   social distancing-ecq: 1.0
#   social distancing-cough: 1.0
#   ecq-cough: 1.0
#
# Triangle 146:
# Nodes: ('social distancing', 'ecq', 'fever')
# Edges:
#   social distancing-ecq: 1.0
#   social distancing-fever: 1.0
#   ecq-fever: 1.0
#
# Triangle 147:
# Nodes: ('social distancing', 'ecq', 'lagnat')
# Edges:
#   social distancing-ecq: 1.0
#   social distancing-lagnat: 1.0
#   ecq-lagnat: 1.0
#
# Triangle 148:
# Nodes: ('social distancing', 'ecq', 'rashes')
# Edges:
#   social distancing-ecq: 1.0
#   social distancing-rashes: 1.0
#   ecq-rashes: 1.0
#
# Triangle 149:
# Nodes: ('social distancing', 'ecq', 'sipon')
# Edges:
#   social distancing-ecq: 1.0
#   social distancing-sipon: 1.0
#   ecq-sipon: 1.0
#
# Triangle 150:
# Nodes: ('social distancing', 'ecq', 'ubo')
# Edges:
#   social distancing-ecq: 1.0
#   social distancing-ubo: 1.0
#   ecq-ubo: 1.0
#
# Triangle 151:
# Nodes: ('social distancing', 'Frontliners', 'flu')
# Edges:
#   social distancing-Frontliners: 1.0
#   social distancing-flu: 1.0
#   Frontliners-flu: 1.0
#
# Triangle 152:
# Nodes: ('social distancing', 'Frontliners', 'cough')
# Edges:
#   social distancing-Frontliners: 1.0
#   social distancing-cough: 1.0
#   Frontliners-cough: 1.0
#
# Triangle 153:
# Nodes: ('social distancing', 'Frontliners', 'fever')
# Edges:
#   social distancing-Frontliners: 1.0
#   social distancing-fever: 1.0
#   Frontliners-fever: 1.0
#
# Triangle 154:
# Nodes: ('social distancing', 'Frontliners', 'headache')
# Edges:
#   social distancing-Frontliners: 1.0
#   social distancing-headache: 1.0
#   Frontliners-headache: 1.0
#
# Triangle 155:
# Nodes: ('social distancing', 'Frontliners', 'lagnat')
# Edges:
#   social distancing-Frontliners: 1.0
#   social distancing-lagnat: 1.0
#   Frontliners-lagnat: 1.0
#
# Triangle 156:
# Nodes: ('social distancing', 'Frontliners', 'rashes')
# Edges:
#   social distancing-Frontliners: 1.0
#   social distancing-rashes: 1.0
#   Frontliners-rashes: 1.0
#
# Triangle 157:
# Nodes: ('social distancing', 'Frontliners', 'ubo')
# Edges:
#   social distancing-Frontliners: 1.0
#   social distancing-ubo: 1.0
#   Frontliners-ubo: 1.0
#
# Triangle 158:
# Nodes: ('social distancing', 'Frontliners', 'ecq')
# Edges:
#   social distancing-Frontliners: 1.0
#   social distancing-ecq: 1.0
#   Frontliners-ecq: 1.0
#
# Triangle 159:
# Nodes: ('social distancing', 'Quarantine', 'flu')
# Edges:
#   social distancing-Quarantine: 1.0
#   social distancing-flu: 1.0
#   Quarantine-flu: 1.0
#
# Triangle 160:
# Nodes: ('social distancing', 'Quarantine', 'cough')
# Edges:
#   social distancing-Quarantine: 1.0
#   social distancing-cough: 1.0
#   Quarantine-cough: 1.0
#
# Triangle 161:
# Nodes: ('social distancing', 'Quarantine', 'fever')
# Edges:
#   social distancing-Quarantine: 1.0
#   social distancing-fever: 1.0
#   Quarantine-fever: 1.0
#
# Triangle 162:
# Nodes: ('social distancing', 'Quarantine', 'lagnat')
# Edges:
#   social distancing-Quarantine: 1.0
#   social distancing-lagnat: 1.0
#   Quarantine-lagnat: 1.0
#
# Triangle 163:
# Nodes: ('social distancing', 'Quarantine', 'rashes')
# Edges:
#   social distancing-Quarantine: 1.0
#   social distancing-rashes: 1.0
#   Quarantine-rashes: 1.0
#
# Triangle 164:
# Nodes: ('social distancing', 'Quarantine', 'sipon')
# Edges:
#   social distancing-Quarantine: 1.0
#   social distancing-sipon: 1.0
#   Quarantine-sipon: 1.0
#
# Triangle 165:
# Nodes: ('social distancing', 'Quarantine', 'ubo')
# Edges:
#   social distancing-Quarantine: 1.0
#   social distancing-ubo: 1.0
#   Quarantine-ubo: 1.0
#
# Triangle 166:
# Nodes: ('social distancing', 'Quarantine', 'ecq')
# Edges:
#   social distancing-Quarantine: 1.0
#   social distancing-ecq: 1.0
#   Quarantine-ecq: 1.0
#
# Triangle 167:
# Nodes: ('social distancing', 'Quarantine', 'Frontliners')
# Edges:
#   social distancing-Quarantine: 1.0
#   social distancing-Frontliners: 1.0
#   Quarantine-Frontliners: 1.0
#
# Triangle 168:
# Nodes: ('work from home', 'fever', 'flu')
# Edges:
#   work from home-fever: 1.0
#   work from home-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 169:
# Nodes: ('work from home', 'headache', 'flu')
# Edges:
#   work from home-headache: 1.0
#   work from home-flu: 1.0
#   headache-flu: 1.0
#
# Triangle 170:
# Nodes: ('work from home', 'headache', 'fever')
# Edges:
#   work from home-headache: 1.0
#   work from home-fever: 1.0
#   headache-fever: 1.0
#
# Triangle 171:
# Nodes: ('work from home', 'lagnat', 'flu')
# Edges:
#   work from home-lagnat: 1.0
#   work from home-flu: 1.0
#   lagnat-flu: 1.0
#
# Triangle 172:
# Nodes: ('work from home', 'lagnat', 'fever')
# Edges:
#   work from home-lagnat: 1.0
#   work from home-fever: 1.0
#   lagnat-fever: 1.0
#
# Triangle 173:
# Nodes: ('work from home', 'rashes', 'flu')
# Edges:
#   work from home-rashes: 1.0
#   work from home-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 174:
# Nodes: ('work from home', 'rashes', 'fever')
# Edges:
#   work from home-rashes: 1.0
#   work from home-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 175:
# Nodes: ('work from home', 'rashes', 'headache')
# Edges:
#   work from home-rashes: 1.0
#   work from home-headache: 1.0
#   rashes-headache: 1.0
#
# Triangle 176:
# Nodes: ('work from home', 'rashes', 'lagnat')
# Edges:
#   work from home-rashes: 1.0
#   work from home-lagnat: 1.0
#   rashes-lagnat: 1.0
#
# Triangle 177:
# Nodes: ('work from home', 'sipon', 'flu')
# Edges:
#   work from home-sipon: 1.0
#   work from home-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 178:
# Nodes: ('work from home', 'sipon', 'fever')
# Edges:
#   work from home-sipon: 1.0
#   work from home-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 179:
# Nodes: ('work from home', 'sipon', 'lagnat')
# Edges:
#   work from home-sipon: 1.0
#   work from home-lagnat: 1.0
#   sipon-lagnat: 1.0
#
# Triangle 180:
# Nodes: ('work from home', 'ubo', 'flu')
# Edges:
#   work from home-ubo: 1.0
#   work from home-flu: 1.0
#   ubo-flu: 1.0
#
# Triangle 181:
# Nodes: ('work from home', 'ubo', 'fever')
# Edges:
#   work from home-ubo: 1.0
#   work from home-fever: 1.0
#   ubo-fever: 1.0
#
# Triangle 182:
# Nodes: ('work from home', 'ubo', 'lagnat')
# Edges:
#   work from home-ubo: 1.0
#   work from home-lagnat: 1.0
#   ubo-lagnat: 1.0
#
# Triangle 183:
# Nodes: ('work from home', 'ubo', 'sipon')
# Edges:
#   work from home-ubo: 1.0
#   work from home-sipon: 1.0
#   ubo-sipon: 1.0
#
# Triangle 184:
# Nodes: ('work from home', 'ecq', 'flu')
# Edges:
#   work from home-ecq: 1.0
#   work from home-flu: 1.0
#   ecq-flu: 1.0
#
# Triangle 185:
# Nodes: ('work from home', 'ecq', 'fever')
# Edges:
#   work from home-ecq: 1.0
#   work from home-fever: 1.0
#   ecq-fever: 1.0
#
# Triangle 186:
# Nodes: ('work from home', 'ecq', 'lagnat')
# Edges:
#   work from home-ecq: 1.0
#   work from home-lagnat: 1.0
#   ecq-lagnat: 1.0
#
# Triangle 187:
# Nodes: ('work from home', 'ecq', 'rashes')
# Edges:
#   work from home-ecq: 1.0
#   work from home-rashes: 1.0
#   ecq-rashes: 1.0
#
# Triangle 188:
# Nodes: ('work from home', 'ecq', 'sipon')
# Edges:
#   work from home-ecq: 1.0
#   work from home-sipon: 1.0
#   ecq-sipon: 1.0
#
# Triangle 189:
# Nodes: ('work from home', 'ecq', 'ubo')
# Edges:
#   work from home-ecq: 1.0
#   work from home-ubo: 1.0
#   ecq-ubo: 1.0
#
# Triangle 190:
# Nodes: ('work from home', 'face shield', 'flu')
# Edges:
#   work from home-face shield: 1.0
#   work from home-flu: 1.0
#   face shield-flu: 1.0
#
# Triangle 191:
# Nodes: ('work from home', 'face shield', 'fever')
# Edges:
#   work from home-face shield: 1.0
#   work from home-fever: 1.0
#   face shield-fever: 1.0
#
# Triangle 192:
# Nodes: ('work from home', 'face shield', 'headache')
# Edges:
#   work from home-face shield: 1.0
#   work from home-headache: 1.0
#   face shield-headache: 1.0
#
# Triangle 193:
# Nodes: ('work from home', 'face shield', 'lagnat')
# Edges:
#   work from home-face shield: 1.0
#   work from home-lagnat: 1.0
#   face shield-lagnat: 1.0
#
# Triangle 194:
# Nodes: ('work from home', 'face shield', 'rashes')
# Edges:
#   work from home-face shield: 1.0
#   work from home-rashes: 1.0
#   face shield-rashes: 1.0
#
# Triangle 195:
# Nodes: ('work from home', 'face shield', 'sipon')
# Edges:
#   work from home-face shield: 1.0
#   work from home-sipon: 1.0
#   face shield-sipon: 1.0
#
# Triangle 196:
# Nodes: ('work from home', 'Frontliners', 'flu')
# Edges:
#   work from home-Frontliners: 1.0
#   work from home-flu: 1.0
#   Frontliners-flu: 1.0
#
# Triangle 197:
# Nodes: ('work from home', 'Frontliners', 'fever')
# Edges:
#   work from home-Frontliners: 1.0
#   work from home-fever: 1.0
#   Frontliners-fever: 1.0
#
# Triangle 198:
# Nodes: ('work from home', 'Frontliners', 'headache')
# Edges:
#   work from home-Frontliners: 1.0
#   work from home-headache: 1.0
#   Frontliners-headache: 1.0
#
# Triangle 199:
# Nodes: ('work from home', 'Frontliners', 'lagnat')
# Edges:
#   work from home-Frontliners: 1.0
#   work from home-lagnat: 1.0
#   Frontliners-lagnat: 1.0
#
# Triangle 200:
# Nodes: ('work from home', 'Frontliners', 'rashes')
# Edges:
#   work from home-Frontliners: 1.0
#   work from home-rashes: 1.0
#   Frontliners-rashes: 1.0
#
# Triangle 201:
# Nodes: ('work from home', 'Frontliners', 'ubo')
# Edges:
#   work from home-Frontliners: 1.0
#   work from home-ubo: 1.0
#   Frontliners-ubo: 1.0
#
# Triangle 202:
# Nodes: ('work from home', 'Frontliners', 'ecq')
# Edges:
#   work from home-Frontliners: 1.0
#   work from home-ecq: 1.0
#   Frontliners-ecq: 1.0
#
# Triangle 203:
# Nodes: ('work from home', 'Frontliners', 'face shield')
# Edges:
#   work from home-Frontliners: 1.0
#   work from home-face shield: 1.0
#   Frontliners-face shield: 1.0
#
# Triangle 204:
# Nodes: ('work from home', 'masks', 'fever')
# Edges:
#   work from home-masks: 1.0
#   work from home-fever: 1.0
#   masks-fever: 1.0
#
# Triangle 205:
# Nodes: ('work from home', 'masks', 'face shield')
# Edges:
#   work from home-masks: 1.0
#   work from home-face shield: 1.0
#   masks-face shield: 1.0
#
# Triangle 206:
# Nodes: ('work from home', 'Quarantine', 'flu')
# Edges:
#   work from home-Quarantine: 1.0
#   work from home-flu: 1.0
#   Quarantine-flu: 1.0
#
# Triangle 207:
# Nodes: ('work from home', 'Quarantine', 'fever')
# Edges:
#   work from home-Quarantine: 1.0
#   work from home-fever: 1.0
#   Quarantine-fever: 1.0
#
# Triangle 208:
# Nodes: ('work from home', 'Quarantine', 'lagnat')
# Edges:
#   work from home-Quarantine: 1.0
#   work from home-lagnat: 1.0
#   Quarantine-lagnat: 1.0
#
# Triangle 209:
# Nodes: ('work from home', 'Quarantine', 'rashes')
# Edges:
#   work from home-Quarantine: 1.0
#   work from home-rashes: 1.0
#   Quarantine-rashes: 1.0
#
# Triangle 210:
# Nodes: ('work from home', 'Quarantine', 'sipon')
# Edges:
#   work from home-Quarantine: 1.0
#   work from home-sipon: 1.0
#   Quarantine-sipon: 1.0
#
# Triangle 211:
# Nodes: ('work from home', 'Quarantine', 'ubo')
# Edges:
#   work from home-Quarantine: 1.0
#   work from home-ubo: 1.0
#   Quarantine-ubo: 1.0
#
# Triangle 212:
# Nodes: ('work from home', 'Quarantine', 'ecq')
# Edges:
#   work from home-Quarantine: 1.0
#   work from home-ecq: 1.0
#   Quarantine-ecq: 1.0
#
# Triangle 213:
# Nodes: ('work from home', 'Quarantine', 'face shield')
# Edges:
#   work from home-Quarantine: 1.0
#   work from home-face shield: 1.0
#   Quarantine-face shield: 1.0
#
# Triangle 214:
# Nodes: ('work from home', 'Quarantine', 'Frontliners')
# Edges:
#   work from home-Quarantine: 1.0
#   work from home-Frontliners: 1.0
#   Quarantine-Frontliners: 1.0
#
# Triangle 215:
# Nodes: ('work from home', 'social distancing', 'flu')
# Edges:
#   work from home-social distancing: 1.0
#   work from home-flu: 1.0
#   social distancing-flu: 1.0
#
# Triangle 216:
# Nodes: ('work from home', 'social distancing', 'fever')
# Edges:
#   work from home-social distancing: 1.0
#   work from home-fever: 1.0
#   social distancing-fever: 1.0
#
# Triangle 217:
# Nodes: ('work from home', 'social distancing', 'headache')
# Edges:
#   work from home-social distancing: 1.0
#   work from home-headache: 1.0
#   social distancing-headache: 1.0
#
# Triangle 218:
# Nodes: ('work from home', 'social distancing', 'lagnat')
# Edges:
#   work from home-social distancing: 1.0
#   work from home-lagnat: 1.0
#   social distancing-lagnat: 1.0
#
# Triangle 219:
# Nodes: ('work from home', 'social distancing', 'rashes')
# Edges:
#   work from home-social distancing: 1.0
#   work from home-rashes: 1.0
#   social distancing-rashes: 1.0
#
# Triangle 220:
# Nodes: ('work from home', 'social distancing', 'sipon')
# Edges:
#   work from home-social distancing: 1.0
#   work from home-sipon: 1.0
#   social distancing-sipon: 1.0
#
# Triangle 221:
# Nodes: ('work from home', 'social distancing', 'ubo')
# Edges:
#   work from home-social distancing: 1.0
#   work from home-ubo: 1.0
#   social distancing-ubo: 1.0
#
# Triangle 222:
# Nodes: ('work from home', 'social distancing', 'ecq')
# Edges:
#   work from home-social distancing: 1.0
#   work from home-ecq: 1.0
#   social distancing-ecq: 1.0
#
# Triangle 223:
# Nodes: ('work from home', 'social distancing', 'Frontliners')
# Edges:
#   work from home-social distancing: 1.0
#   work from home-Frontliners: 1.0
#   social distancing-Frontliners: 1.0
#
# Triangle 224:
# Nodes: ('work from home', 'social distancing', 'Quarantine')
# Edges:
#   work from home-social distancing: 1.0
#   work from home-Quarantine: 1.0
#   social distancing-Quarantine: 1.0
#
# ============================================
# Processed successfully: coefficient = 0.49230769230769234
#
# Processing msv_0.4_2020_04_02.csv
# Processed successfully: coefficient = 0.47692307692307695
#
# Processing msv_0.4_2020_04_03.csv
# Processed successfully: coefficient = 0.3868131868131868
#
# Processing msv_0.4_2020_04_04.csv
# Processed successfully: coefficient = 0.4043956043956044
#
# Processing msv_0.4_2020_04_05.csv
# Processed successfully: coefficient = 0.5626373626373626
#
# Processing msv_0.4_2020_04_06.csv
#
# Debugging Clustering Coefficient Calculation:
# Total possible triplets (denominator): 455
# ============================================
#
# Total triangles found: 239
# Clustering coefficient: 0.5252747252747253
#
# Triangles found:
#
# Triangle 1:
# Nodes: ('fever', 'cough', 'flu')
# Edges:
#   fever-cough: 1.0
#   fever-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 2:
# Nodes: ('rashes', 'cough', 'flu')
# Edges:
#   rashes-cough: 1.0
#   rashes-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 3:
# Nodes: ('rashes', 'fever', 'flu')
# Edges:
#   rashes-fever: 1.0
#   rashes-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 4:
# Nodes: ('rashes', 'fever', 'cough')
# Edges:
#   rashes-fever: 1.0
#   rashes-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 5:
# Nodes: ('rashes', 'headache', 'fever')
# Edges:
#   rashes-headache: 1.0
#   rashes-fever: 1.0
#   headache-fever: 1.0
#
# Triangle 6:
# Nodes: ('rashes', 'lagnat', 'cough')
# Edges:
#   rashes-lagnat: 1.0
#   rashes-cough: 1.0
#   lagnat-cough: 1.0
#
# Triangle 7:
# Nodes: ('sipon', 'cough', 'flu')
# Edges:
#   sipon-cough: 1.0
#   sipon-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 8:
# Nodes: ('sipon', 'fever', 'flu')
# Edges:
#   sipon-fever: 1.0
#   sipon-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 9:
# Nodes: ('sipon', 'fever', 'cough')
# Edges:
#   sipon-fever: 1.0
#   sipon-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 10:
# Nodes: ('ubo', 'cough', 'flu')
# Edges:
#   ubo-cough: 1.0
#   ubo-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 11:
# Nodes: ('ubo', 'fever', 'flu')
# Edges:
#   ubo-fever: 1.0
#   ubo-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 12:
# Nodes: ('ubo', 'fever', 'cough')
# Edges:
#   ubo-fever: 1.0
#   ubo-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 13:
# Nodes: ('ubo', 'headache', 'fever')
# Edges:
#   ubo-headache: 1.0
#   ubo-fever: 1.0
#   headache-fever: 1.0
#
# Triangle 14:
# Nodes: ('ubo', 'lagnat', 'cough')
# Edges:
#   ubo-lagnat: 1.0
#   ubo-cough: 1.0
#   lagnat-cough: 1.0
#
# Triangle 15:
# Nodes: ('ubo', 'rashes', 'flu')
# Edges:
#   ubo-rashes: 1.0
#   ubo-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 16:
# Nodes: ('ubo', 'rashes', 'cough')
# Edges:
#   ubo-rashes: 1.0
#   ubo-cough: 1.0
#   rashes-cough: 1.0
#
# Triangle 17:
# Nodes: ('ubo', 'rashes', 'fever')
# Edges:
#   ubo-rashes: 1.0
#   ubo-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 18:
# Nodes: ('ubo', 'rashes', 'headache')
# Edges:
#   ubo-rashes: 1.0
#   ubo-headache: 1.0
#   rashes-headache: 1.0
#
# Triangle 19:
# Nodes: ('ubo', 'rashes', 'lagnat')
# Edges:
#   ubo-rashes: 1.0
#   ubo-lagnat: 1.0
#   rashes-lagnat: 1.0
#
# Triangle 20:
# Nodes: ('ubo', 'sipon', 'flu')
# Edges:
#   ubo-sipon: 1.0
#   ubo-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 21:
# Nodes: ('ubo', 'sipon', 'cough')
# Edges:
#   ubo-sipon: 1.0
#   ubo-cough: 1.0
#   sipon-cough: 1.0
#
# Triangle 22:
# Nodes: ('ubo', 'sipon', 'fever')
# Edges:
#   ubo-sipon: 1.0
#   ubo-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 23:
# Nodes: ('ecq', 'cough', 'flu')
# Edges:
#   ecq-cough: 1.0
#   ecq-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 24:
# Nodes: ('ecq', 'fever', 'flu')
# Edges:
#   ecq-fever: 1.0
#   ecq-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 25:
# Nodes: ('ecq', 'fever', 'cough')
# Edges:
#   ecq-fever: 1.0
#   ecq-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 26:
# Nodes: ('ecq', 'rashes', 'flu')
# Edges:
#   ecq-rashes: 1.0
#   ecq-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 27:
# Nodes: ('ecq', 'rashes', 'cough')
# Edges:
#   ecq-rashes: 1.0
#   ecq-cough: 1.0
#   rashes-cough: 1.0
#
# Triangle 28:
# Nodes: ('ecq', 'rashes', 'fever')
# Edges:
#   ecq-rashes: 1.0
#   ecq-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 29:
# Nodes: ('ecq', 'sipon', 'flu')
# Edges:
#   ecq-sipon: 1.0
#   ecq-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 30:
# Nodes: ('ecq', 'sipon', 'cough')
# Edges:
#   ecq-sipon: 1.0
#   ecq-cough: 1.0
#   sipon-cough: 1.0
#
# Triangle 31:
# Nodes: ('ecq', 'sipon', 'fever')
# Edges:
#   ecq-sipon: 1.0
#   ecq-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 32:
# Nodes: ('ecq', 'ubo', 'flu')
# Edges:
#   ecq-ubo: 1.0
#   ecq-flu: 1.0
#   ubo-flu: 1.0
#
# Triangle 33:
# Nodes: ('ecq', 'ubo', 'cough')
# Edges:
#   ecq-ubo: 1.0
#   ecq-cough: 1.0
#   ubo-cough: 1.0
#
# Triangle 34:
# Nodes: ('ecq', 'ubo', 'fever')
# Edges:
#   ecq-ubo: 1.0
#   ecq-fever: 1.0
#   ubo-fever: 1.0
#
# Triangle 35:
# Nodes: ('ecq', 'ubo', 'rashes')
# Edges:
#   ecq-ubo: 1.0
#   ecq-rashes: 1.0
#   ubo-rashes: 1.0
#
# Triangle 36:
# Nodes: ('ecq', 'ubo', 'sipon')
# Edges:
#   ecq-ubo: 1.0
#   ecq-sipon: 1.0
#   ubo-sipon: 1.0
#
# Triangle 37:
# Nodes: ('face shield', 'fever', 'flu')
# Edges:
#   face shield-fever: 1.0
#   face shield-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 38:
# Nodes: ('face shield', 'headache', 'fever')
# Edges:
#   face shield-headache: 1.0
#   face shield-fever: 1.0
#   headache-fever: 1.0
#
# Triangle 39:
# Nodes: ('face shield', 'rashes', 'flu')
# Edges:
#   face shield-rashes: 1.0
#   face shield-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 40:
# Nodes: ('face shield', 'rashes', 'fever')
# Edges:
#   face shield-rashes: 1.0
#   face shield-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 41:
# Nodes: ('face shield', 'rashes', 'headache')
# Edges:
#   face shield-rashes: 1.0
#   face shield-headache: 1.0
#   rashes-headache: 1.0
#
# Triangle 42:
# Nodes: ('face shield', 'sipon', 'flu')
# Edges:
#   face shield-sipon: 1.0
#   face shield-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 43:
# Nodes: ('face shield', 'sipon', 'fever')
# Edges:
#   face shield-sipon: 1.0
#   face shield-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 44:
# Nodes: ('face shield', 'ubo', 'flu')
# Edges:
#   face shield-ubo: 1.0
#   face shield-flu: 1.0
#   ubo-flu: 1.0
#
# Triangle 45:
# Nodes: ('face shield', 'ubo', 'fever')
# Edges:
#   face shield-ubo: 1.0
#   face shield-fever: 1.0
#   ubo-fever: 1.0
#
# Triangle 46:
# Nodes: ('face shield', 'ubo', 'headache')
# Edges:
#   face shield-ubo: 1.0
#   face shield-headache: 1.0
#   ubo-headache: 1.0
#
# Triangle 47:
# Nodes: ('face shield', 'ubo', 'rashes')
# Edges:
#   face shield-ubo: 1.0
#   face shield-rashes: 1.0
#   ubo-rashes: 1.0
#
# Triangle 48:
# Nodes: ('face shield', 'ubo', 'sipon')
# Edges:
#   face shield-ubo: 1.0
#   face shield-sipon: 1.0
#   ubo-sipon: 1.0
#
# Triangle 49:
# Nodes: ('Frontliners', 'cough', 'flu')
# Edges:
#   Frontliners-cough: 1.0
#   Frontliners-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 50:
# Nodes: ('Frontliners', 'fever', 'flu')
# Edges:
#   Frontliners-fever: 1.0
#   Frontliners-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 51:
# Nodes: ('Frontliners', 'fever', 'cough')
# Edges:
#   Frontliners-fever: 1.0
#   Frontliners-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 52:
# Nodes: ('Frontliners', 'headache', 'fever')
# Edges:
#   Frontliners-headache: 1.0
#   Frontliners-fever: 1.0
#   headache-fever: 1.0
#
# Triangle 53:
# Nodes: ('Frontliners', 'rashes', 'flu')
# Edges:
#   Frontliners-rashes: 1.0
#   Frontliners-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 54:
# Nodes: ('Frontliners', 'rashes', 'cough')
# Edges:
#   Frontliners-rashes: 1.0
#   Frontliners-cough: 1.0
#   rashes-cough: 1.0
#
# Triangle 55:
# Nodes: ('Frontliners', 'rashes', 'fever')
# Edges:
#   Frontliners-rashes: 1.0
#   Frontliners-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 56:
# Nodes: ('Frontliners', 'rashes', 'headache')
# Edges:
#   Frontliners-rashes: 1.0
#   Frontliners-headache: 1.0
#   rashes-headache: 1.0
#
# Triangle 57:
# Nodes: ('Frontliners', 'sipon', 'flu')
# Edges:
#   Frontliners-sipon: 1.0
#   Frontliners-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 58:
# Nodes: ('Frontliners', 'sipon', 'cough')
# Edges:
#   Frontliners-sipon: 1.0
#   Frontliners-cough: 1.0
#   sipon-cough: 1.0
#
# Triangle 59:
# Nodes: ('Frontliners', 'sipon', 'fever')
# Edges:
#   Frontliners-sipon: 1.0
#   Frontliners-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 60:
# Nodes: ('Frontliners', 'ubo', 'flu')
# Edges:
#   Frontliners-ubo: 1.0
#   Frontliners-flu: 1.0
#   ubo-flu: 1.0
#
# Triangle 61:
# Nodes: ('Frontliners', 'ubo', 'cough')
# Edges:
#   Frontliners-ubo: 1.0
#   Frontliners-cough: 1.0
#   ubo-cough: 1.0
#
# Triangle 62:
# Nodes: ('Frontliners', 'ubo', 'fever')
# Edges:
#   Frontliners-ubo: 1.0
#   Frontliners-fever: 1.0
#   ubo-fever: 1.0
#
# Triangle 63:
# Nodes: ('Frontliners', 'ubo', 'headache')
# Edges:
#   Frontliners-ubo: 1.0
#   Frontliners-headache: 1.0
#   ubo-headache: 1.0
#
# Triangle 64:
# Nodes: ('Frontliners', 'ubo', 'rashes')
# Edges:
#   Frontliners-ubo: 1.0
#   Frontliners-rashes: 1.0
#   ubo-rashes: 1.0
#
# Triangle 65:
# Nodes: ('Frontliners', 'ubo', 'sipon')
# Edges:
#   Frontliners-ubo: 1.0
#   Frontliners-sipon: 1.0
#   ubo-sipon: 1.0
#
# Triangle 66:
# Nodes: ('Frontliners', 'ecq', 'flu')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-flu: 1.0
#   ecq-flu: 1.0
#
# Triangle 67:
# Nodes: ('Frontliners', 'ecq', 'cough')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-cough: 1.0
#   ecq-cough: 1.0
#
# Triangle 68:
# Nodes: ('Frontliners', 'ecq', 'fever')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-fever: 1.0
#   ecq-fever: 1.0
#
# Triangle 69:
# Nodes: ('Frontliners', 'ecq', 'rashes')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-rashes: 1.0
#   ecq-rashes: 1.0
#
# Triangle 70:
# Nodes: ('Frontliners', 'ecq', 'sipon')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-sipon: 1.0
#   ecq-sipon: 1.0
#
# Triangle 71:
# Nodes: ('Frontliners', 'ecq', 'ubo')
# Edges:
#   Frontliners-ecq: 1.0
#   Frontliners-ubo: 1.0
#   ecq-ubo: 1.0
#
# Triangle 72:
# Nodes: ('masks', 'cough', 'flu')
# Edges:
#   masks-cough: 1.0
#   masks-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 73:
# Nodes: ('masks', 'fever', 'flu')
# Edges:
#   masks-fever: 1.0
#   masks-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 74:
# Nodes: ('masks', 'fever', 'cough')
# Edges:
#   masks-fever: 1.0
#   masks-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 75:
# Nodes: ('masks', 'headache', 'fever')
# Edges:
#   masks-headache: 1.0
#   masks-fever: 1.0
#   headache-fever: 1.0
#
# Triangle 76:
# Nodes: ('masks', 'rashes', 'flu')
# Edges:
#   masks-rashes: 1.0
#   masks-flu: 1.0
#   rashes-flu: 1.0
#
# Triangle 77:
# Nodes: ('masks', 'rashes', 'cough')
# Edges:
#   masks-rashes: 1.0
#   masks-cough: 1.0
#   rashes-cough: 1.0
#
# Triangle 78:
# Nodes: ('masks', 'rashes', 'fever')
# Edges:
#   masks-rashes: 1.0
#   masks-fever: 1.0
#   rashes-fever: 1.0
#
# Triangle 79:
# Nodes: ('masks', 'rashes', 'headache')
# Edges:
#   masks-rashes: 1.0
#   masks-headache: 1.0
#   rashes-headache: 1.0
#
# Triangle 80:
# Nodes: ('masks', 'sipon', 'flu')
# Edges:
#   masks-sipon: 1.0
#   masks-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 81:
# Nodes: ('masks', 'sipon', 'cough')
# Edges:
#   masks-sipon: 1.0
#   masks-cough: 1.0
#   sipon-cough: 1.0
#
# Triangle 82:
# Nodes: ('masks', 'sipon', 'fever')
# Edges:
#   masks-sipon: 1.0
#   masks-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 83:
# Nodes: ('masks', 'ubo', 'flu')
# Edges:
#   masks-ubo: 1.0
#   masks-flu: 1.0
#   ubo-flu: 1.0
#
# Triangle 84:
# Nodes: ('masks', 'ubo', 'cough')
# Edges:
#   masks-ubo: 1.0
#   masks-cough: 1.0
#   ubo-cough: 1.0
#
# Triangle 85:
# Nodes: ('masks', 'ubo', 'fever')
# Edges:
#   masks-ubo: 1.0
#   masks-fever: 1.0
#   ubo-fever: 1.0
#
# Triangle 86:
# Nodes: ('masks', 'ubo', 'headache')
# Edges:
#   masks-ubo: 1.0
#   masks-headache: 1.0
#   ubo-headache: 1.0
#
# Triangle 87:
# Nodes: ('masks', 'ubo', 'rashes')
# Edges:
#   masks-ubo: 1.0
#   masks-rashes: 1.0
#   ubo-rashes: 1.0
#
# Triangle 88:
# Nodes: ('masks', 'ubo', 'sipon')
# Edges:
#   masks-ubo: 1.0
#   masks-sipon: 1.0
#   ubo-sipon: 1.0
#
# Triangle 89:
# Nodes: ('masks', 'ecq', 'flu')
# Edges:
#   masks-ecq: 1.0
#   masks-flu: 1.0
#   ecq-flu: 1.0
#
# Triangle 90:
# Nodes: ('masks', 'ecq', 'cough')
# Edges:
#   masks-ecq: 1.0
#   masks-cough: 1.0
#   ecq-cough: 1.0
#
# Triangle 91:
# Nodes: ('masks', 'ecq', 'fever')
# Edges:
#   masks-ecq: 1.0
#   masks-fever: 1.0
#   ecq-fever: 1.0
#
# Triangle 92:
# Nodes: ('masks', 'ecq', 'rashes')
# Edges:
#   masks-ecq: 1.0
#   masks-rashes: 1.0
#   ecq-rashes: 1.0
#
# Triangle 93:
# Nodes: ('masks', 'ecq', 'sipon')
# Edges:
#   masks-ecq: 1.0
#   masks-sipon: 1.0
#   ecq-sipon: 1.0
#
# Triangle 94:
# Nodes: ('masks', 'ecq', 'ubo')
# Edges:
#   masks-ecq: 1.0
#   masks-ubo: 1.0
#   ecq-ubo: 1.0
#
# Triangle 95:
# Nodes: ('masks', 'face shield', 'flu')
# Edges:
#   masks-face shield: 1.0
#   masks-flu: 1.0
#   face shield-flu: 1.0
#
# Triangle 96:
# Nodes: ('masks', 'face shield', 'fever')
# Edges:
#   masks-face shield: 1.0
#   masks-fever: 1.0
#   face shield-fever: 1.0
#
# Triangle 97:
# Nodes: ('masks', 'face shield', 'headache')
# Edges:
#   masks-face shield: 1.0
#   masks-headache: 1.0
#   face shield-headache: 1.0
#
# Triangle 98:
# Nodes: ('masks', 'face shield', 'rashes')
# Edges:
#   masks-face shield: 1.0
#   masks-rashes: 1.0
#   face shield-rashes: 1.0
#
# Triangle 99:
# Nodes: ('masks', 'face shield', 'sipon')
# Edges:
#   masks-face shield: 1.0
#   masks-sipon: 1.0
#   face shield-sipon: 1.0
#
# Triangle 100:
# Nodes: ('masks', 'face shield', 'ubo')
# Edges:
#   masks-face shield: 1.0
#   masks-ubo: 1.0
#   face shield-ubo: 1.0
#
# Triangle 101:
# Nodes: ('masks', 'Frontliners', 'flu')
# Edges:
#   masks-Frontliners: 1.0
#   masks-flu: 1.0
#   Frontliners-flu: 1.0
#
# Triangle 102:
# Nodes: ('masks', 'Frontliners', 'cough')
# Edges:
#   masks-Frontliners: 1.0
#   masks-cough: 1.0
#   Frontliners-cough: 1.0
#
# Triangle 103:
# Nodes: ('masks', 'Frontliners', 'fever')
# Edges:
#   masks-Frontliners: 1.0
#   masks-fever: 1.0
#   Frontliners-fever: 1.0
#
# Triangle 104:
# Nodes: ('masks', 'Frontliners', 'headache')
# Edges:
#   masks-Frontliners: 1.0
#   masks-headache: 1.0
#   Frontliners-headache: 1.0
#
# Triangle 105:
# Nodes: ('masks', 'Frontliners', 'rashes')
# Edges:
#   masks-Frontliners: 1.0
#   masks-rashes: 1.0
#   Frontliners-rashes: 1.0
#
# Triangle 106:
# Nodes: ('masks', 'Frontliners', 'sipon')
# Edges:
#   masks-Frontliners: 1.0
#   masks-sipon: 1.0
#   Frontliners-sipon: 1.0
#
# Triangle 107:
# Nodes: ('masks', 'Frontliners', 'ubo')
# Edges:
#   masks-Frontliners: 1.0
#   masks-ubo: 1.0
#   Frontliners-ubo: 1.0
#
# Triangle 108:
# Nodes: ('masks', 'Frontliners', 'ecq')
# Edges:
#   masks-Frontliners: 1.0
#   masks-ecq: 1.0
#   Frontliners-ecq: 1.0
#
# Triangle 109:
# Nodes: ('Quarantine', 'cough', 'flu')
# Edges:
#   Quarantine-cough: 1.0
#   Quarantine-flu: 1.0
#   cough-flu: 1.0
#
# Triangle 110:
# Nodes: ('Quarantine', 'fever', 'flu')
# Edges:
#   Quarantine-fever: 1.0
#   Quarantine-flu: 1.0
#   fever-flu: 1.0
#
# Triangle 111:
# Nodes: ('Quarantine', 'fever', 'cough')
# Edges:
#   Quarantine-fever: 1.0
#   Quarantine-cough: 1.0
#   fever-cough: 1.0
#
# Triangle 112:
# Nodes: ('Quarantine', 'lagnat', 'cough')
# Edges:
#   Quarantine-lagnat: 1.0
#   Quarantine-cough: 1.0
#   lagnat-cough: 1.0
#
# Triangle 113:
# Nodes: ('Quarantine', 'sipon', 'flu')
# Edges:
#   Quarantine-sipon: 1.0
#   Quarantine-flu: 1.0
#   sipon-flu: 1.0
#
# Triangle 114:
# Nodes: ('Quarantine', 'sipon', 'cough')
# Edges:
#   Quarantine-sipon: 1.0
#   Quarantine-cough: 1.0
#   sipon-cough: 1.0
#
# Triangle 115:
# Nodes: ('Quarantine', 'sipon', 'fever')
# Edges:
#   Quarantine-sipon: 1.0
#   Quarantine-fever: 1.0
#   sipon-fever: 1.0
#
# Triangle 116:
# Nodes: ('Quarantine', 'ubo', 'flu')
# Edges:
#   Quarantine-ubo: 1.0
#   Quarantine-flu: 1.0
#   ubo-flu: 1.0
#
# Triangle 117:
# Nodes: ('Quarantine', 'ubo', 'cough')
# Edges:
#   Quarantine-ubo: 1.0
#   Quarantine-cough: 1.0
#   ubo-cough: 1.0
#
# Triangle 118:
# Nodes: ('Quarantine', 'ubo', 'fever')
# Edges:
#   Quarantine-ubo: 1.0
#   Quarantine-fever: 1.0
#   ubo-fever: 1.0
#
# Triangle 119:
# Nodes: ('Quarantine', 'ubo', 'lagnat')
# Edges:
#   Quarantine-ubo: 1.0
#   Quarantine-lagnat: 1.0
#   ubo-lagnat: 1.0
#
# Triangle 120:
# Nodes: ('Quarantine', 'ubo', 'sipon')
# Edges:
#   Quarantine-ubo: 1.0
#   Quarantine-sipon: 1.0
#   ubo-sipon: 1.0
#
# Triangle 121:
# Nodes: ('Quarantine', 'ecq', 'flu')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-flu: 1.0
#   ecq-flu: 1.0
#
# Triangle 122:
# Nodes: ('Quarantine', 'ecq', 'cough')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-cough: 1.0
#   ecq-cough: 1.0
#
# Triangle 123:
# Nodes: ('Quarantine', 'ecq', 'fever')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-fever: 1.0
#   ecq-fever: 1.0
#
# Triangle 124:
# Nodes: ('Quarantine', 'ecq', 'sipon')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-sipon: 1.0
#   ecq-sipon: 1.0
#
# Triangle 125:
# Nodes: ('Quarantine', 'ecq', 'ubo')
# Edges:
#   Quarantine-ecq: 1.0
#   Quarantine-ubo: 1.0
#   ecq-ubo: 1.0
#
# Triangle 126:
# Nodes: ('Quarantine', 'Frontliners', 'flu')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-flu: 1.0
#   Frontliners-flu: 1.0
#
# Triangle 127:
# Nodes: ('Quarantine', 'Frontliners', 'cough')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-cough: 1.0
#   Frontliners-cough: 1.0
#
# Triangle 128:
# Nodes: ('Quarantine', 'Frontliners', 'fever')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-fever: 1.0
#   Frontliners-fever: 1.0
#
# Triangle 129:
# Nodes: ('Quarantine', 'Frontliners', 'sipon')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-sipon: 1.0
#   Frontliners-sipon: 1.0
#
# Triangle 130:
# Nodes: ('Quarantine', 'Frontliners', 'ubo')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-ubo: 1.0
#   Frontliners-ubo: 1.0
#
# Triangle 131:
# Nodes: ('Quarantine', 'Frontliners', 'ecq')
# Edges:
#   Quarantine-Frontliners: 1.0
#   Quarantine-ecq: 1.0
#   Frontliners-ecq: 1.0
#
# Triangle 132:
# Nodes: ('Quarantine', 'masks', 'flu')
# Edges:
#   Quarantine-masks: 1.0
#   Quarantine-flu: 1.0
#   masks-flu: 1.0
#
# Triangle 133:
# ...
#
# Processing rsv_0.8_2020_08_23.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_08_24.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_08_25.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_08_26.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_08_27.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_08_28.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_08_29.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_08_30.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_08_31.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_01.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_02.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_03.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_04.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_05.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_06.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_07.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_08.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_09.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_10.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_11.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_12.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_13.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_14.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_15.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_16.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_17.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_18.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_19.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_20.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_21.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_22.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_23.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_24.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_25.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_26.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_27.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_28.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_29.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_09_30.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_01.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_02.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_03.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_04.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_05.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_06.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_07.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_08.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_09.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_10.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_11.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_12.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_13.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_14.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_15.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_16.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_17.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_18.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_19.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_20.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_21.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_22.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_23.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_24.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_25.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_26.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_27.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_28.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_29.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_30.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_10_31.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_01.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_02.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_03.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_04.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_05.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_06.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_07.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_08.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_09.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_10.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_11.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_12.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_13.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_14.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_15.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_16.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_17.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_18.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_19.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_20.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_21.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_22.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_23.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_24.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_25.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_26.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_27.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_28.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_29.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_11_30.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_01.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_02.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_03.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_04.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_05.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_06.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_07.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_08.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_09.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_10.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_11.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_12.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_13.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_14.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_15.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_16.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_17.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_18.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_19.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_20.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_21.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_22.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_23.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_24.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_25.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_26.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_27.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_28.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_29.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_30.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2020_12_31.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_01.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_02.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_03.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_04.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_05.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_06.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_07.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_08.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_09.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_10.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_11.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_12.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_13.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_14.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_15.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_16.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_17.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_18.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_19.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_20.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_21.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_22.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_23.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_24.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_25.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_26.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_27.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_28.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_29.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_30.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_01_31.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_01.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_02.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_03.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_04.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_05.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_06.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_07.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_08.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_09.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_10.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_11.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_12.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_13.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_14.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_15.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_16.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_17.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_18.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_19.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_20.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_21.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_22.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_23.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_24.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_25.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_26.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_27.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_02_28.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_01.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_02.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_03.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_04.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_05.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_06.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_07.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_08.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_09.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_10.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_11.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_12.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_13.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_14.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_15.csv
# Processed successfully: coefficient = 0.0
#
# Processing rsv_0.8_2021_03_16.csv
# Processed successfully: coefficient = 0.0
# Created cluscoeff_rsv_0.8_30day.csv with 337 entries
#
# Clustering coefficient calculation completed
