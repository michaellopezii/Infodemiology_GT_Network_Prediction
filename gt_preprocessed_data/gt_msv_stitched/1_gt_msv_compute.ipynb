# %%
import pandas as pd
import os
from datetime import datetime, timedelta
import glob
import numpy as np

# %%
# Process all tags
tags = [
    "flu", "cough", "fever", "headache", "lagnat", "rashes",
    "sipon", "ubo", "ecq", "face-shield", "Frontliners",
    "masks", "Quarantine", "social-distancing", "work-from-home"
]

# %%
def load_csv_file(filepath):
    """Load a CSV file and remove the 'isPartial' column."""
    df = pd.read_csv(filepath)
    return df.drop('isPartial', axis=1, errors='ignore')

# %%
def get_correction_factor(first_file_df, second_file_df, tag_column):
    """Calculate correction factor between two consecutive files."""
    # Get all dates that appear in both files
    common_dates = list(set(first_file_df['date']) & set(second_file_df['date']))
    common_dates.sort()  # Ensure dates are in order
    
    # For 30-day window, we need 29 quotients
    required_quotients = 29
    
    if len(common_dates) < required_quotients:
        print(f"Warning: Only found {len(common_dates)} common dates, needed {required_quotients}")
        return 1.0
    
    # Take only the first required_quotients number of dates
    common_dates = common_dates[:required_quotients]
    
    quotients = []
    for date in common_dates:
        first_value = first_file_df[first_file_df['date'] == date][tag_column].iloc[0]
        second_value = second_file_df[second_file_df['date'] == date][tag_column].iloc[0]
        
        try:
            if second_value == 0 or np.isnan(first_value) or np.isnan(second_value):
                quotient = 1.0
            else:
                quotient = first_value / second_value
                if not np.isreal(quotient) or np.isinf(quotient) or np.isnan(quotient):
                    quotient = 1.0
        except:
            quotient = 1.0
            
        quotients.append(quotient)
    
    correction_factor = sum(quotients) / required_quotients
    return correction_factor

# %%
def process_tag_files(tag):
    """Process all CSV files for a given tag."""
    tag_column = tag.replace('-', ' ')
    folder_path = f"../../gt_raw_daily30daywindow_volumes/{tag}"
    csv_files = sorted(glob.glob(os.path.join(folder_path, "*.csv")))
    
    if not csv_files:
        print(f"No CSV files found for tag: {tag}")
        return None
    
    # Initialize result DataFrame with first file's initial days
    first_file_df = load_csv_file(csv_files[0])
    initial_days = 29  # 29 days for 30-day window
    result_df = first_file_df.head(initial_days).copy()
    
    # Define cutoff date
    CUTOFF_DATE = '2021-03-15'
    
    # Keep track of the last processed date
    last_processed_date = None
    
    # Process files in pairs
    for i in range(len(csv_files) - 1):
        current_file = csv_files[i]
        next_file = csv_files[i + 1]
        
        print(f"Processing files: {os.path.basename(current_file)} and {os.path.basename(next_file)}")
        
        # Load the CSV files
        current_df = load_csv_file(current_file)
        next_df = load_csv_file(next_file)
        
        # Get all dates from both files
        all_dates = sorted(list(set(current_df['date'].tolist() + next_df['date'].tolist())))
        
        # If we have a gap from last processed date, fill it using the last correction factor
        if last_processed_date is not None:
            last_processed_datetime = datetime.strptime(last_processed_date, '%Y-%m-%d')
            current_start_datetime = datetime.strptime(min(all_dates), '%Y-%m-%d')
            
            if (current_start_datetime - last_processed_datetime).days > 1:
                # Generate missing dates
                missing_date = last_processed_datetime + timedelta(days=1)
                while missing_date < current_start_datetime:
                    missing_date_str = missing_date.strftime('%Y-%m-%d')
                    
                    # Use the last available value and correction factor
                    if missing_date_str <= CUTOFF_DATE:
                        last_value = result_df.iloc[-1][tag_column]
                        
                        # Add to result DataFrame
                        new_row = pd.DataFrame({
                            'date': [missing_date_str],
                            tag_column: [last_value]  # Use last value for gap filling
                        })
                        result_df = pd.concat([result_df, new_row], ignore_index=True)
                    
                    missing_date += timedelta(days=1)
        
        # Calculate correction factor and process normal dates
        correction_factor = get_correction_factor(current_df, next_df, tag_column)
        
        target_dates = sorted(next_df['date'].unique())
        if len(target_dates) >= 30:  # 30-day window
            target_date = target_dates[29]  # Get the 30th day
            
            if target_date <= CUTOFF_DATE:
                original_value = next_df[next_df['date'] == target_date][tag_column].iloc[0]
                corrected_value = original_value * correction_factor
                
                new_row = pd.DataFrame({
                    'date': [target_date],
                    tag_column: [corrected_value]
                })
                result_df = pd.concat([result_df, new_row], ignore_index=True)
                last_processed_date = target_date
    
    # Fill any remaining gaps until CUTOFF_DATE
    if last_processed_date:
        last_processed_datetime = datetime.strptime(last_processed_date, '%Y-%m-%d')
        cutoff_datetime = datetime.strptime(CUTOFF_DATE, '%Y-%m-%d')
        
        current_date = last_processed_datetime + timedelta(days=1)
        while current_date <= cutoff_datetime:
            current_date_str = current_date.strftime('%Y-%m-%d')
            
            # Use the last available value
            last_value = result_df.iloc[-1][tag_column]
            
            new_row = pd.DataFrame({
                'date': [current_date_str],
                tag_column: [last_value]  # Use last value for final gap filling
            })
            result_df = pd.concat([result_df, new_row], ignore_index=True)
            
            current_date += timedelta(days=1)
    
    # Ensure the DataFrame is sorted by date and has no duplicates
    result_df = result_df.sort_values('date').drop_duplicates(subset='date', keep='first')
    return result_df

# %%
# Process each tag
for tag in tags:
    print(f"\nProcessing tag: {tag}")
    result_df = process_tag_files(tag)
    
    if result_df is not None:
        output_filename = f"{tag}_msv_stitched_30day.csv"
        result_df.to_csv(output_filename, index=False)
        print(f"Saved processed data to {output_filename}")
# Out:
# Processing tag: flu
# Processing files: 2020 03 16.csv and 2020 03 17.csv
# Processing files: 2020 03 17.csv and 2020 03 18.csv
# Processing files: 2020 03 18.csv and 2020 03 19.csv
# Processing files: 2020 03 19.csv and 2020 03 20.csv
# Processing files: 2020 03 20.csv and 2020 03 21.csv
# Processing files: 2020 03 21.csv and 2020 03 22.csv
# Processing files: 2020 03 22.csv and 2020 03 23.csv
# Processing files: 2020 03 23.csv and 2020 03 24.csv
# Processing files: 2020 03 24.csv and 2020 03 25.csv
# Processing files: 2020 03 25.csv and 2020 03 26.csv
# Processing files: 2020 03 26.csv and 2020 03 27.csv
# Processing files: 2020 03 27.csv and 2020 03 28.csv
# Processing files: 2020 03 28.csv and 2020 03 29.csv
# Processing files: 2020 03 29.csv and 2020 03 30.csv
# Processing files: 2020 03 30.csv and 2020 03 31.csv
# Processing files: 2020 03 31.csv and 2020 04 01.csv
# Processing files: 2020 04 01.csv and 2020 04 02.csv
# Processing files: 2020 04 02.csv and 2020 04 03.csv
# Processing files: 2020 04 03.csv and 2020 04 04.csv
# Processing files: 2020 04 04.csv and 2020 04 05.csv
# Processing files: 2020 04 05.csv and 2020 04 06.csv
# Processing files: 2020 04 06.csv and 2020 04 07.csv
# Processing files: 2020 04 07.csv and 2020 04 08.csv
# Processing files: 2020 04 08.csv and 2020 04 09.csv
# Processing files: 2020 04 09.csv and 2020 04 10.csv
# Processing files: 2020 04 10.csv and 2020 04 11.csv
# Processing files: 2020 04 11.csv and 2020 04 12.csv
# Processing files: 2020 04 12.csv and 2020 04 13.csv
# Processing files: 2020 04 13.csv and 2020 04 14.csv
# Processing files: 2020 04 14.csv and 2020 04 15.csv
# Processing files: 2020 04 15.csv and 2020 04 16.csv
# Processing files: 2020 04 16.csv and 2020 04 17.csv
# Processing files: 2020 04 17.csv and 2020 04 18.csv
# Processing files: 2020 04 18.csv and 2020 04 19.csv
# Processing files: 2020 04 19.csv and 2020 04 20.csv
# Processing files: 2020 04 20.csv and 2020 04 21.csv
# Processing files: 2020 04 21.csv and 2020 04 22.csv
# Processing files: 2020 04 22.csv and 2020 04 23.csv
# Processing files: 2020 04 23.csv and 2020 04 24.csv
# Processing files: 2020 04 24.csv and 2020 04 25.csv
# Processing files: 2020 04 25.csv and 2020 04 26.csv
# Processing files: 2020 04 26.csv and 2020 04 27.csv
# Processing files: 2020 04 27.csv and 2020 04 28.csv
# Processing files: 2020 04 28.csv and 2020 04 29.csv
# Processing files: 2020 04 29.csv and 2020 04 30.csv
# Processing files: 2020 04 30.csv and 2020 05 01.csv
# Processing files: 2020 05 01.csv and 2020 05 02.csv
# Processing files: 2020 05 02.csv and 2020 05 03.csv
# Processing files: 2020 05 03.csv and 2020 05 04.csv
# Processing files: 2020 05 04.csv and 2020 05 05.csv
# Processing files: 2020 05 05.csv and 2020 05 06.csv
# Processing files: 2020 05 06.csv and 2020 05 07.csv
# Processing files: 2020 05 07.csv and 2020 05 08.csv
# Processing files: 2020 05 08.csv and 2020 05 09.csv
# Processing files: 2020 05 09.csv and 2020 05 10.csv
# Processing files: 2020 05 10.csv and 2020 05 11.csv
# Processing files: 2020 05 11.csv and 2020 05 12.csv
# Processing files: 2020 05 12.csv and 2020 05 13.csv
# Processing files: 2020 05 13.csv and 2020 05 14.csv
# Processing files: 2020 05 14.csv and 2020 05 15.csv
# Processing files: 2020 05 15.csv and 2020 05 16.csv
# Processing files: 2020 05 16.csv and 2020 05 17.csv
# Processing files: 2020 05 17.csv and 2020 05 18.csv
# Processing files: 2020 05 18.csv and 2020 05 19.csv
# Processing files: 2020 05 19.csv and 2020 05 20.csv
# Processing files: 2020 05 20.csv and 2020 05 21.csv
# Processing files: 2020 05 21.csv and 2020 05 22.csv
# Processing files: 2020 05 22.csv and 2020 05 23.csv
# Processing files: 2020 05 23.csv and 2020 05 24.csv
# Processing files: 2020 05 24.csv and 2020 05 25.csv
# Processing files: 2020 05 25.csv and 2020 05 26.csv
# Processing files: 2020 05 26.csv and 2020 05 27.csv
# Processing files: 2020 05 27.csv and 2020 05 28.csv
# Processing files: 2020 05 28.csv and 2020 05 29.csv
# Processing files: 2020 05 29.csv and 2020 05 30.csv
# Processing files: 2020 05 30.csv and 2020 05 31.csv
# Processing files: 2020 05 31.csv and 2020 06 01.csv
# Processing files: 2020 06 01.csv and 2020 06 02.csv
# Processing files: 2020 06 02.csv and 2020 06 03.csv
# Processing files: 2020 06 03.csv and 2020 06 04.csv
# Processing files: 2020 06 04.csv and 2020 06 05.csv
# Processing files: 2020 06 05.csv and 2020 06 06.csv
# Processing files: 2020 06 06.csv and 2020 06 07.csv
# Processing files: 2020 06 07.csv and 2020 06 08.csv
# Processing files: 2020 06 08.csv and 2020 06 09.csv
# Processing files: 2020 06 09.csv and 2020 06 10.csv
# Processing files: 2020 06 10.csv and 2020 06 11.csv
# Processing files: 2020 06 11.csv and 2020 06 12.csv
# Processing files: 2020 06 12.csv and 2020 06 13.csv
# Processing files: 2020 06 13.csv and 2020 06 14.csv
# Processing files: 2020 06 14.csv and 2020 06 15.csv
# Processing files: 2020 06 15.csv and 2020 06 16.csv
# Processing files: 2020 06 16.csv and 2020 06 17.csv
# Processing files: 2020 06 17.csv and 2020 06 18.csv
# Processing files: 2020 06 18.csv and 2020 06 19.csv
# Processing files: 2020 06 19.csv and 2020 06 20.csv
# Processing files: 2020 06 20.csv and 2020 06 21.csv
# Processing files: 2020 06 21.csv and 2020 06 22.csv
# Processing files: 2020 06 22.csv and 2020 06 23.csv
# Processing files: 2020 06 23.csv and 2020 06 24.csv
# Processing files: 2020 06 24.csv and 2020 06 25.csv
# Processing files: 2020 06 25.csv and 2020 06 26.csv
# Processing files: 2020 06 26.csv and 2020 06 27.csv
# Processing files: 2020 06 27.csv and 2020 06 28.csv
# Processing files: 2020 06 28.csv and 2020 06 29.csv
# Processing files: 2020 06 29.csv and 2020 06 30.csv
# Processing files: 2020 06 30.csv and 2020 07 01.csv
# Processing files: 2020 07 01.csv and 2020 07 02.csv
# Processing files: 2020 07 02.csv and 2020 07 03.csv
# Processing files: 2020 07 03.csv and 2020 07 04.csv
# Processing files: 2020 07 04.csv and 2020 07 05.csv
# Processing files: 2020 07 05.csv and 2020 07 06.csv
# Processing files: 2020 07 06.csv and 2020 07 07.csv
# Processing files: 2020 07 07.csv and 2020 07 08.csv
# Processing files: 2020 07 08.csv and 2020 07 09.csv
# Processing files: 2020 07 09.csv and 2020 07 10.csv
# Processing files: 2020 07 10.csv and 2020 07 11.csv
# Processing files: 2020 07 11.csv and 2020 07 12.csv
# Processing files: 2020 07 12.csv and 2020 07 13.csv
# Processing files: 2020 07 13.csv and 2020 07 14.csv
# Processing files: 2020 07 14.csv and 2020 07 15.csv
# Processing files: 2020 07 15.csv and 2020 07 16.csv
# Processing files: 2020 07 16.csv and 2020 07 17.csv
# Processing files: 2020 07 17.csv and 2020 07 18.csv
# Processing files: 2020 07 18.csv and 2020 07 19.csv
# Processing files: 2020 07 19.csv and 2020 07 20.csv
# Processing files: 2020 07 20.csv and 2020 07 21.csv
# Processing files: 2020 07 21.csv and 2020 07 22.csv
# Processing files: 2020 07 22.csv and 2020 07 23.csv
# Processing files: 2020 07 23.csv and 2020 07 24.csv
# Processing files: 2020 07 24.csv and 2020 07 25.csv
# Processing files: 2020 07 25.csv and 2020 07 26.csv
# Processing files: 2020 07 26.csv and 2020 07 27.csv
# Processing files: 2020 07 27.csv and 2020 07 28.csv
# Processing files: 2020 07 28.csv and 2020 07 29.csv
# Processing files: 2020 07 29.csv and 2020 07 30.csv
# Processing files: 2020 07 30.csv and 2020 07 31.csv
# Processing files: 2020 07 31.csv and 2020 08 01.csv
# Processing files: 2020 08 01.csv and 2020 08 02.csv
# Processing files: 2020 08 02.csv and 2020 08 03.csv
# Processing files: 2020 08 03.csv and 2020 08 04.csv
# Processing files: 2020 08 04.csv and 2020 08 05.csv
# Processing files: 2020 08 05.csv and 2020 08 06.csv
# Processing files: 2020 08 06.csv and 2020 08 07.csv
# Processing files: 2020 08 07.csv and 2020 08 08.csv
# Processing files: 2020 08 08.csv and 2020 08 09.csv
# Processing files: 2020 08 09.csv and 2020 08 10.csv
# Processing files: 2020 08 10.csv and 2020 08 11.csv
# Processing files: 2020 08 11.csv and 2020 08 12.csv
# Processing files: 2020 08 12.csv and 2020 08 13.csv
# Processing files: 2020 08 13.csv and 2020 08 14.csv
# Processing files: 2020 08 14.csv and 2020 08 15.csv
# Processing files: 2020 08 15.csv and 2020 08 16.csv
# Processing files: 2020 08 16.csv and 2020 08 17.csv
# Processing files: 2020 08 17.csv and 2020 08 18.csv
# Processing files: 2020 08 18.csv and 2020 08 19.csv
# Processing files: 2020 08 19.csv and 2020 08 20.csv
# Processing files: 2020 08 20.csv and 2020 08 21.csv
# Processing files: 2020 08 21.csv and 2020 08 22.csv
# Processing files: 2020 08 22.csv and 2020 08 23.csv
# Processing files: 2020 08 23.csv and 2020 08 24.csv
# Processing files: 2020 08 24.csv and 2020 08 25.csv
# Processing files: 2020 08 25.csv and 2020 08 26.csv
# Processing files: 2020 08 26.csv and 2020 08 27.csv
# Processing files: 2020 08 27.csv and 2020 08 28.csv
# Processing files: 2020 08 28.csv and 2020 08 29.csv
# Processing files: 2020 08 29.csv and 2020 08 30.csv
# Processing files: 2020 08 30.csv and 2020 08 31.csv
# Processing files: 2020 08 31.csv and 2020 09 01.csv
# Processing files: 2020 09 01.csv and 2020 09 02.csv
# Processing files: 2020 09 02.csv and 2020 09 03.csv
# Processing files: 2020 09 03.csv and 2020 09 04.csv
# Processing files: 2020 09 04.csv and 2020 09 05.csv
# Processing files: 2020 09 05.csv and 2020 09 06.csv
# Processing files: 2020 09 06.csv and 2020 09 07.csv
# Processing files: 2020 09 07.csv and 2020 09 08.csv
# Processing files: 2020 09 08.csv and 2020 09 09.csv
# Processing files: 2020 09 09.csv and 2020 09 10.csv
# Processing files: 2020 09 10.csv and 2020 09 11.csv
# Processing files: 2020 09 11.csv and 2020 09 12.csv
# Processing files: 2020 09 12.csv and 2020 09 13.csv
# Processing files: 2020 09 13.csv and 2020 09 14.csv
# Processing files: 2020 09 14.csv and 2020 09 15.csv
# Processing files: 2020 09 15.csv and 2020 09 16.csv
# Processing files: 2020 09 16.csv and 2020 09 17.csv
# Processing files: 2020 09 17.csv and 2020 09 18.csv
# Processing files: 2020 09 18.csv and 2020 09 19.csv
# Processing files: 2020 09 19.csv and 2020 09 20.csv
# Processing files: 2020 09 20.csv and 2020 09 21.csv
# Processing files: 2020 09 21.csv and 2020 09 22.csv
# Processing files: 2020 09 22.csv and 2020 09 23.csv
# Processing files: 2020 09 23.csv and 2020 09 24.csv
# Processing files: 2020 09 24.csv and 2020 09 25.csv
# Processing files: 2020 09 25.csv and 2020 09 26.csv
# Processing files: 2020 09 26.csv and 2020 09 27.csv
# Processing files: 2020 09 27.csv and 2020 09 28.csv
# Processing files: 2020 09 28.csv and 2020 09 29.csv
# Processing files: 2020 09 29.csv and 2020 09 30.csv
# Processing files: 2020 09 30.csv and 2020 10 01.csv
# Processing files: 2020 10 01.csv and 2020 10 02.csv
# Processing files: 2020 10 02.csv and 2020 10 03.csv
# Processing files: 2020 10 03.csv and 2020 10 04.csv
# Processing files: 2020 10 04.csv and 2020 10 05.csv
# Processing files: 2020 10 05.csv and 2020 10 06.csv
# Processing files: 2020 10 06.csv and 2020 10 07.csv
# Processing files: 2020 10 07.csv and 2020 10 08.csv
# Processing files: 2020 10 08.csv and 2020 10 09.csv
# Processing files: 2020 10 09.csv and 2020 10 10.csv
# Processing files: 2020 10 10.csv and 2020 10 11.csv
# Processing files: 2020 10 11.csv and 2020 10 12.csv
# Processing files: 2020 10 12.csv and 2020 10 13.csv
# Processing files: 2020 10 13.csv and 2020 10 14.csv
# Processing files: 2020 10 14.csv and 2020 10 15.csv
# Processing files: 2020 10 15.csv and 2020 10 16.csv
# Processing files: 2020 10 16.csv and 2020 10 17.csv
# Processing files: 2020 10 17.csv and 2020 10 18.csv
# Processing files: 2020 10 18.csv and 2020 10 19.csv
# Processing files: 2020 10 19.csv and 2020 10 20.csv
# Processing files: 2020 10 20.csv and 2020 10 21.csv
# Processing files: 2020 10 21.csv and 2020 10 22.csv
# Processing files: 2020 10 22.csv and 2020 10 23.csv
# Processing files: 2020 10 23.csv and 2020 10 24.csv
# Processing files: 2020 10 24.csv and 2020 10 25.csv
# Processing files: 2020 10 25.csv and 2020 10 26.csv
# Processing files: 2020 10 26.csv and 2020 10 27.csv
# Processing files: 2020 10 27.csv and 2020 10 28.csv
# Processing files: 2020 10 28.csv and 2020 10 29.csv
# Processing files: 2020 10 29.csv and 2020 10 30.csv
# Processing files: 2020 10 30.csv and 2020 10 31.csv
# Processing files: 2020 10 31.csv and 2020 11 01.csv
# Processing files: 2020 11 01.csv and 2020 11 02.csv
# Processing files: 2020 11 02.csv and 2020 11 03.csv
# Processing files: 2020 11 03.csv and 2020 11 04.csv
# Processing files: 2020 11 04.csv and 2020 11 05.csv
# Processing files: 2020 11 05.csv and 2020 11 06.csv
# Processing files: 2020 11 06.csv and 2020 11 07.csv
# Processing files: 2020 11 07.csv and 2020 11 08.csv
# Processing files: 2020 11 08.csv and 2020 11 09.csv
# Processing files: 2020 11 09.csv and 2020 11 10.csv
# Processing files: 2020 11 10.csv and 2020 11 11.csv
# Processing files: 2020 11 11.csv and 2020 11 12.csv
# Processing files: 2020 11 12.csv and 2020 11 13.csv
# Processing files: 2020 11 13.csv and 2020 11 14.csv
# Processing files: 2020 11 14.csv and 2020 11 15.csv
# Processing files: 2020 11 15.csv and 2020 11 16.csv
# Processing files: 2020 11 16.csv and 2020 11 17.csv
# Processing files: 2020 11 17.csv and 2020 11 18.csv
# Processing files: 2020 11 18.csv and 2020 11 19.csv
# Processing files: 2020 11 19.csv and 2020 11 20.csv
# Processing files: 2020 11 20.csv and 2020 11 21.csv
# Processing files: 2020 11 21.csv and 2020 11 22.csv
# Processing files: 2020 11 22.csv and 2020 11 23.csv
# Processing files: 2020 11 23.csv and 2020 11 24.csv
# Processing files: 2020 11 24.csv and 2020 11 25.csv
# Processing files: 2020 11 25.csv and 2020 11 26.csv
# Processing files: 2020 11 26.csv and 2020 11 27.csv
# Processing files: 2020 11 27.csv and 2020 11 28.csv
# Processing files: 2020 11 28.csv and 2020 11 29.csv
# Processing files: 2020 11 29.csv and 2020 11 30.csv
# Processing files: 2020 11 30.csv and 2020 12 01.csv
# Processing files: 2020 12 01.csv and 2020 12 02.csv
# Processing files: 2020 12 02.csv and 2020 12 03.csv
# Processing files: 2020 12 03.csv and 2020 12 04.csv
# Processing files: 2020 12 04.csv and 2020 12 05.csv
# Processing files: 2020 12 05.csv and 2020 12 06.csv
# Processing files: 2020 12 06.csv and 2020 12 07.csv
# Processing files: 2020 12 07.csv and 2020 12 08.csv
# Processing files: 2020 12 08.csv and 2020 12 09.csv
# Processing files: 2020 12 09.csv and 2020 12 10.csv
# Processing files: 2020 12 10.csv and 2020 12 11.csv
# Processing files: 2020 12 11.csv and 2020 12 12.csv
# Processing files: 2020 12 12.csv and 2020 12 13.csv
# Processing files: 2020 12 13.csv and 2020 12 14.csv
# Processing files: 2020 12 14.csv and 2020 12 15.csv
# Processing files: 2020 12 15.csv and 2020 12 16.csv
# Processing files: 2020 12 16.csv and 2020 12 17.csv
# Processing files: 2020 12 17.csv and 2020 12 18.csv
# Processing files: 2020 12 18.csv and 2020 12 19.csv
# Processing files: 2020 12 19.csv and 2020 12 20.csv
# Processing files: 2020 12 20.csv and 2020 12 21.csv
# Processing files: 2020 12 21.csv and 2020 12 22.csv
# Processing files: 2020 12 22.csv and 2020 12 23.csv
# Processing files: 2020 12 23.csv and 2020 12 24.csv
# Processing files: 2020 12 24.csv and 2020 12 25.csv
# Processing files: 2020 12 25.csv and 2020 12 26.csv
# Processing files: 2020 12 26.csv and 2020 12 27.csv
# Processing files: 2020 12 27.csv and 2020 12 28.csv
# Processing files: 2020 12 28.csv and 2020 12 29.csv
# Processing files: 2020 12 29.csv and 2020 12 30.csv
# Processing files: 2020 12 30.csv and 2020 12 31.csv
# Processing files: 2020 12 31.csv and 2021 01 01.csv
# Processing files: 2021 01 01.csv and 2021 01 02.csv
# Processing files: 2021 01 02.csv and 2021 01 03.csv
# Processing files: 2021 01 03.csv and 2021 01 04.csv
# Processing files: 2021 01 04.csv and 2021 01 05.csv
# Processing files: 2021 01 05.csv and 2021 01 06.csv
# Processing files: 2021 01 06.csv and 2021 01 07.csv
# Processing files: 2021 01 07.csv and 2021 01 08.csv
# Processing files: 2021 01 08.csv and 2021 01 09.csv
# Processing files: 2021 01 09.csv and 2021 01 10.csv
# Processing files: 2021 01 10.csv and 2021 01 11.csv
# Processing files: 2021 01 11.csv and 2021 01 12.csv
# Processing files: 2021 01 12.csv and 2021 01 13.csv
# Processing files: 2021 01 13.csv and 2021 01 14.csv
# Processing files: 2021 01 14.csv and 2021 01 15.csv
# Processing files: 2021 01 15.csv and 2021 01 16.csv
# Processing files: 2021 01 16.csv and 2021 01 17.csv
# Processing files: 2021 01 17.csv and 2021 01 18.csv
# Processing files: 2021 01 18.csv and 2021 01 19.csv
# Processing files: 2021 01 19.csv and 2021 01 20.csv
# Processing files: 2021 01 20.csv and 2021 01 21.csv
# Processing files: 2021 01 21.csv and 2021 01 22.csv
# Processing files: 2021 01 22.csv and 2021 01 23.csv
# Processing files: 2021 01 23.csv and 2021 01 24.csv
# Processing files: 2021 01 24.csv and 2021 01 25.csv
# Processing files: 2021 01 25.csv and 2021 01 26.csv
# Processing files: 2021 01 26.csv and 2021 01 27.csv
# Processing files: 2021 01 27.csv and 2021 01 28.csv
# Processing files: 2021 01 28.csv and 2021 01 29.csv
# Processing files: 2021 01 29.csv and 2021 01 30.csv
# Processing files: 2021 01 30.csv and 2021 01 31.csv
# Processing files: 2021 01 31.csv and 2021 02 01.csv
# Processing files: 2021 02 01.csv and 2021 02 02.csv
# Processing files: 2021 02 02.csv and 2021 02 03.csv
# Processing files: 2021 02 03.csv and 2021 02 04.csv
# Processing files: 2021 02 04.csv and 2021 02 05.csv
# Processing files: 2021 02 05.csv and 2021 02 06.csv
# Processing files: 2021 02 06.csv and 2021 02 07.csv
# Processing files: 2021 02 07.csv and 2021 02 08.csv
# Processing files: 2021 02 08.csv and 2021 02 09.csv
# Processing files: 2021 02 09.csv and 2021 02 10.csv
# Processing files: 2021 02 10.csv and 2021 02 11.csv
# Processing files: 2021 02 11.csv and 2021 02 12.csv
# Processing files: 2021 02 12.csv and 2021 02 13.csv
# Processing files: 2021 02 13.csv and 2021 02 14.csv
# Saved processed data to flu_msv_stitched_30day.csv
#
# Processing tag: cough
# Processing files: 2020 03 16.csv and 2020 03 17.csv
# Processing files: 2020 03 17.csv and 2020 03 18.csv
# Processing files: 2020 03 18.csv and 2020 03 19.csv
# Processing files: 2020 03 19.csv and 2020 03 20.csv
# Processing files: 2020 03 20.csv and 2020 03 21.csv
# Processing files: 2020 03 21.csv and 2020 03 22.csv
# Processing files: 2020 03 22.csv and 2020 03 23.csv
# Processing files: 2020 03 23.csv and 2020 03 24.csv
# Processing files: 2020 03 24.csv and 2020 03 25.csv
# Processing files: 2020 03 25.csv and 2020 03 26.csv
# Processing files: 2020 03 26.csv and 2020 03 27.csv
# Processing files: 2020 03 27.csv and 2020 03 28.csv
# Processing files: 2020 03 28.csv and 2020 03 29.csv
# Processing files: 2020 03 29.csv and 2020 03 30.csv
# Processing files: 2020 03 30.csv and 2020 03 31.csv
# Processing files: 2020 03 31.csv and 2020 04 01.csv
# Processing files: 2020 04 01.csv and 2020 04 02.csv
# Processing files: 2020 04 02.csv and 2020 04 03.csv
# Processing files: 2020 04 03.csv and 2020 04 04.csv
# Processing files: 2020 04 04.csv and 2020 04 05.csv
# Processing files: 2020 04 05.csv and 2020 04 06.csv
# Processing files: 2020 04 06.csv and 2020 04 07.csv
# Processing files: 2020 04 07.csv and 2020 04 08.csv
# Processing files: 2020 04 08.csv and 2020 04 09.csv
# Processing files: 2020 04 09.csv and 2020 04 10.csv
# Processing files: 2020 04 10.csv and 2020 04 11.csv
# Processing files: 2020 04 11.csv and 2020 04 12.csv
# Processing files: 2020 04 12.csv and 2020 04 13.csv
# Processing files: 2020 04 13.csv and 2020 04 14.csv
# Processing files: 2020 04 14.csv and 2020 04 15.csv
# Processing files: 2020 04 15.csv and 2020 04 16.csv
# Processing files: 2020 04 16.csv and 2020 04 17.csv
# Processing files: 2020 04 17.csv and 2020 04 18.csv
# Processing files: 2020 04 18.csv and 2020 04 19.csv
# Processing files: 2020 04 19.csv and 2020 04 20.csv
# Processing files: 2020 04 20.csv and 2020 04 21.csv
# Processing files: 2020 04 21.csv and 2020 04 22.csv
# Processing files: 2020 04 22.csv and 2020 04 23.csv
# Processing files: 2020 04 23.csv and 2020 04 24.csv
# Processing files: 2020 04 24.csv and 2020 04 25.csv
# Processing files: 2020 04 25.csv and 2020 04 26.csv
# Processing files: 2020 04 26.csv and 2020 04 27.csv
# Processing files: 2020 04 27.csv and 2020 04 28.csv
# Processing files: 2020 04 28.csv and 2020 04 29.csv
# Processing files: 2020 04 29.csv and 2020 04 30.csv
# Processing files: 2020 04 30.csv and 2020 05 01.csv
# Processing files: 2020 05 01.csv and 2020 05 02.csv
# Processing files: 2020 05 02.csv and 2020 05 03.csv
# Processing files: 2020 05 03.csv and 2020 05 04.csv
# Processing files: 2020 05 04.csv and 2020 05 05.csv
# Processing files: 2020 05 05.csv and 2020 05 06.csv
# Processing files: 2020 05 06.csv and 2020 05 07.csv
# Processing files: 2020 05 07.csv and 2020 05 08.csv
# Processing files: 2020 05 08.csv and 2020 05 09.csv
# Processing files: 2020 05 09.csv and 2020 05 10.csv
# Processing files: 2020 05 10.csv and 2020 05 11.csv
# Processing files: 2020 05 11.csv and 2020 05 12.csv
# Processing files: 2020 05 12.csv and 2020 05 13.csv
# Processing files: 2020 05 13.csv and 2020 05 14.csv
# Processing files: 2020 05 14.csv and 2020 05 15.csv
# Processing files: 2020 05 15.csv and 2020 05 16.csv
# Processing files: 2020 05 16.csv and 2020 05 17.csv
# Processing files: 2020 05 17.csv and 2020 05 18.csv
# Processing files: 2020 05 18.csv and 2020 05 19.csv
# Processing files: 2020 05 19.csv and 2020 05 20.csv
# Processing files: 2020 05 20.csv and 2020 05 21.csv
# Processing files: 2020 05 21.csv and 2020 05 22.csv
# Processing files: 2020 05 22.csv and 2020 05 23.csv
# Processing files: 2020 05 23.csv and 2020 05 24.csv
# Processing files: 2020 05 24.csv and 2020 05 25.csv
# Processing files: 2020 05 25.csv and 2020 05 26.csv
# Processing files: 2020 05 26.csv and 2020 05 27.csv
# Processing files: 2020 05 27.csv and 2020 05 28.csv
# Processing files: 2020 05 28.csv and 2020 05 29.csv
# Processing files: 2020 05 29.csv and 2020 05 30.csv
# Processing files: 2020 05 30.csv and 2020 05 31.csv
# Processing files: 2020 05 31.csv and 2020 06 01.csv
# Processing files: 2020 06 01.csv and 2020 06 02.csv
# Processing files: 2020 06 02.csv and 2020 06 03.csv
# Processing files: 2020 06 03.csv and 2020 06 04.csv
# Processing files: 2020 06 04.csv and 2020 06 05.csv
# Processing files: 2020 06 05.csv and 2020 06 06.csv
# Processing files: 2020 06 06.csv and 2020 06 07.csv
# Processing files: 2020 06 07.csv and 2020 06 08.csv
# Processing files: 2020 06 08.csv and 2020 06 09.csv
# Processing files: 2020 06 09.csv and 2020 06 10.csv
# Processing files: 2020 06 10.csv and 2020 06 11.csv
# Processing files: 2020 06 11.csv and 2020 06 12.csv
# Processing files: 2020 06 12.csv and 2020 06 13.csv
# Processing files: 2020 06 13.csv and 2020 06 14.csv
# Processing files: 2020 06 14.csv and 2020 06 15.csv
# Processing files: 2020 06 15.csv and 2020 06 16.csv
# Processing files: 2020 06 16.csv and 2020 06 17.csv
# Processing files: 2020 06 17.csv and 2020 06 18.csv
# Processing files: 2020 06 18.csv and 2020 06 19.csv
# Processing files: 2020 06 19.csv and 2020 06 20.csv
# Processing files: 2020 06 20.csv and 2020 06 21.csv
# Processing files: 2020 06 21.csv and 2020 06 22.csv
# Processing files: 2020 06 22.csv and 2020 06 23.csv
# Processing files: 2020 06 23.csv and 2020 06 24.csv
# Processing files: 2020 06 24.csv and 2020 06 25.csv
# Processing files: 2020 06 25.csv and 2020 06 26.csv
# Processing files: 2020 06 26.csv and 2020 06 27.csv
# Processing files: 2020 06 27.csv and 2020 06 28.csv
# Processing files: 2020 06 28.csv and 2020 06 29.csv
# Processing files: 2020 06 29.csv and 2020 06 30.csv
# Processing files: 2020 06 30.csv and 2020 07 01.csv
# Processing files: 2020 07 01.csv and 2020 07 02.csv
# Processing files: 2020 07 02.csv and 2020 07 03.csv
# Processing files: 2020 07 03.csv and 2020 07 04.csv
# Processing files: 2020 07 04.csv and 2020 07 05.csv
# Processing files: 2020 07 05.csv and 2020 07 06.csv
# Processing files: 2020 07 06.csv and 2020 07 07.csv
# Processing files: 2020 07 07.csv and 2020 07 08.csv
# Processing files: 2020 07 08.csv and 2020 07 09.csv
# Processing files: 2020 07 09.csv and 2020 07 10.csv
# Processing files: 2020 07 10.csv and 2020 07 11.csv
# Processing files: 2020 07 11.csv and 2020 07 12.csv
# Processing files: 2020 07 12.csv and 2020 07 13.csv
# Processing files: 2020 07 13.csv and 2020 07 14.csv
# Processing files: 2020 07 14.csv and 2020 07 15.csv
# Processing files: 2020 07 15.csv and 2020 07 16.csv
# Processing files: 2020 07 16.csv and 2020 07 17.csv
# Processing files: 2020 07 17.csv and 2020 07 18.csv
# Processing files: 2020 07 18.csv and 2020 07 19.csv
# Processing files: 2020 07 19.csv and 2020 07 20.csv
# Processing files: 2020 07 20.csv and 2020 07 21.csv
# Processing files: 2020 07 21.csv and 2020 07 22.csv
# Processing files: 2020 07 22.csv and 2020 07 23.csv
# Processing files: 2020 07 23.csv and 2020 07 24.csv
# Processing files: 2020 07 24.csv and 2020 07 25.csv
# Processing files: 2020 07 25.csv and 2020 07 26.csv
# Processing files: 2020 07 26.csv and 2020 07 27.csv
# Processing files: 2020 07 27.csv and 2020 07 28.csv
# Processing files: 2020 07 28.csv and 2020 07 29.csv
# Processing files: 2020 07 29.csv and 2020 07 30.csv
# Processing files: 2020 07 30.csv and 2020 07 31.csv
# Processing files: 2020 07 31.csv and 2020 08 01.csv
# Processing files: 2020 08 01.csv and 2020 08 02.csv
# Processing files: 2020 08 02.csv and 2020 08 03.csv
# Processing files: 2020 08 03.csv and 2020 08 04.csv
# Processing files: 2020 08 04.csv and 2020 08 05.csv
# Processing files: 2020 08 05.csv and 2020 08 06.csv
# Processing files: 2020 08 06.csv and 2020 08 07.csv
# Processing files: 2020 08 07.csv and 2020 08 08.csv
# Processing files: 2020 08 08.csv and 2020 08 09.csv
# Processing files: 2020 08 09.csv and 2020 08 10.csv
# Processing files: 2020 08 10.csv and 2020 08 11.csv
# Processing files: 2020 08 11.csv and 2020 08 12.csv
# Processing files: 2020 08 12.csv and 2020 08 13.csv
# Processing files: 2020 08 13.csv and 2020 08 14.csv
# Processing files: 2020 08 14.csv and 2020 08 15.csv
# Processing files: 2020 08 15.csv and 2020 08 16.csv
# Processing files: 2020 08 16.csv and 2020 08 17.csv
# Processing files: 2020 08 17.csv and 2020 08 18.csv
# Processing files: 2020 08 18.csv and 2020 08 19.csv
# Processing files: 2020 08 19.csv and 2020 08 20.csv
# Processing files: 2020 08 20.csv and 2020 08 21.csv
# Processing files: 2020 08 21.csv and 2020 08 22.csv
# Processing files: 2020 08 22.csv and 2020 08 23.csv
# Processing files: 2020 08 23.csv and 2020 08 24.csv
# Processing files: 2020 08 24.csv and 2020 08 25.csv
# Processing files: 2020 08 25.csv and 2020 08 26.csv
# Processing files: 2020 08 26.csv and 2020 08 27.csv
# Processing files: 2020 08 27.csv and 2020 08 28.csv
# Processing files: 2020 08 28.csv and 2020 08 29.csv
# Processing files: 2020 08 29.csv and 2020 08 30.csv
# Processing files: 2020 08 30.csv and 2020 08 31.csv
# Processing files: 2020 08 31.csv and 2020 09 01.csv
# Processing files: 2020 09 01.csv and 2020 09 02.csv
# Processing files: 2020 09 02.csv and 2020 09 03.csv
# Processing files: 2020 09 03.csv and 2020 09 04.csv
# Processing files: 2020 09 04.csv and 2020 09 05.csv
# Processing files: 2020 09 05.csv and 2020 09 06.csv
# Processing files: 2020 09 06.csv and 2020 09 07.csv
# Processing files: 2020 09 07.csv and 2020 09 08.csv
# Processing files: 2020 09 08.csv and 2020 09 09.csv
# Processing files: 2020 09 09.csv and 2020 09 10.csv
# Processing files: 2020 09 10.csv and 2020 09 11.csv
# Processing files: 2020 09 11.csv and 2020 09 12.csv
# Processing files: 2020 09 12.csv and 2020 09 13.csv
# Processing files: 2020 09 13.csv and 2020 09 14.csv
# Processing files: 2020 09 14.csv and 2020 09 15.csv
# Processing files: 2020 09 15.csv and 2020 09 16.csv
# Processing files: 2020 09 16.csv and 2020 09 17.csv
# Processing files: 2020 09 17.csv and 2020 09 18.csv
# Processing files: 2020 09 18.csv and 2020 09 19.csv
# Processing files: 2020 09 19.csv and 2020 09 20.csv
# Processing files: 2020 09 20.csv and 2020 09 21.csv
# Processing files: 2020 09 21.csv and 2020 09 22.csv
# Processing files: 2020 09 22.csv and 2020 09 23.csv
# Processing files: 2020 09 23.csv and 2020 09 24.csv
# Processing files: 2020 09 24.csv and 2020 09 25.csv
# Processing files: 2020 09 25.csv and 2020 09 26.csv
# Processing files: 2020 09 26.csv and 2020 09 27.csv
# Processing files: 2020 09 27.csv and 2020 09 28.csv
# Processing files: 2020 09 28.csv and 2020 09 29.csv
# Processing files: 2020 09 29.csv and 2020 09 30.csv
# Processing files: 2020 09 30.csv and 2020 10 01.csv
# Processing files: 2020 10 01.csv and 2020 10 02.csv
# Processing files: 2020 10 02.csv and 2020 10 03.csv
# Processing files: 2020 10 03.csv and 2020 10 04.csv
# Processing files: 2020 10 04.csv and 2020 10 05.csv
# Processing files: 2020 10 05.csv and 2020 10 06.csv
# Processing files: 2020 10 06.csv and 2020 10 07.csv
# Processing files: 2020 10 07.csv and 2020 10 08.csv
# Processing files: 2020 10 08.csv and 2020 10 09.csv
# Processing files: 2020 10 09.csv and 2020 10 10.csv
# Processing files: 2020 10 10.csv and 2020 10 11.csv
# Processing files: 2020 10 11.csv and 2020 10 12.csv
# Processing files: 2020 10 12.csv and 2020 10 13.csv
# Processing files: 2020 10 13.csv and 2020 10 14.csv
# Processing files: 2020 10 14.csv and 2020 10 15.csv
# Processing files: 2020 10 15.csv and 2020 10 16.csv
# Processing files: 2020 10 16.csv and 2020 10 17.csv
# Processing files: 2020 10 17.csv and 2020 10 18.csv
# Processing files: 2020 10 18.csv and 2020 10 19.csv
# Processing files: 2020 10 19.csv and 2020 10 20.csv
# Processing files: 2020 10 20.csv and 2020 10 21.csv
# Processing files: 2020 10 21.csv and 2020 10 22.csv
# Processing files: 2020 10 22.csv and 2020 10 23.csv
# Processing files: 2020 10 23.csv and 2020 10 24.csv
# Processing files: 2020 10 24.csv and 2020 10 25.csv
# Processing files: 2020 10 25.csv and 2020 10 26.csv
# Processing files: 2020 10 26.csv and 2020 10 27.csv
# Processing files: 2020 10 27.csv and 2020 10 28.csv
# Processing files: 2020 10 28.csv and 2020 10 29.csv
# Processing files: 2020 10 29.csv and 2020 10 30.csv
# Processing files: 2020 10 30.csv and 2020 10 31.csv
# Processing files: 2020 10 31.csv and 2020 11 01.csv
# Processing files: 2020 11 01.csv and 2020 11 02.csv
# Processing files: 2020 11 02.csv and 2020 11 03.csv
# Processing files: 2020 11 03.csv and 2020 11 04.csv
# Processing files: 2020 11 04.csv and 2020 11 05.csv
# Processing files: 2020 11 05.csv and 2020 11 06.csv
# Processing files: 2020 11 06.csv and 2020 11 07.csv
# Processing files: 2020 11 07.csv and 2020 11 08.csv
# Processing files: 2020 11 08.csv and 2020 11 09.csv
# Processing files: 2020 11 09.csv and 2020 11 10.csv
# Processing files: 2020 11 10.csv and 2020 11 11.csv
# Processing files: 2020 11 11.csv and 2020 11 12.csv
# Processing files: 2020 11 12.csv and 2020 11 13.csv
# Processing files: 2020 11 13.csv and 2020 11 14.csv
# Processing files: 2020 11 14.csv and 2020 11 15.csv
# Processing files: 2020 11 15.csv and 2020 11 16.csv
# Processing files: 2020 11 16.csv and 2020 11 17.csv
# Processing files: 2020 11 17.csv and 2020 11 18.csv
# Processing files: 2020 11 18.csv and 2020 11 19.csv
# Processing files: 2020 11 19.csv and 2020 11 20.csv
# Processing files: 2020 11 20.csv and 2020 11 21.csv
# Processing files: 2020 11 21.csv and 2020 11 22.csv
# Processing files: 2020 11 22.csv and 2020 11 23.csv
# Processing files: 2020 11 23.csv and 2020 11 24.csv
# Processing files: 2020 11 24.csv and 2020 11 25.csv
# Processing files: 2020 11 25.csv and 2020 11 26.csv
# Processing files: 2020 11 26.csv and 2020 11 27.csv
# Processing files: 2020 11 27.csv and 2020 11 28.csv
# Processing files: 2020 11 28.csv and 2020 11 29.csv
# Processing files: 2020 11 29.csv and 2020 11 30.csv
# Processing files: 2020 11 30.csv and 2020 12 01.csv
# Processing files: 2020 12 01.csv and 2020 12 02.csv
# Processing files: 2020 12 02.csv and 2020 12 03.csv
# Processing files: 2020 12 03.csv and 2020 12 04.csv
# Processing files: 2020 12 04.csv and 2020 12 05.csv
# Processing files: 2020 12 05.csv and 2020 12 06.csv
# Processing files: 2020 12 06.csv and 2020 12 07.csv
# Processing files: 2020 12 07.csv and 2020 12 08.csv
# Processing files: 2020 12 08.csv and 2020 12 09.csv
# Processing files: 2020 12 09.csv and 2020 12 10.csv
# Processing files: 2020 12 10.csv and 2020 12 11.csv
# Processing files: 2020 12 11.csv and 2020 12 12.csv
# Processing files: 2020 12 12.csv and 2020 12 13.csv
# Processing files: 2020 12 13.csv and 2020 12 14.csv
# Processing files: 2020 12 14.csv and 2020 12 15.csv
# Processing files: 2020 12 15.csv and 2020 12 16.csv
# Processing files: 2020 12 16.csv and 2020 12 17.csv
# Processing files: 2020 12 17.csv and 2020 12 18.csv
# Processing files: 2020 12 18.csv and 2020 12 19.csv
# Processing files: 2020 12 19.csv and 2020 12 20.csv
# Processing files: 2020 12 20.csv and 2020 12 21.csv
# Processing files: 2020 12 21.csv and 2020 12 22.csv
# Processing files: 2020 12 22.csv and 2020 12 23.csv
# Processing files: 2020 12 23.csv and 2020 12 24.csv
# Processing files: 2020 12 24.csv and 2020 12 25.csv
# Processing files: 2020 12 25.csv and 2020 12 26.csv
# Processing files: 2020 12 26.csv and 2020 12 27.csv
# Processing files: 2020 12 27.csv and 2020 12 28.csv
# Processing files: 2020 12 28.csv and 2020 12 29.csv
# Processing files: 2020 12 29.csv and 2020 12 30.csv
# Processing files: 2020 12 30.csv and 2020 12 31.csv
# Processing files: 2020 12 31.csv and 2021 01 01.csv
# Processing files: 2021 01 01.csv and 2021 01 02.csv
# Processing files: 2021 01 02.csv and 2021 01 03.csv
# Processing files: 2021 01 03.csv and 2021 01 04.csv
# Processing files: 2021 01 04.csv and 2021 01 05.csv
# Processing files: 2021 01 05.csv and 2021 01 06.csv
# Processing files: 2021 01 06.csv and 2021 01 07.csv
# Processing files: 2021 01 07.csv and 2021 01 08.csv
# Processing files: 2021 01 08.csv and 2021 01 09.csv
# Processing files: 2021 01 09.csv and 2021 01 10.csv
# Processing files: 2021 01 10.csv and 2021 01 11.csv
# Processing files: 2021 01 11.csv and 2021 01 12.csv
# Processing files: 2021 01 12.csv and 2021 01 13.csv
# Processing files: 2021 01 13.csv and 2021 01 14.csv
# Processing files: 2021 01 14.csv and 2021 01 15.csv
# Processing files: 2021 01 15.csv and 2021 01 16.csv
# Processing files: 2021 01 16.csv and 2021 01 17.csv
# Processing files: 2021 01 17.csv and 2021 01 18.csv
# Processing files: 2021 01 18.csv and 2021 01 19.csv
# Processing files: 2021 01 19.csv and 2021 01 20.csv
# Processing files: 2021 01 20.csv and 2021 01 21.csv
# Processing files: 2021 01 21.csv and 2021 01 22.csv
# Processing files: 2021 01 22.csv and 2021 01 23.csv
# Processing files: 2021 01 23.csv and 2021 01 24.csv
# Processing files: 2021 01 24.csv and 2021 01 25.csv
# Processing files: 2021 01 25.csv and 2021 01 26.csv
# Processing files: 2021 01 26.csv and 2021 01 27.csv
# Processing files: 2021 01 27.csv and 2021 01 28.csv
# Processing files: 2021 01 28.csv and 2021 01 29.csv
# Processing files: 2021 01 29.csv and 2021 01 30.csv
# Processing files: 2021 01 30.csv and 2021 01 31.csv
# Processing files: 2021 01 31.csv and 2021 02 01.csv
# Processing files: 2021 02 01.csv and 2021 02 02.csv
# Processing files: 2021 02 02.csv and 2021 02 03.csv
# Processing files: 2021 02 03.csv and 2021 02 04.csv
# Processing files: 2021 02 04.csv and 2021 02 05.csv
# Processing files: 2021 02 05.csv and 2021 02 06.csv
# Processing files: 2021 02 06.csv and 2021 02 07.csv
# Processing files: 2021 02 07.csv and 2021 02 08.csv
# Processing files: 2021 02 08.csv and 2021 02 09.csv
# Processing files: 2021 02 09.csv and 2021 02 10.csv
# Processing files: 2021 02 10.csv and 2021 02 11.csv
# Processing files: 2021 02 11.csv and 2021 02 12.csv
# Processing files: 2021 02 12.csv and 2021 02 13.csv
# Processing files: 2021 02 13.csv and 2021 02 14.csv
# Saved processed data to cough_msv_stitched_30day.csv
#
# Processing tag: fever
# Processing files: 2020 03 16.csv and 2020 03 17.csv
# Processing files: 2020 03 17.csv and 2020 03 18.csv
# Processing files: 2020 03 18.csv and 2020 03 19.csv
# Processing files: 2020 03 19.csv and 2020 03 20.csv
# Processing files: 2020 03 20.csv and 2020 03 21.csv
# Processing files: 2020 03 21.csv and 2020 03 22.csv
# Processing files: 2020 03 22.csv and 2020 03 23.csv
# Processing files: 2020 03 23.csv and 2020 03 24.csv
# Processing files: 2020 03 24.csv and 2020 03 25.csv
# Processing files: 2020 03 25.csv and 2020 03 26.csv
# Processing files: 2020 03 26.csv and 2020 03 27.csv
# Processing files: 2020 03 27.csv and 2020 03 28.csv
# Processing files: 2020 03 28.csv and 2020 03 29.csv
# Processing files: 2020 03 29.csv and 2020 03 30.csv
# Processing files: 2020 03 30.csv and 2020 03 31.csv
# Processing files: 2020 03 31.csv and 2020 04 01.csv
# Processing files: 2020 04 01.csv and 2020 04 02.csv
# Processing files: 2020 04 02.csv and 2020 04 03.csv
# Processing files: 2020 04 03.csv and 2020 04 04.csv
# Processing files: 2020 04 04.csv and 2020 04 05.csv
# Processing files: 2020 04 05.csv and 2020 04 06.csv
# Processing files: 2020 04 06.csv and 2020 04 07.csv
# Processing files: 2020 04 07.csv and 2020 04 08.csv
# Processing files: 2020 04 08.csv and 2020 04 09.csv
# Processing files: 2020 04 09.csv and 2020 04 10.csv
# Processing files: 2020 04 10.csv and 2020 04 11.csv
# Processing files: 2020 04 11.csv and 2020 04 12.csv
# Processing files: 2020 04 12.csv and 2020 04 13.csv
# Processing files: 2020 04 13.csv and 2020 04 14.csv
# Processing files: 2020 04 14.csv and 2020 04 15.csv
# Processing files: 2020 04 15.csv and 2020 04 16.csv
# Processing files: 2020 04 16.csv and 2020 04 17.csv
# Processing files: 2020 04 17.csv and 2020 04 18.csv
# Processing files: 2020 04 18.csv and 2020 04 19.csv
# Processing files: 2020 04 19.csv and 2020 04 20.csv
# Processing files: 2020 04 20.csv and 2020 04 21.csv
# Processing files: 2020 04 21.csv and 2020 04 22.csv
# Processing files: 2020 04 22.csv and 2020 04 23.csv
# Processing files: 2020 04 23.csv and 2020 04 24.csv
# Processing files: 2020 04 24.csv and 2020 04 25.csv
# Processing files: 2020 04 25.csv and 2020 04 26.csv
# Processing files: 2020 04 26.csv and 2020 04 27.csv
# Processing files: 2020 04 27.csv and 2020 04 28.csv
# Processing files: 2020 04 28.csv and 2020 04 29.csv
# Processing files: 2020 04 29.csv and 2020 04 30.csv
# Processing files: 2020 04 30.csv and 2020 05 01.csv
# Processing files: 2020 05 01.csv and 2020 05 02.csv
# Processing files: 2020 05 02.csv and 2020 05 03.csv
# Processing files: 2020 05 03.csv and 2020 05 04.csv
# Processing files: 2020 05 04.csv and 2020 05 05.csv
# Processing files: 2020 05 05.csv and 2020 05 06.csv
# Processing files: 2020 05 06.csv and 2020 05 07.csv
# Processing files: 2020 05 07.csv and 2020 05 08.csv
# Processing files: 2020 05 08.csv and 2020 05 09.csv
# Processing files: 2020 05 09.csv and 2020 05 10.csv
# Processing files: 2020 05 10.csv and 2020 05 11.csv
# Processing files: 2020 05 11.csv and 2020 05 12.csv
# Processing files: 2020 05 12.csv and 2020 05 13.csv
# Processing files: 2020 05 13.csv and 2020 05 14.csv
# Processing files: 2020 05 14.csv and 2020 05 15.csv
# Processing files: 2020 05 15.csv and 2020 05 16.csv
# Processing files: 2020 05 16.csv and 2020 05 17.csv
# Processing files: 2020 05 17.csv and 2020 05 18.csv
# Processing files: 2020 05 18.csv and 2020 05 19.csv
# Processing files: 2020 05 19.csv and 2020 05 20.csv
# Processing files: 2020 05 20.csv and 2020 05 21.csv
# Processing files: 2020 05 21.csv and 2020 05 22.csv
# Processing files: 2020 05 22.csv and 2020 05 23.csv
# Processing files: 2020 05 23.csv and 2020 05 24.csv
# Processing files: 2020 05 24.csv and 2020 05 25.csv
# Processing files: 2020 05 25.csv and 2020 05 26.csv
# Processing files: 2020 05 26.csv and 2020 05 27.csv
# Processing files: 2020 05 27.csv and 2020 05 28.csv
# Processing files: 2020 05 28.csv and 2020 05 29.csv
# Processing files: 2020 05 29.csv and 2020 05 30.csv
# Processing files: 2020 05 30.csv and 2020 05 31.csv
# Processing files: 2020 05 31.csv and 2020 06 01.csv
# Processing files: 2020 06 01.csv and 2020 06 02.csv
# Processing files: 2020 06 02.csv and 2020 06 03.csv
# Processing files: 2020 06 03.csv and 2020 06 04.csv
# Processing files: 2020 06 04.csv and 2020 06 05.csv
# Processing files: 2020 06 05.csv and 2020 06 06.csv
# Processing files: 2020 06 06.csv and 2020 06 07.csv
# Processing files: 2020 06 07.csv and 2020 06 08.csv
# Processing files: 2020 06 08.csv and 2020 06 09.csv
# Processing files: 2020 06 09.csv and 2020 06 10.csv
# Processing files: 2020 06 10.csv and 2020 06 11.csv
# Processing files: 2020 06 11.csv and 2020 06 12.csv
# Processing files: 2020 06 12.csv and 2020 06 13.csv
# Processing files: 2020 06 13.csv and 2020 06 14.csv
# Processing files: 2020 06 14.csv and 2020 06 15.csv
# Processing files: 2020 06 15.csv and 2020 06 16.csv
# Processing files: 2020 06 16.csv and 2020 06 17.csv
# Processing files: 2020 06 17.csv and 2020 06 18.csv
# Processing files: 2020 06 18.csv and 2020 06 19.csv
# Processing files: 2020 06 19.csv and 2020 06 20.csv
# Processing files: 2020 06 20.csv and 2020 06 21.csv
# Processing files: 2020 06 21.csv and 2020 06 22.csv
# Processing files: 2020 06 22.csv and 2020 06 23.csv
# Processing files: 2020 06 23.csv and 2020 06 24.csv
# Processing files: 2020 06 24.csv and 2020 06 25.csv
# Processing files: 2020 06 25.csv and 2020 06 26.csv
# Processing files: 2020 06 26.csv and 2020 06 27.csv
# Processing files: 2020 06 27.csv and 2020 06 28.csv
# Processing files: 2020 06 28.csv and 2020 06 29.csv
# Processing files: 2020 06 29.csv and 2020 06 30.csv
# Processing files: 2020 06 30.csv and 2020 07 01.csv
# Processing files: 2020 07 01.csv and 2020 07 02.csv
# Processing files: 2020 07 02.csv and 2020 07 03.csv
# Processing files: 2020 07 03.csv and 2020 07 04.csv
# Processing files: 2020 07 04.csv and 2020 07 05.csv
# Processing files: 2020 07 05.csv and 2020 07 06.csv
# Processing files: 2020 07 06.csv and 2020 07 07.csv
# Processing files: 2020 07 07.csv and 2020 07 08.csv
# Processing files: 2020 07 08.csv and 2020 07 09.csv
# Processing files: 2020 07 09.csv and 2020 07 10.csv
# Processing files: 2020 07 10.csv and 2020 07 11.csv
# Processing files: 2020 07 11.csv and 2020 07 12.csv
# Processing files: 2020 07 12.csv and 2020 07 13.csv
# Processing files: 2020 07 13.csv and 2020 07 14.csv
# Processing files: 2020 07 14.csv and 2020 07 15.csv
# Processing files: 2020 07 15.csv and 2020 07 16.csv
# Processing files: 2020 07 16.csv and 2020 07 17.csv
# Processing files: 2020 07 17.csv and 2020 07 18.csv
# Processing files: 2020 07 18.csv and 2020 07 19.csv
# Processing files: 2020 07 19.csv and 2020 07 20.csv
# Processing files: 2020 07 20.csv and 2020 07 21.csv
# Processing files: 2020 07 21.csv and 2020 07 22.csv
# Processing files: 2020 07 22.csv and 2020 07 23.csv
# Processing files: 2020 07 23.csv and 2020 07 24.csv
# Processing files: 2020 07 24.csv and 2020 07 25.csv
# Processing files: 2020 07 25.csv and 2020 07 26.csv
# Processing files: 2020 07 26.csv and 2020 07 27.csv
# Processing files: 2020 07 27.csv and 2020 07 28.csv
# Processing files: 2020 07 28.csv and 2020 07 29.csv
# Processing files: 2020 07 29.csv and 2020 07 30.csv
# Processing files: 2020 07 30.csv and 2020 07 31.csv
# Processing files: 2020 07 31.csv and 2020 08 01.csv
# Processing files: 2020 08 01.csv and 2020 08 02.csv
# Processing files: 2020 08 02.csv and 2020 08 03.csv
# Processing files: 2020 08 03.csv and 2020 08 04.csv
# Processing files: 2020 08 04.csv and 2020 08 05.csv
# Processing files: 2020 08 05.csv and 2020 08 06.csv
# Processing files: 2020 08 06.csv and 2020 08 07.csv
# Processing files: 2020 08 07.csv and 2020 08 08.csv
# Processing files: 2020 08 08.csv and 2020 08 09.csv
# Processing files: 2020 08 09.csv and 2020 08 10.csv
# Processing files: 2020 08 10.csv and 2020 08 11.csv
# Processing files: 2020 08 11.csv and 2020 08 12.csv
# Processing files: 2020 08 12.csv and 2020 08 13.csv
# Processing files: 2020 08 13.csv and 2020 08 14.csv
# Processing files: 2020 08 14.csv and 2020 08 15.csv
# Processing files: 2020 08 15.csv and 2020 08 16.csv
# Processing files: 2020 08 16.csv and 2020 08 17.csv
# Processing files: 2020 08 17.csv and 2020 08 18.csv
# Processing files: 2020 08 18.csv and 2020 08 19.csv
# Processing files: 2020 08 19.csv and 2020 08 20.csv
# Processing files: 2020 08 20.csv and 2020 08 21.csv
# Processing files: 2020 08 21.csv and 2020 08 22.csv
# Processing files: 2020 08 22.csv and 2020 08 23.csv
# Processing files: 2020 08 23.csv and 2020 08 24.csv
# Processing files: 2020 08 24.csv and 2020 08 25.csv
# Processing files: 2020 08 25.csv and 2020 08 26.csv
# Processing files: 2020 08 26.csv and 2020 08 27.csv
# Processing files: 2020 08 27.csv and 2020 08 28.csv
# Processing files: 2020 08 28.csv and 2020 08 29.csv
# Processing files: 2020 08 29.csv and 2020 08 30.csv
# Processing files: 2020 08 30.csv and 2020 08 31.csv
# Processing files: 2020 08 31.csv and 2020 09 01.csv
# Processing files: 2020 09 01.csv and 2020 09 02.csv
# Processing files: 2020 09 02.csv and 2020 09 03.csv
# Processing files: 2020 09 03.csv and 2020 09 04.csv
# Processing files: 2020 09 04.csv and 2020 09 05.csv
# Processing files: 2020 09 05.csv and 2020 09 06.csv
# Processing files: 2020 09 06.csv and 2020 09 07.csv
# Processing files: 2020 09 07.csv and 2020 09 08.csv
# Processing files: 2020 09 08.csv and 2020 09 09.csv
# Processing files: 2020 09 09.csv and 2020 09 10.csv
# Processing files: 2020 09 10.csv and 2020 09 11.csv
# Processing files: 2020 09 11.csv and 2020 09 12.csv
# Processing files: 2020 09 12.csv and 2020 09 13.csv
# Processing files: 2020 09 13.csv and 2020 09 14.csv
# Processing files: 2020 09 14.csv and 2020 09 15.csv
# Processing files: 2020 09 15.csv and 2020 09 16.csv
# Processing files: 2020 09 16.csv and 2020 09 17.csv
# Processing files: 2020 09 17.csv and 2020 09 18.csv
# Processing files: 2020 09 18.csv and 2020 09 19.csv
# Processing files: 2020 09 19.csv and 2020 09 20.csv
# Processing files: 2020 09 20.csv and 2020 09 21.csv
# Processing files: 2020 09 21.csv and 2020 09 22.csv
# Processing files: 2020 09 22.csv and 2020 09 23.csv
# Processing files: 2020 09 23.csv and 2020 09 24.csv
# Processing files: 2020 09 24.csv and 2020 09 25.csv
# Processing files: 2020 09 25.csv and 2020 09 26.csv
# Processing files: 2020 09 26.csv and 2020 09 27.csv
# Processing files: 2020 09 27.csv and 2020 09 28.csv
# Processing files: 2020 09 28.csv and 2020 09 29.csv
# Processing files: 2020 09 29.csv and 2020 09 30.csv
# Processing files: 2020 09 30.csv and 2020 10 01.csv
# Processing files: 2020 10 01.csv and 2020 10 02.csv
# Processing files: 2020 10 02.csv and 2020 10 03.csv
# Processing files: 2020 10 03.csv and 2020 10 04.csv
# Processing files: 2020 10 04.csv and 2020 10 05.csv
# Processing files: 2020 10 05.csv and 2020 10 06.csv
# Processing files: 2020 10 06.csv and 2020 10 07.csv
# Processing files: 2020 10 07.csv and 2020 10 08.csv
# Processing files: 2020 10 08.csv and 2020 10 09.csv
# Processing files: 2020 10 09.csv and 2020 10 10.csv
# Processing files: 2020 10 10.csv and 2020 10 11.csv
# Processing files: 2020 10 11.csv and 2020 10 12.csv
# Processing files: 2020 10 12.csv and 2020 10 13.csv
# Processing files: 2020 10 13.csv and 2020 10 14.csv
# Processing files: 2020 10 14.csv and 2020 10 15.csv
# Processing files: 2020 10 15.csv and 2020 10 16.csv
# Processing files: 2020 10 16.csv and 2020 10 17.csv
# Processing files: 2020 10 17.csv and 2020 10 18.csv
# Processing files: 2020 10 18.csv and 2020 10 19.csv
# Processing files: 2020 10 19.csv and 2020 10 20.csv
# Processing files: 2020 10 20.csv and 2020 10 21.csv
# Processing files: 2020 10 21.csv and 2020 10 22.csv
# Processing files: 2020 10 22.csv and 2020 10 23.csv
# Processing files: 2020 10 23.csv and 2020 10 24.csv
# Processing files: 2020 10 24.csv and 2020 10 25.csv
# Processing files: 2020 10 25.csv and 2020 10 26.csv
# Processing files: 2020 10 26.csv and 2020 10 27.csv
# Processing files: 2020 10 27.csv and 2020 10 28.csv
# Processing files: 2020 10 28.csv and 2020 10 29.csv
# Processing files: 2020 10 29.csv and 2020 10 30.csv
# Processing files: 2020 10 30.csv and 2020 10 31.csv
# Processing files: 2020 10 31.csv and 2020 11 01.csv
# Processing files: 2020 11 01.csv and 2020 11 02.csv
# Processing files: 2020 11 02.csv and 2020 11 03.csv
# Processing files: 2020 11 03.csv and 2020 11 04.csv
# Processing files: 2020 11 04.csv and 2020 11 05.csv
# Processing files: 2020 11 05.csv and 2020 11 06.csv
# Processing files: 2020 11 06.csv and 2020 11 07.csv
# Processing files: 2020 11 07.csv and 2020 11 08.csv
# Processing files: 2020 11 08.csv and 2020 11 09.csv
# Processing files: 2020 11 09.csv and 2020 11 10.csv
# Processing files: 2020 11 10.csv and 2020 11 11.csv
# Processing files: 2020 11 11.csv and 2020 11 12.csv
# Processing files: 2020 11 12.csv and 2020 11 13.csv
# Processing files: 2020 11 13.csv and 2020 11 14.csv
# Processing files: 2020 11 14.csv and 2020 11 15.csv
# Processing files: 2020 11 15.csv and 2020 11 16.csv
# Processing files: 2020 11 16.csv and 2020 11 17.csv
# Processing files: 2020 11 17.csv and 2020 11 18.csv
# Processing files: 2020 11 18.csv and 2020 11 19.csv
# Processing files: 2020 11 19.csv and 2020 11 20.csv
# ...
# Processing files: 2020 04 14.csv and 2020 04 15.csv
# Processing files: 2020 04 15.csv and 2020 04 16.csv
# Processing files: 2020 04 16.csv and 2020 04 17.csv
# Processing files: 2020 04 17.csv and 2020 04 18.csv
# Processing files: 2020 04 18.csv and 2020 04 19.csv
# Processing files: 2020 04 19.csv and 2020 04 20.csv
# Processing files: 2020 04 20.csv and 2020 04 21.csv
# Processing files: 2020 04 21.csv and 2020 04 22.csv
# Processing files: 2020 04 22.csv and 2020 04 23.csv
# Processing files: 2020 04 23.csv and 2020 04 24.csv
# Processing files: 2020 04 24.csv and 2020 04 25.csv
# Processing files: 2020 04 25.csv and 2020 04 26.csv
# Processing files: 2020 04 26.csv and 2020 04 27.csv
# Processing files: 2020 04 27.csv and 2020 04 28.csv
# Processing files: 2020 04 28.csv and 2020 04 29.csv
# Processing files: 2020 04 29.csv and 2020 04 30.csv
# Processing files: 2020 04 30.csv and 2020 05 01.csv
# Processing files: 2020 05 01.csv and 2020 05 02.csv
# Processing files: 2020 05 02.csv and 2020 05 03.csv
# Processing files: 2020 05 03.csv and 2020 05 04.csv
# Processing files: 2020 05 04.csv and 2020 05 05.csv
# Processing files: 2020 05 05.csv and 2020 05 06.csv
# Processing files: 2020 05 06.csv and 2020 05 07.csv
# Processing files: 2020 05 07.csv and 2020 05 08.csv
# Processing files: 2020 05 08.csv and 2020 05 09.csv
# Processing files: 2020 05 09.csv and 2020 05 10.csv
# Processing files: 2020 05 10.csv and 2020 05 11.csv
# Processing files: 2020 05 11.csv and 2020 05 12.csv
# Processing files: 2020 05 12.csv and 2020 05 13.csv
# Processing files: 2020 05 13.csv and 2020 05 14.csv
# Processing files: 2020 05 14.csv and 2020 05 15.csv
# Processing files: 2020 05 15.csv and 2020 05 16.csv
# Processing files: 2020 05 16.csv and 2020 05 17.csv
# Processing files: 2020 05 17.csv and 2020 05 18.csv
# Processing files: 2020 05 18.csv and 2020 05 19.csv
# Processing files: 2020 05 19.csv and 2020 05 20.csv
# Processing files: 2020 05 20.csv and 2020 05 21.csv
# Processing files: 2020 05 21.csv and 2020 05 22.csv
# Processing files: 2020 05 22.csv and 2020 05 23.csv
# Processing files: 2020 05 23.csv and 2020 05 24.csv
# Processing files: 2020 05 24.csv and 2020 05 25.csv
# Processing files: 2020 05 25.csv and 2020 05 26.csv
# Processing files: 2020 05 26.csv and 2020 05 27.csv
# Processing files: 2020 05 27.csv and 2020 05 28.csv
# Processing files: 2020 05 28.csv and 2020 05 29.csv
# Processing files: 2020 05 29.csv and 2020 05 30.csv
# Processing files: 2020 05 30.csv and 2020 05 31.csv
# Processing files: 2020 05 31.csv and 2020 06 01.csv
# Processing files: 2020 06 01.csv and 2020 06 02.csv
# Processing files: 2020 06 02.csv and 2020 06 03.csv
# Processing files: 2020 06 03.csv and 2020 06 04.csv
# Processing files: 2020 06 04.csv and 2020 06 05.csv
# Processing files: 2020 06 05.csv and 2020 06 06.csv
# Processing files: 2020 06 06.csv and 2020 06 07.csv
# Processing files: 2020 06 07.csv and 2020 06 08.csv
# Processing files: 2020 06 08.csv and 2020 06 09.csv
# Processing files: 2020 06 09.csv and 2020 06 10.csv
# Processing files: 2020 06 10.csv and 2020 06 11.csv
# Processing files: 2020 06 11.csv and 2020 06 12.csv
# Processing files: 2020 06 12.csv and 2020 06 13.csv
# Processing files: 2020 06 13.csv and 2020 06 14.csv
# Processing files: 2020 06 14.csv and 2020 06 15.csv
# Processing files: 2020 06 15.csv and 2020 06 16.csv
# Processing files: 2020 06 16.csv and 2020 06 17.csv
# Processing files: 2020 06 17.csv and 2020 06 18.csv
# Processing files: 2020 06 18.csv and 2020 06 19.csv
# Processing files: 2020 06 19.csv and 2020 06 20.csv
# Processing files: 2020 06 20.csv and 2020 06 21.csv
# Processing files: 2020 06 21.csv and 2020 06 22.csv
# Processing files: 2020 06 22.csv and 2020 06 23.csv
# Processing files: 2020 06 23.csv and 2020 06 24.csv
# Processing files: 2020 06 24.csv and 2020 06 25.csv
# Processing files: 2020 06 25.csv and 2020 06 26.csv
# Processing files: 2020 06 26.csv and 2020 06 27.csv
# Processing files: 2020 06 27.csv and 2020 06 28.csv
# Processing files: 2020 06 28.csv and 2020 06 29.csv
# Processing files: 2020 06 29.csv and 2020 06 30.csv
# Processing files: 2020 06 30.csv and 2020 07 01.csv
# Processing files: 2020 07 01.csv and 2020 07 02.csv
# Processing files: 2020 07 02.csv and 2020 07 03.csv
# Processing files: 2020 07 03.csv and 2020 07 04.csv
# Processing files: 2020 07 04.csv and 2020 07 05.csv
# Processing files: 2020 07 05.csv and 2020 07 06.csv
# Processing files: 2020 07 06.csv and 2020 07 07.csv
# Processing files: 2020 07 07.csv and 2020 07 08.csv
# Processing files: 2020 07 08.csv and 2020 07 09.csv
# Processing files: 2020 07 09.csv and 2020 07 10.csv
# Processing files: 2020 07 10.csv and 2020 07 11.csv
# Processing files: 2020 07 11.csv and 2020 07 12.csv
# Processing files: 2020 07 12.csv and 2020 07 13.csv
# Processing files: 2020 07 13.csv and 2020 07 14.csv
# Processing files: 2020 07 14.csv and 2020 07 15.csv
# Processing files: 2020 07 15.csv and 2020 07 16.csv
# Processing files: 2020 07 16.csv and 2020 07 17.csv
# Processing files: 2020 07 17.csv and 2020 07 18.csv
# Processing files: 2020 07 18.csv and 2020 07 19.csv
# Processing files: 2020 07 19.csv and 2020 07 20.csv
# Processing files: 2020 07 20.csv and 2020 07 21.csv
# Processing files: 2020 07 21.csv and 2020 07 22.csv
# Processing files: 2020 07 22.csv and 2020 07 23.csv
# Processing files: 2020 07 23.csv and 2020 07 24.csv
# Processing files: 2020 07 24.csv and 2020 07 25.csv
# Processing files: 2020 07 25.csv and 2020 07 26.csv
# Processing files: 2020 07 26.csv and 2020 07 27.csv
# Processing files: 2020 07 27.csv and 2020 07 28.csv
# Processing files: 2020 07 28.csv and 2020 07 29.csv
# Processing files: 2020 07 29.csv and 2020 07 30.csv
# Processing files: 2020 07 30.csv and 2020 07 31.csv
# Processing files: 2020 07 31.csv and 2020 08 01.csv
# Processing files: 2020 08 01.csv and 2020 08 02.csv
# Processing files: 2020 08 02.csv and 2020 08 03.csv
# Processing files: 2020 08 03.csv and 2020 08 04.csv
# Processing files: 2020 08 04.csv and 2020 08 05.csv
# Processing files: 2020 08 05.csv and 2020 08 06.csv
# Processing files: 2020 08 06.csv and 2020 08 07.csv
# Processing files: 2020 08 07.csv and 2020 08 08.csv
# Processing files: 2020 08 08.csv and 2020 08 09.csv
# Processing files: 2020 08 09.csv and 2020 08 10.csv
# Processing files: 2020 08 10.csv and 2020 08 11.csv
# Processing files: 2020 08 11.csv and 2020 08 12.csv
# Processing files: 2020 08 12.csv and 2020 08 13.csv
# Processing files: 2020 08 13.csv and 2020 08 14.csv
# Processing files: 2020 08 14.csv and 2020 08 15.csv
# Processing files: 2020 08 15.csv and 2020 08 16.csv
# Processing files: 2020 08 16.csv and 2020 08 17.csv
# Processing files: 2020 08 17.csv and 2020 08 18.csv
# Processing files: 2020 08 18.csv and 2020 08 19.csv
# Processing files: 2020 08 19.csv and 2020 08 20.csv
# Processing files: 2020 08 20.csv and 2020 08 21.csv
# Processing files: 2020 08 21.csv and 2020 08 22.csv
# Processing files: 2020 08 22.csv and 2020 08 23.csv
# Processing files: 2020 08 23.csv and 2020 08 24.csv
# Processing files: 2020 08 24.csv and 2020 08 25.csv
# Processing files: 2020 08 25.csv and 2020 08 26.csv
# Processing files: 2020 08 26.csv and 2020 08 27.csv
# Processing files: 2020 08 27.csv and 2020 08 28.csv
# Processing files: 2020 08 28.csv and 2020 08 29.csv
# Processing files: 2020 08 29.csv and 2020 08 30.csv
# Processing files: 2020 08 30.csv and 2020 08 31.csv
# Processing files: 2020 08 31.csv and 2020 09 01.csv
# Processing files: 2020 09 01.csv and 2020 09 02.csv
# Processing files: 2020 09 02.csv and 2020 09 03.csv
# Processing files: 2020 09 03.csv and 2020 09 04.csv
# Processing files: 2020 09 04.csv and 2020 09 05.csv
# Processing files: 2020 09 05.csv and 2020 09 06.csv
# Processing files: 2020 09 06.csv and 2020 09 07.csv
# Processing files: 2020 09 07.csv and 2020 09 08.csv
# Processing files: 2020 09 08.csv and 2020 09 09.csv
# Processing files: 2020 09 09.csv and 2020 09 10.csv
# Processing files: 2020 09 10.csv and 2020 09 11.csv
# Processing files: 2020 09 11.csv and 2020 09 12.csv
# Processing files: 2020 09 12.csv and 2020 09 13.csv
# Processing files: 2020 09 13.csv and 2020 09 14.csv
# Processing files: 2020 09 14.csv and 2020 09 15.csv
# Processing files: 2020 09 15.csv and 2020 09 16.csv
# Processing files: 2020 09 16.csv and 2020 09 17.csv
# Processing files: 2020 09 17.csv and 2020 09 18.csv
# Processing files: 2020 09 18.csv and 2020 09 19.csv
# Processing files: 2020 09 19.csv and 2020 09 20.csv
# Processing files: 2020 09 20.csv and 2020 09 21.csv
# Processing files: 2020 09 21.csv and 2020 09 22.csv
# Processing files: 2020 09 22.csv and 2020 09 23.csv
# Processing files: 2020 09 23.csv and 2020 09 24.csv
# Processing files: 2020 09 24.csv and 2020 09 25.csv
# Processing files: 2020 09 25.csv and 2020 09 26.csv
# Processing files: 2020 09 26.csv and 2020 09 27.csv
# Processing files: 2020 09 27.csv and 2020 09 28.csv
# Processing files: 2020 09 28.csv and 2020 09 29.csv
# Processing files: 2020 09 29.csv and 2020 09 30.csv
# Processing files: 2020 09 30.csv and 2020 10 01.csv
# Processing files: 2020 10 01.csv and 2020 10 02.csv
# Processing files: 2020 10 02.csv and 2020 10 03.csv
# Processing files: 2020 10 03.csv and 2020 10 04.csv
# Processing files: 2020 10 04.csv and 2020 10 05.csv
# Processing files: 2020 10 05.csv and 2020 10 06.csv
# Processing files: 2020 10 06.csv and 2020 10 07.csv
# Processing files: 2020 10 07.csv and 2020 10 08.csv
# Processing files: 2020 10 08.csv and 2020 10 09.csv
# Processing files: 2020 10 09.csv and 2020 10 10.csv
# Processing files: 2020 10 10.csv and 2020 10 11.csv
# Processing files: 2020 10 11.csv and 2020 10 12.csv
# Processing files: 2020 10 12.csv and 2020 10 13.csv
# Processing files: 2020 10 13.csv and 2020 10 14.csv
# Processing files: 2020 10 14.csv and 2020 10 15.csv
# Processing files: 2020 10 15.csv and 2020 10 16.csv
# Processing files: 2020 10 16.csv and 2020 10 17.csv
# Processing files: 2020 10 17.csv and 2020 10 18.csv
# Processing files: 2020 10 18.csv and 2020 10 19.csv
# Processing files: 2020 10 19.csv and 2020 10 20.csv
# Processing files: 2020 10 20.csv and 2020 10 21.csv
# Processing files: 2020 10 21.csv and 2020 10 22.csv
# Processing files: 2020 10 22.csv and 2020 10 23.csv
# Processing files: 2020 10 23.csv and 2020 10 24.csv
# Processing files: 2020 10 24.csv and 2020 10 25.csv
# Processing files: 2020 10 25.csv and 2020 10 26.csv
# Processing files: 2020 10 26.csv and 2020 10 27.csv
# Processing files: 2020 10 27.csv and 2020 10 28.csv
# Processing files: 2020 10 28.csv and 2020 10 29.csv
# Processing files: 2020 10 29.csv and 2020 10 30.csv
# Processing files: 2020 10 30.csv and 2020 10 31.csv
# Processing files: 2020 10 31.csv and 2020 11 01.csv
# Processing files: 2020 11 01.csv and 2020 11 02.csv
# Processing files: 2020 11 02.csv and 2020 11 03.csv
# Processing files: 2020 11 03.csv and 2020 11 04.csv
# Processing files: 2020 11 04.csv and 2020 11 05.csv
# Processing files: 2020 11 05.csv and 2020 11 06.csv
# Processing files: 2020 11 06.csv and 2020 11 07.csv
# Processing files: 2020 11 07.csv and 2020 11 08.csv
# Processing files: 2020 11 08.csv and 2020 11 09.csv
# Processing files: 2020 11 09.csv and 2020 11 10.csv
# Processing files: 2020 11 10.csv and 2020 11 11.csv
# Processing files: 2020 11 11.csv and 2020 11 12.csv
# Processing files: 2020 11 12.csv and 2020 11 13.csv
# Processing files: 2020 11 13.csv and 2020 11 14.csv
# Processing files: 2020 11 14.csv and 2020 11 15.csv
# Processing files: 2020 11 15.csv and 2020 11 16.csv
# Processing files: 2020 11 16.csv and 2020 11 17.csv
# Processing files: 2020 11 17.csv and 2020 11 18.csv
# Processing files: 2020 11 18.csv and 2020 11 19.csv
# Processing files: 2020 11 19.csv and 2020 11 20.csv
# Processing files: 2020 11 20.csv and 2020 11 21.csv
# Processing files: 2020 11 21.csv and 2020 11 22.csv
# Processing files: 2020 11 22.csv and 2020 11 23.csv
# Processing files: 2020 11 23.csv and 2020 11 24.csv
# Processing files: 2020 11 24.csv and 2020 11 25.csv
# Processing files: 2020 11 25.csv and 2020 11 26.csv
# Processing files: 2020 11 26.csv and 2020 11 27.csv
# Processing files: 2020 11 27.csv and 2020 11 28.csv
# Processing files: 2020 11 28.csv and 2020 11 29.csv
# Processing files: 2020 11 29.csv and 2020 11 30.csv
# Processing files: 2020 11 30.csv and 2020 12 01.csv
# Processing files: 2020 12 01.csv and 2020 12 02.csv
# Processing files: 2020 12 02.csv and 2020 12 03.csv
# Processing files: 2020 12 03.csv and 2020 12 04.csv
# Processing files: 2020 12 04.csv and 2020 12 05.csv
# Processing files: 2020 12 05.csv and 2020 12 06.csv
# Processing files: 2020 12 06.csv and 2020 12 07.csv
# Processing files: 2020 12 07.csv and 2020 12 08.csv
# Processing files: 2020 12 08.csv and 2020 12 09.csv
# Processing files: 2020 12 09.csv and 2020 12 10.csv
# Processing files: 2020 12 10.csv and 2020 12 11.csv
# Processing files: 2020 12 11.csv and 2020 12 12.csv
# Processing files: 2020 12 12.csv and 2020 12 13.csv
# Processing files: 2020 12 13.csv and 2020 12 14.csv
# Processing files: 2020 12 14.csv and 2020 12 15.csv
# Processing files: 2020 12 15.csv and 2020 12 16.csv
# Processing files: 2020 12 16.csv and 2020 12 17.csv
# Processing files: 2020 12 17.csv and 2020 12 18.csv
# Processing files: 2020 12 18.csv and 2020 12 19.csv
# Processing files: 2020 12 19.csv and 2020 12 20.csv
# Processing files: 2020 12 20.csv and 2020 12 21.csv
# Processing files: 2020 12 21.csv and 2020 12 22.csv
# Processing files: 2020 12 22.csv and 2020 12 23.csv
# Processing files: 2020 12 23.csv and 2020 12 24.csv
# Processing files: 2020 12 24.csv and 2020 12 25.csv
# Processing files: 2020 12 25.csv and 2020 12 26.csv
# Processing files: 2020 12 26.csv and 2020 12 27.csv
# Processing files: 2020 12 27.csv and 2020 12 28.csv
# Processing files: 2020 12 28.csv and 2020 12 29.csv
# Processing files: 2020 12 29.csv and 2020 12 30.csv
# Processing files: 2020 12 30.csv and 2020 12 31.csv
# Processing files: 2020 12 31.csv and 2021 01 01.csv
# Processing files: 2021 01 01.csv and 2021 01 02.csv
# Processing files: 2021 01 02.csv and 2021 01 03.csv
# Processing files: 2021 01 03.csv and 2021 01 04.csv
# Processing files: 2021 01 04.csv and 2021 01 05.csv
# Processing files: 2021 01 05.csv and 2021 01 06.csv
# Processing files: 2021 01 06.csv and 2021 01 07.csv
# Processing files: 2021 01 07.csv and 2021 01 08.csv
# Processing files: 2021 01 08.csv and 2021 01 09.csv
# Processing files: 2021 01 09.csv and 2021 01 10.csv
# Processing files: 2021 01 10.csv and 2021 01 11.csv
# Processing files: 2021 01 11.csv and 2021 01 12.csv
# Processing files: 2021 01 12.csv and 2021 01 13.csv
# Processing files: 2021 01 13.csv and 2021 01 14.csv
# Processing files: 2021 01 14.csv and 2021 01 15.csv
# Processing files: 2021 01 15.csv and 2021 01 16.csv
# Processing files: 2021 01 16.csv and 2021 01 17.csv
# Processing files: 2021 01 17.csv and 2021 01 18.csv
# Processing files: 2021 01 18.csv and 2021 01 19.csv
# Processing files: 2021 01 19.csv and 2021 01 20.csv
# Processing files: 2021 01 20.csv and 2021 01 21.csv
# Processing files: 2021 01 21.csv and 2021 01 22.csv
# Processing files: 2021 01 22.csv and 2021 01 23.csv
# Processing files: 2021 01 23.csv and 2021 01 24.csv
# Processing files: 2021 01 24.csv and 2021 01 25.csv
# Processing files: 2021 01 25.csv and 2021 01 26.csv
# Processing files: 2021 01 26.csv and 2021 01 27.csv
# Processing files: 2021 01 27.csv and 2021 01 28.csv
# Processing files: 2021 01 28.csv and 2021 01 29.csv
# Processing files: 2021 01 29.csv and 2021 01 30.csv
# Processing files: 2021 01 30.csv and 2021 01 31.csv
# Processing files: 2021 01 31.csv and 2021 02 01.csv
# Processing files: 2021 02 01.csv and 2021 02 02.csv
# Processing files: 2021 02 02.csv and 2021 02 03.csv
# Processing files: 2021 02 03.csv and 2021 02 04.csv
# Processing files: 2021 02 04.csv and 2021 02 05.csv
# Processing files: 2021 02 05.csv and 2021 02 06.csv
# Processing files: 2021 02 06.csv and 2021 02 07.csv
# Processing files: 2021 02 07.csv and 2021 02 08.csv
# Processing files: 2021 02 08.csv and 2021 02 09.csv
# Processing files: 2021 02 09.csv and 2021 02 10.csv
# Processing files: 2021 02 10.csv and 2021 02 11.csv
# Processing files: 2021 02 11.csv and 2021 02 12.csv
# Processing files: 2021 02 12.csv and 2021 02 13.csv
# Processing files: 2021 02 13.csv and 2021 02 14.csv
# Saved processed data to work-from-home_msv_stitched_30day.csv
