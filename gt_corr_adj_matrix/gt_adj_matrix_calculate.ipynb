# %%
import pandas as pd
import os
import numpy as np
from datetime import datetime

# %%
def create_adjacency_matrix(correlation_matrix, threshold):
    """
    Convert correlation matrix to adjacency matrix using threshold.
    Only fills lower triangular part, leaving other cells empty
    """
    # Create empty matrix of same size as correlation matrix
    n = len(correlation_matrix)
    adjacency = pd.DataFrame(
        np.nan,  # Fill with NaN initially
        index=correlation_matrix.index,
        columns=correlation_matrix.columns
    )
    
    # Fill only lower triangular part
    for i in range(n):
        for j in range(i + 1):  # Only up to i (lower triangle including diagonal)
            value = correlation_matrix.iloc[i, j]
            try:
                # Convert to binary based on threshold
                adjacency.iloc[i, j] = 1 if float(value) >= threshold else 0
            except (ValueError, TypeError):
                # Handle any non-numeric values
                adjacency.iloc[i, j] = 0
            
    return adjacency

# %%
def process_correlation_matrices(source_dir, dest_dir, matrix_type):
    """
    Process all correlation matrices in source directory.
    matrix_type should be 'msv' or 'rsv'
    """
    thresholds = [0.4, 0.5, 0.6, 0.8]
    
    # Get all CSV files in source directory
    correlation_files = sorted([f for f in os.listdir(source_dir) if f.endswith('.csv')])
    
    for correlation_file in correlation_files:
        print(f"\nProcessing: {correlation_file}")
        
        # Extract date from filename
        date_parts = correlation_file.split('_')[-3:]  # Get last three parts
        year = date_parts[0]
        month = date_parts[1]
        day = date_parts[2].replace('.csv', '')
        
        # Read correlation matrix
        correlation_matrix = pd.read_csv(os.path.join(source_dir, correlation_file), index_col=0)
        
        # Process for each threshold
        for threshold in thresholds:
            # Create adjacency matrix
            adjacency_matrix = create_adjacency_matrix(correlation_matrix, threshold)
            
            # Create filename for adjacency matrix
            adj_filename = f"{matrix_type}_{threshold}_{year}_{month}_{day}.csv"
            
            # Define destination path
            threshold_dir = f"{threshold}_threshold"
            dest_path = os.path.join(dest_dir, threshold_dir, adj_filename)
            
            # Save adjacency matrix
            adjacency_matrix.to_csv(dest_path)
            print(f"Created adjacency matrix for threshold {threshold}: {adj_filename}")

# %%
# Define source and destination directories
source_dirs = [
    "./gt_dcorr_matrices_msv_15day",
    "./gt_dcorr_matrices_msv_30day",
    "./gt_dcorr_matrices_rsv_normal_15day",
    "./gt_dcorr_matrices_rsv_normal_30day"
]

dest_dirs = [
    "./gt_adj_matrices_msv_15day",
    "./gt_adj_matrices_msv_30day",
    "./gt_adj_matrices_rsv_normal_15day",
    "./gt_adj_matrices_rsv_normal_30day"
]

# %%
# Process each directory
for source_dir, dest_dir in zip(source_dirs, dest_dirs):
    print(f"\nProcessing directory: {source_dir}")
    
    # Determine matrix type (msv or rsv)
    matrix_type = "msv" if "msv" in source_dir else "rsv"
    
    # Process matrices
    if os.path.exists(source_dir):
        process_correlation_matrices(source_dir, dest_dir, matrix_type)
    else:
        print(f"Source directory not found: {source_dir}")
# Out:
# Processing directory: ./gt_dcorr_matrices_msv_15day
#
# Processing: msv_distance_correlation_2020_03_30.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_03_30.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_03_30.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_03_30.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_03_30.csv
#
# Processing: msv_distance_correlation_2020_03_31.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_03_31.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_03_31.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_03_31.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_03_31.csv
#
# Processing: msv_distance_correlation_2020_04_01.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_01.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_01.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_01.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_01.csv
#
# Processing: msv_distance_correlation_2020_04_02.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_02.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_02.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_02.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_02.csv
#
# Processing: msv_distance_correlation_2020_04_03.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_03.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_03.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_03.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_03.csv
#
# Processing: msv_distance_correlation_2020_04_04.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_04.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_04.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_04.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_04.csv
#
# Processing: msv_distance_correlation_2020_04_05.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_05.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_05.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_05.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_05.csv
#
# Processing: msv_distance_correlation_2020_04_06.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_06.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_06.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_06.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_06.csv
#
# Processing: msv_distance_correlation_2020_04_07.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_07.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_07.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_07.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_07.csv
#
# Processing: msv_distance_correlation_2020_04_08.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_08.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_08.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_08.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_08.csv
#
# Processing: msv_distance_correlation_2020_04_09.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_09.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_09.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_09.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_09.csv
#
# Processing: msv_distance_correlation_2020_04_10.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_10.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_10.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_10.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_10.csv
#
# Processing: msv_distance_correlation_2020_04_11.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_11.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_11.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_11.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_11.csv
#
# Processing: msv_distance_correlation_2020_04_12.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_12.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_12.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_12.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_12.csv
#
# Processing: msv_distance_correlation_2020_04_13.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_13.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_13.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_13.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_13.csv
#
# Processing: msv_distance_correlation_2020_04_14.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_14.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_14.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_14.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_14.csv
#
# Processing: msv_distance_correlation_2020_04_15.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_15.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_15.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_15.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_15.csv
#
# Processing: msv_distance_correlation_2020_04_16.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_16.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_16.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_16.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_16.csv
#
# Processing: msv_distance_correlation_2020_04_17.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_17.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_17.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_17.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_17.csv
#
# Processing: msv_distance_correlation_2020_04_18.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_18.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_18.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_18.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_18.csv
#
# Processing: msv_distance_correlation_2020_04_19.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_19.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_19.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_19.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_19.csv
#
# Processing: msv_distance_correlation_2020_04_20.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_20.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_20.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_20.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_20.csv
#
# Processing: msv_distance_correlation_2020_04_21.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_21.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_21.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_21.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_21.csv
#
# Processing: msv_distance_correlation_2020_04_22.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_22.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_22.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_22.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_22.csv
#
# Processing: msv_distance_correlation_2020_04_23.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_23.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_23.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_23.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_23.csv
#
# Processing: msv_distance_correlation_2020_04_24.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_24.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_24.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_24.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_24.csv
#
# Processing: msv_distance_correlation_2020_04_25.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_25.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_25.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_25.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_25.csv
#
# Processing: msv_distance_correlation_2020_04_26.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_26.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_26.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_26.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_26.csv
#
# Processing: msv_distance_correlation_2020_04_27.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_27.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_27.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_27.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_27.csv
#
# Processing: msv_distance_correlation_2020_04_28.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_28.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_28.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_28.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_28.csv
#
# Processing: msv_distance_correlation_2020_04_29.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_29.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_29.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_29.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_29.csv
#
# Processing: msv_distance_correlation_2020_04_30.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_04_30.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_04_30.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_04_30.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_04_30.csv
#
# Processing: msv_distance_correlation_2020_05_01.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_01.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_01.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_01.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_01.csv
#
# Processing: msv_distance_correlation_2020_05_02.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_02.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_02.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_02.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_02.csv
#
# Processing: msv_distance_correlation_2020_05_03.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_03.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_03.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_03.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_03.csv
#
# Processing: msv_distance_correlation_2020_05_04.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_04.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_04.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_04.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_04.csv
#
# Processing: msv_distance_correlation_2020_05_05.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_05.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_05.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_05.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_05.csv
#
# Processing: msv_distance_correlation_2020_05_06.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_06.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_06.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_06.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_06.csv
#
# Processing: msv_distance_correlation_2020_05_07.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_07.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_07.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_07.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_07.csv
#
# Processing: msv_distance_correlation_2020_05_08.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_08.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_08.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_08.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_08.csv
#
# Processing: msv_distance_correlation_2020_05_09.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_09.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_09.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_09.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_09.csv
#
# Processing: msv_distance_correlation_2020_05_10.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_10.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_10.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_10.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_10.csv
#
# Processing: msv_distance_correlation_2020_05_11.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_11.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_11.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_11.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_11.csv
#
# Processing: msv_distance_correlation_2020_05_12.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_12.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_12.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_12.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_12.csv
#
# Processing: msv_distance_correlation_2020_05_13.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_13.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_13.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_13.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_13.csv
#
# Processing: msv_distance_correlation_2020_05_14.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_14.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_14.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_14.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_14.csv
#
# Processing: msv_distance_correlation_2020_05_15.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_15.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_15.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_15.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_15.csv
#
# Processing: msv_distance_correlation_2020_05_16.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_16.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_16.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_16.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_16.csv
#
# Processing: msv_distance_correlation_2020_05_17.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_17.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_17.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_17.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_17.csv
#
# Processing: msv_distance_correlation_2020_05_18.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_18.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_18.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_18.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_18.csv
#
# Processing: msv_distance_correlation_2020_05_19.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_19.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_19.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_19.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_19.csv
#
# Processing: msv_distance_correlation_2020_05_20.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_20.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_20.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_20.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_20.csv
#
# Processing: msv_distance_correlation_2020_05_21.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_21.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_21.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_21.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_21.csv
#
# Processing: msv_distance_correlation_2020_05_22.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_22.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_22.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_22.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_22.csv
#
# Processing: msv_distance_correlation_2020_05_23.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_23.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_23.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_23.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_23.csv
#
# Processing: msv_distance_correlation_2020_05_24.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_24.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_24.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_24.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_24.csv
#
# Processing: msv_distance_correlation_2020_05_25.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_25.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_25.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_25.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_25.csv
#
# Processing: msv_distance_correlation_2020_05_26.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_26.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_26.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_26.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_26.csv
#
# Processing: msv_distance_correlation_2020_05_27.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_27.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_27.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_27.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_27.csv
#
# Processing: msv_distance_correlation_2020_05_28.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_28.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_28.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_28.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_28.csv
#
# Processing: msv_distance_correlation_2020_05_29.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_29.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_29.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_29.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_29.csv
#
# Processing: msv_distance_correlation_2020_05_30.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_30.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_30.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_30.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_30.csv
#
# Processing: msv_distance_correlation_2020_05_31.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_05_31.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_05_31.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_05_31.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_05_31.csv
#
# Processing: msv_distance_correlation_2020_06_01.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_01.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_01.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_01.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_01.csv
#
# Processing: msv_distance_correlation_2020_06_02.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_02.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_02.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_02.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_02.csv
#
# Processing: msv_distance_correlation_2020_06_03.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_03.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_03.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_03.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_03.csv
#
# Processing: msv_distance_correlation_2020_06_04.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_04.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_04.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_04.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_04.csv
#
# Processing: msv_distance_correlation_2020_06_05.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_05.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_05.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_05.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_05.csv
#
# Processing: msv_distance_correlation_2020_06_06.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_06.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_06.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_06.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_06.csv
#
# Processing: msv_distance_correlation_2020_06_07.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_07.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_07.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_07.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_07.csv
#
# Processing: msv_distance_correlation_2020_06_08.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_08.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_08.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_08.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_08.csv
#
# Processing: msv_distance_correlation_2020_06_09.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_09.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_09.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_09.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_09.csv
#
# Processing: msv_distance_correlation_2020_06_10.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_10.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_10.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_10.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_10.csv
#
# Processing: msv_distance_correlation_2020_06_11.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_11.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_11.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_11.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_11.csv
#
# Processing: msv_distance_correlation_2020_06_12.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_12.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_12.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_12.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_12.csv
#
# Processing: msv_distance_correlation_2020_06_13.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_13.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_13.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_13.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_13.csv
#
# Processing: msv_distance_correlation_2020_06_14.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_14.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_14.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_14.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_14.csv
#
# Processing: msv_distance_correlation_2020_06_15.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_15.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_15.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_15.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_15.csv
#
# Processing: msv_distance_correlation_2020_06_16.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_16.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_16.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_16.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_16.csv
#
# Processing: msv_distance_correlation_2020_06_17.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_17.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_17.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_17.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_17.csv
#
# Processing: msv_distance_correlation_2020_06_18.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_18.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_18.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_18.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_18.csv
#
# Processing: msv_distance_correlation_2020_06_19.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_19.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_19.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_19.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_19.csv
#
# Processing: msv_distance_correlation_2020_06_20.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_20.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_20.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_20.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_20.csv
#
# Processing: msv_distance_correlation_2020_06_21.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_21.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_21.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_21.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_21.csv
#
# Processing: msv_distance_correlation_2020_06_22.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_22.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_22.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_22.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_22.csv
#
# Processing: msv_distance_correlation_2020_06_23.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_23.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_23.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_23.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_23.csv
#
# Processing: msv_distance_correlation_2020_06_24.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_24.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_24.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_24.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_24.csv
#
# Processing: msv_distance_correlation_2020_06_25.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_25.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_25.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_25.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_25.csv
#
# Processing: msv_distance_correlation_2020_06_26.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_26.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_26.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_26.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_26.csv
#
# Processing: msv_distance_correlation_2020_06_27.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_27.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_27.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_27.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_27.csv
#
# Processing: msv_distance_correlation_2020_06_28.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_28.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_28.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_28.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_28.csv
#
# Processing: msv_distance_correlation_2020_06_29.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_29.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_29.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_29.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_29.csv
#
# Processing: msv_distance_correlation_2020_06_30.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_06_30.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_06_30.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_06_30.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_06_30.csv
#
# Processing: msv_distance_correlation_2020_07_01.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_01.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_01.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_01.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_01.csv
#
# Processing: msv_distance_correlation_2020_07_02.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_02.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_02.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_02.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_02.csv
#
# Processing: msv_distance_correlation_2020_07_03.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_03.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_03.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_03.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_03.csv
#
# Processing: msv_distance_correlation_2020_07_04.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_04.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_04.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_04.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_04.csv
#
# Processing: msv_distance_correlation_2020_07_05.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_05.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_05.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_05.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_05.csv
#
# Processing: msv_distance_correlation_2020_07_06.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_06.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_06.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_06.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_06.csv
#
# Processing: msv_distance_correlation_2020_07_07.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_07.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_07.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_07.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_07.csv
#
# Processing: msv_distance_correlation_2020_07_08.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_08.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_08.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_08.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_08.csv
#
# Processing: msv_distance_correlation_2020_07_09.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_09.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_09.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_09.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_09.csv
#
# Processing: msv_distance_correlation_2020_07_10.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_10.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_10.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_10.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_10.csv
#
# Processing: msv_distance_correlation_2020_07_11.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_11.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_11.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_11.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_11.csv
#
# Processing: msv_distance_correlation_2020_07_12.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_12.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_12.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_12.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_12.csv
#
# Processing: msv_distance_correlation_2020_07_13.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_13.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_13.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_13.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_13.csv
#
# Processing: msv_distance_correlation_2020_07_14.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_14.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_14.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_14.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_14.csv
#
# Processing: msv_distance_correlation_2020_07_15.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_15.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_15.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_15.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_15.csv
#
# Processing: msv_distance_correlation_2020_07_16.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_16.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_16.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_16.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_16.csv
#
# Processing: msv_distance_correlation_2020_07_17.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_17.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_17.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_17.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_17.csv
#
# Processing: msv_distance_correlation_2020_07_18.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_18.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_18.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_18.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_18.csv
#
# Processing: msv_distance_correlation_2020_07_19.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_19.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_19.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_19.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_19.csv
#
# Processing: msv_distance_correlation_2020_07_20.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_20.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_20.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_20.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_20.csv
#
# Processing: msv_distance_correlation_2020_07_21.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_21.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_21.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_21.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_21.csv
#
# Processing: msv_distance_correlation_2020_07_22.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_22.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_22.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_22.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_22.csv
#
# Processing: msv_distance_correlation_2020_07_23.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_23.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_23.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_23.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_23.csv
#
# Processing: msv_distance_correlation_2020_07_24.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_24.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_24.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_24.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_24.csv
#
# Processing: msv_distance_correlation_2020_07_25.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_25.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_25.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_25.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_25.csv
#
# Processing: msv_distance_correlation_2020_07_26.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_26.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_26.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_26.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_26.csv
#
# Processing: msv_distance_correlation_2020_07_27.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_27.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_27.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_27.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_27.csv
#
# Processing: msv_distance_correlation_2020_07_28.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_28.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_28.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_28.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_28.csv
#
# Processing: msv_distance_correlation_2020_07_29.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_29.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_29.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_29.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_29.csv
#
# Processing: msv_distance_correlation_2020_07_30.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_30.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_30.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_30.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_30.csv
#
# Processing: msv_distance_correlation_2020_07_31.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_07_31.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_07_31.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_07_31.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_07_31.csv
#
# Processing: msv_distance_correlation_2020_08_01.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_01.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_01.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_01.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_01.csv
#
# Processing: msv_distance_correlation_2020_08_02.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_02.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_02.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_02.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_02.csv
#
# Processing: msv_distance_correlation_2020_08_03.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_03.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_03.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_03.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_03.csv
#
# Processing: msv_distance_correlation_2020_08_04.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_04.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_04.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_04.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_04.csv
#
# Processing: msv_distance_correlation_2020_08_05.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_05.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_05.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_05.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_05.csv
#
# Processing: msv_distance_correlation_2020_08_06.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_06.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_06.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_06.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_06.csv
#
# Processing: msv_distance_correlation_2020_08_07.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_07.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_07.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_07.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_07.csv
#
# Processing: msv_distance_correlation_2020_08_08.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_08.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_08.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_08.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_08.csv
#
# Processing: msv_distance_correlation_2020_08_09.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_09.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_09.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_09.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_09.csv
#
# Processing: msv_distance_correlation_2020_08_10.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_10.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_10.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_10.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_10.csv
#
# Processing: msv_distance_correlation_2020_08_11.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_11.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_11.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_11.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_11.csv
#
# Processing: msv_distance_correlation_2020_08_12.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_12.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_12.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_12.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_12.csv
#
# Processing: msv_distance_correlation_2020_08_13.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_13.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_13.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_13.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_13.csv
#
# Processing: msv_distance_correlation_2020_08_14.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_14.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_14.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_14.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_14.csv
#
# Processing: msv_distance_correlation_2020_08_15.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_15.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_15.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_15.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_15.csv
#
# Processing: msv_distance_correlation_2020_08_16.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_16.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_16.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_16.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_16.csv
#
# Processing: msv_distance_correlation_2020_08_17.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_17.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_17.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_17.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_17.csv
#
# Processing: msv_distance_correlation_2020_08_18.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_18.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_18.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_18.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_18.csv
#
# Processing: msv_distance_correlation_2020_08_19.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_19.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_19.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_19.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_19.csv
#
# Processing: msv_distance_correlation_2020_08_20.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_20.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_20.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_20.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_20.csv
#
# Processing: msv_distance_correlation_2020_08_21.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_21.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_21.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_21.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_21.csv
#
# Processing: msv_distance_correlation_2020_08_22.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_22.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_22.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_22.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_22.csv
#
# Processing: msv_distance_correlation_2020_08_23.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_23.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_23.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_23.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_23.csv
#
# Processing: msv_distance_correlation_2020_08_24.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_24.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_24.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_24.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_24.csv
#
# Processing: msv_distance_correlation_2020_08_25.csv
# Created adjacency matrix for threshold 0.4: msv_0.4_2020_08_25.csv
# Created adjacency matrix for threshold 0.5: msv_0.5_2020_08_25.csv
# Created adjacency matrix for threshold 0.6: msv_0.6_2020_08_25.csv
# Created adjacency matrix for threshold 0.8: msv_0.8_2020_08_25.csv
#
# Processing: msv_distance_correlation_2020_08_26.csv
# ...
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_01_26.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_01_26.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_01_26.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_01_26.csv
#
# Processing: rsv_distance_correlation_2021_01_27.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_01_27.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_01_27.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_01_27.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_01_27.csv
#
# Processing: rsv_distance_correlation_2021_01_28.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_01_28.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_01_28.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_01_28.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_01_28.csv
#
# Processing: rsv_distance_correlation_2021_01_29.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_01_29.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_01_29.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_01_29.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_01_29.csv
#
# Processing: rsv_distance_correlation_2021_01_30.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_01_30.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_01_30.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_01_30.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_01_30.csv
#
# Processing: rsv_distance_correlation_2021_01_31.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_01_31.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_01_31.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_01_31.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_01_31.csv
#
# Processing: rsv_distance_correlation_2021_02_01.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_01.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_01.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_01.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_01.csv
#
# Processing: rsv_distance_correlation_2021_02_02.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_02.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_02.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_02.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_02.csv
#
# Processing: rsv_distance_correlation_2021_02_03.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_03.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_03.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_03.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_03.csv
#
# Processing: rsv_distance_correlation_2021_02_04.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_04.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_04.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_04.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_04.csv
#
# Processing: rsv_distance_correlation_2021_02_05.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_05.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_05.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_05.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_05.csv
#
# Processing: rsv_distance_correlation_2021_02_06.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_06.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_06.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_06.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_06.csv
#
# Processing: rsv_distance_correlation_2021_02_07.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_07.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_07.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_07.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_07.csv
#
# Processing: rsv_distance_correlation_2021_02_08.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_08.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_08.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_08.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_08.csv
#
# Processing: rsv_distance_correlation_2021_02_09.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_09.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_09.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_09.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_09.csv
#
# Processing: rsv_distance_correlation_2021_02_10.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_10.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_10.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_10.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_10.csv
#
# Processing: rsv_distance_correlation_2021_02_11.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_11.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_11.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_11.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_11.csv
#
# Processing: rsv_distance_correlation_2021_02_12.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_12.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_12.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_12.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_12.csv
#
# Processing: rsv_distance_correlation_2021_02_13.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_13.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_13.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_13.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_13.csv
#
# Processing: rsv_distance_correlation_2021_02_14.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_14.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_14.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_14.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_14.csv
#
# Processing: rsv_distance_correlation_2021_02_15.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_15.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_15.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_15.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_15.csv
#
# Processing: rsv_distance_correlation_2021_02_16.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_16.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_16.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_16.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_16.csv
#
# Processing: rsv_distance_correlation_2021_02_17.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_17.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_17.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_17.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_17.csv
#
# Processing: rsv_distance_correlation_2021_02_18.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_18.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_18.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_18.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_18.csv
#
# Processing: rsv_distance_correlation_2021_02_19.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_19.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_19.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_19.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_19.csv
#
# Processing: rsv_distance_correlation_2021_02_20.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_20.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_20.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_20.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_20.csv
#
# Processing: rsv_distance_correlation_2021_02_21.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_21.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_21.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_21.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_21.csv
#
# Processing: rsv_distance_correlation_2021_02_22.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_22.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_22.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_22.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_22.csv
#
# Processing: rsv_distance_correlation_2021_02_23.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_23.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_23.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_23.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_23.csv
#
# Processing: rsv_distance_correlation_2021_02_24.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_24.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_24.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_24.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_24.csv
#
# Processing: rsv_distance_correlation_2021_02_25.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_25.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_25.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_25.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_25.csv
#
# Processing: rsv_distance_correlation_2021_02_26.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_26.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_26.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_26.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_26.csv
#
# Processing: rsv_distance_correlation_2021_02_27.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_27.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_27.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_27.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_27.csv
#
# Processing: rsv_distance_correlation_2021_02_28.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_02_28.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_02_28.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_02_28.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_02_28.csv
#
# Processing: rsv_distance_correlation_2021_03_01.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_01.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_01.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_01.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_01.csv
#
# Processing: rsv_distance_correlation_2021_03_02.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_02.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_02.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_02.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_02.csv
#
# Processing: rsv_distance_correlation_2021_03_03.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_03.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_03.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_03.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_03.csv
#
# Processing: rsv_distance_correlation_2021_03_04.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_04.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_04.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_04.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_04.csv
#
# Processing: rsv_distance_correlation_2021_03_05.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_05.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_05.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_05.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_05.csv
#
# Processing: rsv_distance_correlation_2021_03_06.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_06.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_06.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_06.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_06.csv
#
# Processing: rsv_distance_correlation_2021_03_07.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_07.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_07.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_07.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_07.csv
#
# Processing: rsv_distance_correlation_2021_03_08.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_08.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_08.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_08.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_08.csv
#
# Processing: rsv_distance_correlation_2021_03_09.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_09.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_09.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_09.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_09.csv
#
# Processing: rsv_distance_correlation_2021_03_10.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_10.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_10.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_10.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_10.csv
#
# Processing: rsv_distance_correlation_2021_03_11.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_11.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_11.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_11.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_11.csv
#
# Processing: rsv_distance_correlation_2021_03_12.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_12.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_12.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_12.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_12.csv
#
# Processing: rsv_distance_correlation_2021_03_13.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_13.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_13.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_13.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_13.csv
#
# Processing: rsv_distance_correlation_2021_03_14.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_14.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_14.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_14.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_14.csv
#
# Processing: rsv_distance_correlation_2021_03_15.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_15.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_15.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_15.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_15.csv
#
# Processing: rsv_distance_correlation_2021_03_16.csv
# Created adjacency matrix for threshold 0.4: rsv_0.4_2021_03_16.csv
# Created adjacency matrix for threshold 0.5: rsv_0.5_2021_03_16.csv
# Created adjacency matrix for threshold 0.6: rsv_0.6_2021_03_16.csv
# Created adjacency matrix for threshold 0.8: rsv_0.8_2021_03_16.csv
