# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.spatial.distance import correlation
import glob
import os

# %%
def calculate_statistics(metric_data, disease_data):
    """
    Calculate statistical measures between network metrics and disease data
    """
    correlation, p_value = stats.pearsonr(metric_data, disease_data)
    r_squared = correlation ** 2

    # Kendall's Tau correlation
    kendall_corr, kendall_pval = stats.kendalltau(metric_data, disease_data)
    
    # Cohen's d
    n1 = len(metric_data)
    n2 = len(disease_data)
    var1 = np.var(metric_data, ddof=1)
    var2 = np.var(disease_data, ddof=1)
    pooled_sd = np.sqrt(((n1 - 1) * var1 + (n2 - 1) * var2) / (n1 + n2 - 2))
    cohens_d = (np.mean(metric_data) - np.mean(disease_data)) / pooled_sd
    
    # Hedges' g
    hedges_g = cohens_d * (1 - (3 / (4 * (n1 + n2 - 2) - 1)))
    
    return {
        'pearson': {
            'correlation': correlation,
            'p_value': p_value
        },
        'kendall': {
            'correlation': kendall_corr,
            'p_value': kendall_pval
        },
        'p_value': p_value,
        'r_squared': r_squared,
        'cohens_d': cohens_d,
        'hedges_g': hedges_g
    }

# %%
def analyze_metric_file(filepath, confirmed_cases, active_cases, metric_col):
    """
    Analyze a single metric file against both disease metrics
    """
    # Extract file information from filename
    filename = os.path.basename(filepath)
    metric_type, analysis_type, threshold, window = filename.replace('.csv', '').split('_')
    
    # Read the metric data
    metric_df = pd.read_csv(filepath)
    
    # Convert dates to datetime
    metric_df['date'] = pd.to_datetime(metric_df['date'])
    confirmed_cases['date'] = pd.to_datetime(confirmed_cases['date'])
    active_cases['date'] = pd.to_datetime(active_cases['date'])
    
    # Merge with disease data
    merged_confirmed = pd.merge(metric_df, confirmed_cases, on='date', how='inner')
    merged_active = pd.merge(metric_df, active_cases, on='date', how='inner')
    
    # Scale disease data
    merged_confirmed['confirmed_cases'] = merged_confirmed['confirmed_cases'] / 10000
    merged_active['active_cases'] = merged_active['active_cases'] / 100000
    
    # Calculate statistics
    confirmed_stats = calculate_statistics(
        merged_confirmed[metric_col],
        merged_confirmed['confirmed_cases']
    )
    
    active_stats = calculate_statistics(
        merged_active[metric_col],
        merged_active['active_cases']
    )
    
    return {
        'filename': filename,
        'metric_type': metric_type,
        'analysis_type': analysis_type,
        'threshold': threshold,
        'window': window,
        'n_observations': len(merged_confirmed),
        'date_range': f"{merged_confirmed['date'].min().date()} to {merged_confirmed['date'].max().date()}",
        'confirmed_cases_stats': confirmed_stats,
        'active_cases_stats': active_stats
    }

# %%
def analyze_all_metrics(base_dir, confirmed_cases, active_cases):
    """
    Analyze all metric files in the directory
    """
    # Determine metric column based on directory name
    metric_col = 'clustering_coefficient' if 'cluscoeff' in base_dir else 'network_density'
    
    # Get all CSV files in the directory
    file_pattern = os.path.join(base_dir, "*.csv")
    all_files = glob.glob(file_pattern)
    
    results = []
    for filepath in all_files:
        try:
            result = analyze_metric_file(filepath, confirmed_cases, active_cases, metric_col)
            results.append(result)
        except Exception as e:
            print(f"Error processing {filepath}: {str(e)}")
    
    return results

# %%
# Read disease data
confirmed_cases = pd.read_csv('disease_confirmed_daily_cases.csv')
active_cases = pd.read_csv('disease_active_cases.csv')

# %%
# Process clustering coefficient files
cluscoeff_dir = "../gt_netdense_cluscoeff/gt_cluscoeff_rsvmsv_15or30day"
print("\nAnalyzing Clustering Coefficient Files:")
cluscoeff_results = analyze_all_metrics(cluscoeff_dir, confirmed_cases, active_cases)
# Out:
# Analyzing Clustering Coefficient Files:

# %%
# Process network density files
netdense_dir = "./gt_netdense_rsvmsv_15or30day"
print("\nAnalyzing Network Density Files:")
netdense_results = analyze_all_metrics(netdense_dir, confirmed_cases, active_cases)
# Out:
# Analyzing Network Density Files:

# %%
# Display results
def display_results(results):
    for result in results:
        print(f"\nFile: {result['filename']}")
        print(f"Analysis Type: {result['analysis_type']}")
        print(f"Threshold: {result['threshold']}")
        print(f"Window: {result['window']}")
        print(f"Time Period: {result['date_range']}")
        print(f"Number of observations: {result['n_observations']}")
        
        print("\nConfirmed Cases Statistics:")
        stats = result['confirmed_cases_stats']
        print(f"  Pearson Correlation: {stats['pearson']['correlation']:.10f}")
        print(f"  P-value: {stats['pearson']['p_value']:.10f}")
        print(f"  R-squared: {stats['r_squared']:.10f}")
        print(f"  Kendall's tau Correlation: {stats['kendall']['correlation']:.10f}")
        print(f"  P-value: {stats['kendall']['p_value']:.10f}")
        print(f"  Cohen's d: {stats['cohens_d']:.10f}")
        print(f"  Hedges' g: {stats['hedges_g']:.10f}")
        
        print("\nActive Cases Statistics:")
        stats = result['active_cases_stats']
        print(f"  Pearson Correlation: {stats['pearson']['correlation']:.10f}")
        print(f"  P-value: {stats['pearson']['p_value']:.10f}")
        print(f"  R-squared: {stats['r_squared']:.10f}")
        print(f"  Kendall's tau Correlation: {stats['kendall']['correlation']:.10f}")
        print(f"  P-value: {stats['kendall']['p_value']:.10f}")
        print(f"  Cohen's d: {stats['cohens_d']:.10f}")
        print(f"  Hedges' g: {stats['hedges_g']:.10f}")
        print("="*80)

# %%
print("\nClustering Coefficient Results:")
display_results(cluscoeff_results)

print("\nNetwork Density Results:")
display_results(netdense_results)
# Out:
# Clustering Coefficient Results:
#
# File: cluscoeff_msv_0.8_30day.csv
# Analysis Type: msv
# Threshold: 0.8
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1027498703
#   P-value: 0.0595354532
#   R-squared: 0.0105575358
#   Kendall's tau Correlation: -0.1678594554
#   P-value: 0.0001599854
#   Cohen's d: -1.4548919406
#   Hedges' g: -1.4532675730
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1360489569
#   P-value: 0.0124235057
#   R-squared: 0.0185093187
#   Kendall's tau Correlation: -0.2025696382
#   P-value: 0.0000051871
#   Cohen's d: -2.0279197462
#   Hedges' g: -2.0256556006
# ================================================================================
#
# File: cluscoeff_msv_0.5_30day.csv
# Analysis Type: msv
# Threshold: 0.5
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1116230286
#   P-value: 0.0405681494
#   R-squared: 0.0124597005
#   Kendall's tau Correlation: -0.1153868229
#   P-value: 0.0039685172
#   Cohen's d: -1.1612645420
#   Hedges' g: -1.1599680054
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1327604073
#   P-value: 0.0147317659
#   R-squared: 0.0176253257
#   Kendall's tau Correlation: -0.0487172436
#   P-value: 0.2237497917
#   Cohen's d: -1.8038422292
#   Hedges' g: -1.8018282632
# ================================================================================
#
# File: cluscoeff_rsv_0.4_15day.csv
# Analysis Type: rsv
# Threshold: 0.4
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0801259263
#   P-value: 0.1335207304
#   R-squared: 0.0064201641
#   Kendall's tau Correlation: -0.0832621174
#   P-value: 0.0202791721
#   Cohen's d: 1.2442614561
#   Hedges' g: 1.2429316434
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0814387530
#   P-value: 0.1272526661
#   R-squared: 0.0066322705
#   Kendall's tau Correlation: -0.0261566621
#   P-value: 0.4657364009
#   Cohen's d: 0.4702205665
#   Hedges' g: 0.4697180152
# ================================================================================
#
# File: cluscoeff_rsv_0.6_30day.csv
# Analysis Type: rsv
# Threshold: 0.6
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0928479091
#   P-value: 0.0887917565
#   R-squared: 0.0086207342
#   Kendall's tau Correlation: 0.0037836701
#   P-value: 0.9286138376
#   Cohen's d: -1.3866889750
#   Hedges' g: -1.3851407551
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0903329479
#   P-value: 0.0978196278
#   R-squared: 0.0081600415
#   Kendall's tau Correlation: 0.0195952797
#   P-value: 0.6425623600
#   Cohen's d: -1.9779585515
#   Hedges' g: -1.9757501869
# ================================================================================
#
# File: cluscoeff_msv_0.6_15day.csv
# Analysis Type: msv
# Threshold: 0.6
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1314751047
#   P-value: 0.0135626601
#   R-squared: 0.0172857032
#   Kendall's tau Correlation: -0.0686301724
#   P-value: 0.0900473657
#   Cohen's d: -1.2488184263
#   Hedges' g: -1.2474837433
#
# Active Cases Statistics:
#   Pearson Correlation: -0.2083840776
#   P-value: 0.0000818040
#   R-squared: 0.0434239238
#   Kendall's tau Correlation: -0.0850575736
#   P-value: 0.0355861796
#   Cohen's d: -1.8162559171
#   Hedges' g: -1.8143147814
# ================================================================================
#
# File: cluscoeff_msv_0.4_30day.csv
# Analysis Type: msv
# Threshold: 0.4
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1407427295
#   P-value: 0.0096820559
#   R-squared: 0.0198085159
#   Kendall's tau Correlation: -0.1461585938
#   P-value: 0.0000884820
#   Cohen's d: -0.5647939841
#   Hedges' g: -0.5641633991
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1604225432
#   P-value: 0.0031452471
#   R-squared: 0.0257353924
#   Kendall's tau Correlation: -0.0650250399
#   P-value: 0.0810524344
#   Cohen's d: -1.2867108254
#   Hedges' g: -1.2852742298
# ================================================================================
#
# File: cluscoeff_rsv_0.5_15day.csv
# Analysis Type: rsv
# Threshold: 0.5
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0762249673
#   P-value: 0.1535518530
#   R-squared: 0.0058102456
#   Kendall's tau Correlation: -0.0754744416
#   P-value: 0.0386754003
#   Cohen's d: -0.6554715473
#   Hedges' g: -0.6547710077
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0783490522
#   P-value: 0.1423799118
#   R-squared: 0.0061385740
#   Kendall's tau Correlation: 0.0070095706
#   P-value: 0.8476690807
#   Cohen's d: -1.3463259652
#   Hedges' g: -1.3448870703
# ================================================================================
#
# File: cluscoeff_rsv_0.8_15day.csv
# Analysis Type: rsv
# Threshold: 0.8
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1286456576
#   P-value: 0.0157324192
#   R-squared: 0.0165497052
#   Kendall's tau Correlation: -0.2119357303
#   P-value: 0.0000008344
#   Cohen's d: -1.4034960337
#   Hedges' g: -1.4019960380
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1779614179
#   P-value: 0.0007971406
#   R-squared: 0.0316702663
#   Kendall's tau Correlation: -0.2489493049
#   P-value: 0.0000000071
#   Cohen's d: -1.9288116846
#   Hedges' g: -1.9267502542
# ================================================================================
#
# File: cluscoeff_msv_0.5_15day.csv
# Analysis Type: msv
# Threshold: 0.5
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1292227844
#   P-value: 0.0152666678
#   R-squared: 0.0166985280
#   Kendall's tau Correlation: -0.0598231996
#   P-value: 0.1039595859
#   Cohen's d: -0.8174711731
#   Hedges' g: -0.8165974953
#
# Active Cases Statistics:
#   Pearson Correlation: -0.2011724187
#   P-value: 0.0001447999
#   R-squared: 0.0404703420
#   Kendall's tau Correlation: -0.0447012711
#   P-value: 0.2242259524
#   Cohen's d: -1.4789509769
#   Hedges' g: -1.4773703382
# ================================================================================
#
# File: cluscoeff_msv_0.8_15day.csv
# Analysis Type: msv
# Threshold: 0.8
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1148628142
#   P-value: 0.0312019496
#   R-squared: 0.0131934661
#   Kendall's tau Correlation: -0.1530244921
#   P-value: 0.0004101211
#   Cohen's d: -1.4069263833
#   Hedges' g: -1.4054227213
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1768208149
#   P-value: 0.0008624156
#   R-squared: 0.0312656006
#   Kendall's tau Correlation: -0.2126221412
#   P-value: 0.0000009045
#   Cohen's d: -1.9312691352
#   Hedges' g: -1.9292050784
# ================================================================================
#
# File: cluscoeff_rsv_0.6_15day.csv
# Analysis Type: rsv
# Threshold: 0.6
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0910350689
#   P-value: 0.0881129629
#   R-squared: 0.0082873838
#   Kendall's tau Correlation: -0.0167597359
#   P-value: 0.6721628683
#   Cohen's d: -1.2114863704
#   Hedges' g: -1.2101915862
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1187983254
#   P-value: 0.0258255781
#   R-squared: 0.0141130421
#   Kendall's tau Correlation: -0.0090375331
#   P-value: 0.8194322208
#   Cohen's d: -1.7892533482
#   Hedges' g: -1.7873410717
# ================================================================================
#
# File: cluscoeff_rsv_0.4_30day.csv
# Analysis Type: rsv
# Threshold: 0.4
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1059997478
#   P-value: 0.0518777166
#   R-squared: 0.0112359465
#   Kendall's tau Correlation: -0.0409122962
#   P-value: 0.2744295843
#   Cohen's d: -0.5787064131
#   Hedges' g: -0.5780602950
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0661011914
#   P-value: 0.2261745515
#   R-squared: 0.0043693675
#   Kendall's tau Correlation: 0.0584145728
#   P-value: 0.1185334635
#   Cohen's d: -1.3144697593
#   Hedges' g: -1.3130021712
# ================================================================================
#
# File: cluscoeff_msv_0.4_15day.csv
# Analysis Type: msv
# Threshold: 0.4
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0602834875
#   P-value: 0.2593107690
#   R-squared: 0.0036340989
#   Kendall's tau Correlation: -0.1111495697
#   P-value: 0.0019673876
#   Cohen's d: 1.0735555709
#   Hedges' g: 1.0724082012
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1397626872
#   P-value: 0.0086457537
#   R-squared: 0.0195336087
#   Kendall's tau Correlation: -0.0814086133
#   P-value: 0.0233466925
#   Cohen's d: 0.2085036252
#   Hedges' g: 0.2082807855
# ================================================================================
#
# File: cluscoeff_msv_0.6_30day.csv
# Analysis Type: msv
# Threshold: 0.6
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1525517209
#   P-value: 0.0050080319
#   R-squared: 0.0232720275
#   Kendall's tau Correlation: -0.1262250237
#   P-value: 0.0027908180
#   Cohen's d: -1.3899082509
#   Hedges' g: -1.3883564367
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1742551850
#   P-value: 0.0013198882
#   R-squared: 0.0303648695
#   Kendall's tau Correlation: -0.1141230926
#   P-value: 0.0068494022
#   Cohen's d: -1.9802454969
#   Hedges' g: -1.9780345789
# ================================================================================
#
# File: cluscoeff_rsv_0.8_30day.csv
# Analysis Type: rsv
# Threshold: 0.8
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1783625287
#   P-value: 0.0010070733
#   R-squared: 0.0318131916
#   Kendall's tau Correlation: -0.3884238905
#   P-value: 0.0000000000
#   Cohen's d: -1.4496978663
#   Hedges' g: -1.4480792978
#
# Active Cases Statistics:
#   Pearson Correlation: -0.2197509325
#   P-value: 0.0000472260
#   R-squared: 0.0482904723
#   Kendall's tau Correlation: -0.4186271074
#   P-value: 0.0000000000
#   Cohen's d: -2.0241343123
#   Hedges' g: -2.0218743931
# ================================================================================
#
# File: cluscoeff_rsv_0.5_30day.csv
# Analysis Type: rsv
# Threshold: 0.5
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0657277784
#   P-value: 0.2288137793
#   R-squared: 0.0043201409
#   Kendall's tau Correlation: 0.0254413205
#   P-value: 0.5259224685
#   Cohen's d: -1.1807233483
#   Hedges' g: -1.1794050863
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0577325067
#   P-value: 0.2906157731
#   R-squared: 0.0033330423
#   Kendall's tau Correlation: 0.0931224932
#   P-value: 0.0202200609
#   Cohen's d: -1.8211659207
#   Hedges' g: -1.8191326130
# ================================================================================
#
# Network Density Results:
#
# File: netdense_msv_0.5_30day.csv
# Analysis Type: msv
# Threshold: 0.5
# Window: 30day
# Time Period: 2020-04-13 to 2021-03-16
# Number of observations: 338
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0662420252
#   P-value: 0.2244928183
#   R-squared: 0.0043880059
#   Kendall's tau Correlation: -0.1335690148
#   P-value: 0.0003665664
#   Cohen's d: 0.1121094235
#   Hedges' g: 0.1119846263
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0558010842
#   P-value: 0.3063611910
#   R-squared: 0.0031137610
#   Kendall's tau Correlation: -0.0609358500
#   P-value: 0.1039461196
#   Cohen's d: -0.6556017884
#   Hedges' g: -0.6548719905
# ================================================================================
#
# File: netdense_msv_0.8_30day.csv
# Analysis Type: msv
# Threshold: 0.8
# Window: 30day
# Time Period: 2020-04-13 to 2021-03-16
# Number of observations: 338
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0598337832
#   P-value: 0.2726682028
#   R-squared: 0.0035800816
#   Kendall's tau Correlation: -0.0961056254
#   P-value: 0.0266125581
#   Cohen's d: -1.3502624454
#   Hedges' g: -1.3487593703
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0182446702
#   P-value: 0.7382215432
#   R-squared: 0.0003328680
#   Kendall's tau Correlation: -0.0240448617
#   P-value: 0.5789712722
#   Cohen's d: -1.9475302053
#   Hedges' g: -1.9453622681
# ================================================================================
#
# File: netdense_rsv_0.6_30day.csv
# Analysis Type: rsv
# Threshold: 0.6
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: 0.1013693525
#   P-value: 0.0630596964
#   R-squared: 0.0102757456
#   Kendall's tau Correlation: 0.0395027870
#   P-value: 0.3132420210
#   Cohen's d: -0.7179471855
#   Hedges' g: -0.7171456069
#
# Active Cases Statistics:
#   Pearson Correlation: 0.1482668661
#   P-value: 0.0063953415
#   R-squared: 0.0219830636
#   Kendall's tau Correlation: 0.1088701964
#   P-value: 0.0054333038
#   Cohen's d: -1.4471297609
#   Hedges' g: -1.4455140597
# ================================================================================
#
# File: netdense_rsv_0.4_15day.csv
# Analysis Type: rsv
# Threshold: 0.4
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0085116367
#   P-value: 0.8735685619
#   R-squared: 0.0000724480
#   Kendall's tau Correlation: -0.0524832898
#   P-value: 0.1480823717
#   Cohen's d: 5.2491730987
#   Hedges' g: 5.2435630099
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0100422725
#   P-value: 0.8510770996
#   R-squared: 0.0001008472
#   Kendall's tau Correlation: -0.0105654148
#   P-value: 0.7708505425
#   Cohen's d: 3.9202130919
#   Hedges' g: 3.9160233380
# ================================================================================
#
# File: netdense_msv_0.4_30day.csv
# Analysis Type: msv
# Threshold: 0.4
# Window: 30day
# Time Period: 2020-04-13 to 2021-03-16
# Number of observations: 338
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1052348971
#   P-value: 0.0532456830
#   R-squared: 0.0110743836
#   Kendall's tau Correlation: -0.1652345636
#   P-value: 0.0000081496
#   Cohen's d: 1.4484469784
#   Hedges' g: 1.4468346069
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0742198062
#   P-value: 0.1734069342
#   R-squared: 0.0055085796
#   Kendall's tau Correlation: -0.0847601530
#   P-value: 0.0220690101
#   Cohen's d: 0.6259904490
#   Hedges' g: 0.6252936137
# ================================================================================
#
# File: netdense_msv_0.6_15day.csv
# Analysis Type: msv
# Threshold: 0.6
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0878473515
#   P-value: 0.0998703457
#   R-squared: 0.0077171572
#   Kendall's tau Correlation: -0.0964776323
#   P-value: 0.0093685330
#   Cohen's d: 0.0477869069
#   Hedges' g: 0.0477358344
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1622578044
#   P-value: 0.0022606940
#   R-squared: 0.0263275951
#   Kendall's tau Correlation: -0.0855552025
#   P-value: 0.0211700579
#   Cohen's d: -0.7541117272
#   Hedges' g: -0.7533057653
# ================================================================================
#
# File: netdense_rsv_0.8_15day.csv
# Analysis Type: rsv
# Threshold: 0.8
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: 0.0194534622
#   P-value: 0.7160704592
#   R-squared: 0.0003784372
#   Kendall's tau Correlation: 0.0645760921
#   P-value: 0.1113183095
#   Cohen's d: -1.1511644571
#   Hedges' g: -1.1499341424
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0296295292
#   P-value: 0.5795490106
#   R-squared: 0.0008779090
#   Kendall's tau Correlation: 0.0680343458
#   P-value: 0.0933185771
#   Cohen's d: -1.7449524124
#   Hedges' g: -1.7430874828
# ================================================================================
#
# File: netdense_rsv_0.5_15day.csv
# Analysis Type: rsv
# Threshold: 0.5
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0395224321
#   P-value: 0.4598111257
#   R-squared: 0.0015620226
#   Kendall's tau Correlation: -0.0856219652
#   P-value: 0.0186189230
#   Cohen's d: 1.8811838559
#   Hedges' g: 1.8791733281
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0268743954
#   P-value: 0.6153118602
#   R-squared: 0.0007222331
#   Kendall's tau Correlation: -0.0169533552
#   P-value: 0.6411621700
#   Cohen's d: 0.9193062623
#   Hedges' g: 0.9183237476
# ================================================================================
#
# File: netdense_msv_0.8_15day.csv
# Analysis Type: msv
# Threshold: 0.8
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.1024331034
#   P-value: 0.0548537601
#   R-squared: 0.0104925407
#   Kendall's tau Correlation: -0.0829187038
#   P-value: 0.0485140318
#   Cohen's d: -1.2362522895
#   Hedges' g: -1.2349310366
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1378068166
#   P-value: 0.0096352858
#   R-squared: 0.0189907187
#   Kendall's tau Correlation: -0.0204123275
#   P-value: 0.6270902110
#   Cohen's d: -1.8073815090
#   Hedges' g: -1.8054498580
# ================================================================================
#
# File: netdense_msv_0.5_15day.csv
# Analysis Type: msv
# Threshold: 0.5
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0976221290
#   P-value: 0.0673381263
#   R-squared: 0.0095300801
#   Kendall's tau Correlation: -0.1421239979
#   P-value: 0.0001045364
#   Cohen's d: 1.8297239282
#   Hedges' g: 1.8277683985
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1822644113
#   P-value: 0.0005898332
#   R-squared: 0.0332203156
#   Kendall's tau Correlation: -0.1450687160
#   P-value: 0.0000744608
#   Cohen's d: 0.8048445510
#   Hedges' g: 0.8039843680
# ================================================================================
#
# File: netdense_rsv_0.4_30day.csv
# Analysis Type: rsv
# Threshold: 0.4
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0375728555
#   P-value: 0.4918143617
#   R-squared: 0.0014117195
#   Kendall's tau Correlation: -0.0701342899
#   P-value: 0.0580399989
#   Cohen's d: 1.4210564570
#   Hedges' g: 1.4194698662
#
# Active Cases Statistics:
#   Pearson Correlation: 0.0596524822
#   P-value: 0.2748428199
#   R-squared: 0.0035584186
#   Kendall's tau Correlation: 0.0257345912
#   P-value: 0.4866156845
#   Cohen's d: 0.6117306654
#   Hedges' g: 0.6110476762
# ================================================================================
#
# File: netdense_rsv_0.6_15day.csv
# Analysis Type: rsv
# Threshold: 0.6
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: 0.0105961040
#   P-value: 0.8429676305
#   R-squared: 0.0001122774
#   Kendall's tau Correlation: -0.0118119771
#   P-value: 0.7490710708
#   Cohen's d: 0.1876144043
#   Hedges' g: 0.1874138902
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0008264558
#   P-value: 0.9876727476
#   R-squared: 0.0000006830
#   Kendall's tau Correlation: 0.0338447344
#   P-value: 0.3592372276
#   Cohen's d: -0.6195225094
#   Hedges' g: -0.6188603906
# ================================================================================
#
# File: netdense_msv_0.6_30day.csv
# Analysis Type: msv
# Threshold: 0.6
# Window: 30day
# Time Period: 2020-04-13 to 2021-03-16
# Number of observations: 338
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0975657664
#   P-value: 0.0732362096
#   R-squared: 0.0095190788
#   Kendall's tau Correlation: -0.1551032172
#   P-value: 0.0000656780
#   Cohen's d: -0.6651856564
#   Hedges' g: -0.6644451900
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0959426342
#   P-value: 0.0781682059
#   R-squared: 0.0092049890
#   Kendall's tau Correlation: -0.0900320771
#   P-value: 0.0204706627
#   Cohen's d: -1.3944699464
#   Hedges' g: -1.3929176607
# ================================================================================
#
# File: netdense_msv_0.4_15day.csv
# Analysis Type: msv
# Threshold: 0.4
# Window: 15day
# Time Period: 2020-03-30 to 2021-03-16
# Number of observations: 352
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0094868396
#   P-value: 0.8592257960
#   R-squared: 0.0000900001
#   Kendall's tau Correlation: -0.1135691691
#   P-value: 0.0017963488
#   Cohen's d: 5.5591823312
#   Hedges' g: 5.5532409180
#
# Active Cases Statistics:
#   Pearson Correlation: -0.1008386308
#   P-value: 0.0587591577
#   R-squared: 0.0101684295
#   Kendall's tau Correlation: -0.0959721435
#   P-value: 0.0083112658
#   Cohen's d: 3.9743633782
#   Hedges' g: 3.9701157508
# ================================================================================
#
# File: netdense_rsv_0.5_30day.csv
# Analysis Type: rsv
# Threshold: 0.5
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: 0.0607294595
#   P-value: 0.2662547659
#   R-squared: 0.0036880673
#   Kendall's tau Correlation: 0.0212157708
#   P-value: 0.5714547354
#   Cohen's d: 0.0751463031
#   Hedges' g: 0.0750624033
#
# Active Cases Statistics:
#   Pearson Correlation: 0.1365644027
#   P-value: 0.0120922164
#   R-squared: 0.0186498361
#   Kendall's tau Correlation: 0.1403394029
#   P-value: 0.0001806856
#   Cohen's d: -0.7175727407
#   Hedges' g: -0.7167715802
# ================================================================================
#
# File: netdense_rsv_0.8_30day.csv
# Analysis Type: rsv
# Threshold: 0.8
# Window: 30day
# Time Period: 2020-04-14 to 2021-03-16
# Number of observations: 337
#
# Confirmed Cases Statistics:
#   Pearson Correlation: -0.0008088071
#   P-value: 0.9881976752
#   R-squared: 0.0000006542
#   Kendall's tau Correlation: 0.0934301061
#   P-value: 0.0282603024
#   Cohen's d: -1.3084102351
#   Hedges' g: -1.3069494124
#
# Active Cases Statistics:
#   Pearson Correlation: -0.0314493474
#   P-value: 0.5650677970
#   R-squared: 0.0009890615
#   Kendall's tau Correlation: 0.0968473745
#   P-value: 0.0229296857
#   Cohen's d: -1.9199584704
#   Hedges' g: -1.9178148621
# ================================================================================
